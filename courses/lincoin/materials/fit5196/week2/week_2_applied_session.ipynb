# %% [markdown]
# # **Week 2 Applied Session: Introduction to DataWrangling with Pandas**
#
# ![](https://media.licdn.com/dms/image/D5612AQEdvrs4ha4KAQ/article-cover_image-shrink_600_2000/0/1693676526923?e=2147483647&v=beta&t=aegFlNZu0P_4UKcfh4ZTol_MmcIQzqoZx5tOKKMkI1E)

# %% [markdown]
# Pandas is a strange name, kind of an acronym: Python, Numerical, Data Analysis?
#
# Because pandas is an external library you need to import it. There are several ways that you will see imports done:
# - import pandas
# - from pandas import tools
# - import pandas as `pd`
#
# The first is the same as `from pandas import *` where star means all (that's right, the same as SQL)
#
# The second imports a part of pandas only, a sublibrary called *tools*
#
# The third is a renaming, or alias, `pd` is common (you could call pandas `xyz` but you'd be on your own).
#
# You could leave out the `import as` and just type `pandas` every time but it becomes more useful for longer names e.g. `import matplotlib.pyplot as plt`
#
# So, for any code following (if the above imports work), `plt` would mean `matplotlib.pyplot`
#
# This, by the way, is a Python Notebook, select cells (this one is text, below is code) then `SHIFT-ENTER` to run sequentially
#
# The following scripts should work with both Python2 and Python 3!

# %%
# import libraries first
import pandas as pd
import numpy as np # Numberical Python

# %% [markdown]
# ## **1. The Pandas DataFrame**

# %%
# so try pandas.DataFrame()
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# So.. no errors, seems to have worked, but what's in the DataFrame? (nothing)
#
# **note**: Python is case sensitive: `DataFrame` is not the same as `Dataframe` or `dataframe`

# %%
pd.DataFrame([2,4,6,8])
# Out:
#    0
# 0  2
# 1  4
# 2  6
# 3  8

# %%
# aha, better but this is temporary, if you want to use the data you need to save it, so create a variable
df = pd.DataFrame([2,4,6,8])

# %%
# but now there's no output... can't win
# use the variable to see the data
df
# Out:
#    0
# 0  2
# 1  4
# 2  6
# 3  8

# %% [markdown]
# **Note**: the column titles are ` ` and `0`
#
# And another note: Python is one of those `0` index languages, we have 4 items `(2,4,6,8)` but they are found at `0,1,2,3` viz:

# %%
# you can get the values with its index:
df[0][1] # column 0, item 1
# Out:
# np.int64(4)

# %%
# rename the column
df.columns.name = "Index"
df
# Out:
# Index  0
# 0      2
# 1      4
# 2      6
# 3      8

# %%
# You can also use pandas to create an series of datetime objects. Let's make one for the week beginning January 25th, 2015:
dates = pd.date_range('20150125', periods=7)

dates
# Out:
# DatetimeIndex(['2015-01-25', '2015-01-26', '2015-01-27', '2015-01-28',
#                '2015-01-29', '2015-01-30', '2015-01-31'],
#               dtype='datetime64[us]', freq='D')

# %% [markdown]
# Now we'll create a DataFrame using the dates array as our index, fill it with some random values using numpy, and give the columns some labels.
#
# Note that `randn(7,5)` below matches the 7 dates (rows) and 5 names (columns)
#
# (Otherwise it wouldn't work, try changing 5 to 6...)

# %%
df = pd.DataFrame(np.random.randn(7,5), index=dates, columns=['Adam','Bob','Carla','Dave','Eve'])
df
# Out:
#                 Adam       Bob     Carla      Dave       Eve
# 2015-01-25  1.068028 -1.555162 -1.119964 -0.443243 -0.786383
# 2015-01-26  1.461746 -0.331045 -0.925439  0.449471 -0.336225
# 2015-01-27  0.073635 -0.278493  0.674920 -0.478516  0.573509
# 2015-01-28  0.351914  0.379390  0.594328  0.399870  0.567707
# 2015-01-29 -1.927059  1.030311  0.575659 -1.244948  1.996933
# 2015-01-30 -0.459636  2.195240  0.196718  1.136544  1.298310
# 2015-01-31  0.677911 -0.606260  0.572903 -0.742959  0.991342

# %% [markdown]
# DataFrames are more flexible than that, both in terms of what you can store in them and what you can do with them.
#
# It can also be useful to know how to create a DataFrame from a dict of objects.
#
# This comes in particularly handy when working with JSON-like structures.

# %%
df2 = pd.DataFrame({ 'A' : np.random.random_sample(4), # 4 random numbers
                     'B' : pd.Timestamp('20130102'), # 4 dates, note pandas autofills
                     'C' : pd.date_range('20150125',periods = 4), # 4 dates in a range
                     'D' : ['a','b','c','d'], # letters
                     'E' : ["cat","dog","mouse","parrot"], # text/string
                     'F' : 'copy'}) # note pandas autofills

df2
# Out:
#           A          B          C  D       E     F
# 0  0.407571 2013-01-02 2015-01-25  a     cat  copy
# 1  0.841604 2013-01-02 2015-01-26  b     dog  copy
# 2  0.881396 2013-01-02 2015-01-27  c   mouse  copy
# 3  0.000205 2013-01-02 2015-01-28  d  parrot  copy

# %% [markdown]
# ---

# %% [markdown]
# ## **2. Exploring the data in a DataFrame**

# %% [markdown]
# Let's import the UFO sightings dataset via URL. We can access the data types of each column in a DataFrame as follows:

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %% [markdown]
# We can display the index, columns and the underlyinig numpy data separately:

# %%
ufo.index
# Out:
# RangeIndex(start=0, stop=18241, step=1)

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='str')

# %% [markdown]
# We can accesss the data types of each column:

# %%
ufo.dtypes
# Out:
# City               str
# Colors Reported    str
# Shape Reported     str
# State              str
# Time               str
# dtype: object

# %%
ufo.values
# Out:
# array([['Ithaca', nan, 'TRIANGLE', 'NY', '6/1/1930 22:00'],
#        ['Willingboro', nan, 'OTHER', 'NJ', '6/30/1930 20:00'],
#        ['Holyoke', nan, 'OVAL', 'CO', '2/15/1931 14:00'],
#        ...,
#        ['Eagle River', nan, nan, 'WI', '12/31/2000 23:45'],
#        ['Eagle River', 'RED', 'LIGHT', 'WI', '12/31/2000 23:45'],
#        ['Ybor', nan, 'OVAL', 'FL', '12/31/2000 23:59']],
#       shape=(18241, 5), dtype=object)

# %% [markdown]
# We can get the size of the data using `shape`:

# %%
ufo.shape
# Out:
# (18241, 5)

# %% [markdown]
# We can get a quick statistical summary of the data using `describe()` function:

# %%
ufo.describe()
# Out:
#            City Colors Reported Shape Reported  State              Time
# count     18215            2882          15597  18241             18241
# unique     6475              27             27     52             16145
# top     Seattle             RED          LIGHT     CA  11/16/1999 19:00
# freq        187             780           2803   2529                27

# %% [markdown]
# We can have a look at the data in first five rows using `head()` function:

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# We can indicate how many row to return by specifying an integer:

# %%
ufo.head(20)
# Out:
#                     City Colors Reported Shape Reported State  \
# 0                 Ithaca             NaN       TRIANGLE    NY
# 1            Willingboro             NaN          OTHER    NJ
# 2                Holyoke             NaN           OVAL    CO
# 3                Abilene             NaN           DISK    KS
# 4   New York Worlds Fair             NaN          LIGHT    NY
# 5            Valley City             NaN           DISK    ND
# 6            Crater Lake             NaN         CIRCLE    CA
# 7                   Alma             NaN           DISK    MI
# 8                Eklutna             NaN          CIGAR    AK
# 9                Hubbard             NaN       CYLINDER    OR
# 10               Fontana             NaN          LIGHT    CA
# 11              Waterloo             NaN       FIREBALL    AL
# 12                Belton             RED         SPHERE    SC
# 13                Keokuk             NaN           OVAL    IA
# 14             Ludington             NaN           DISK    MI
# 15           Forest Home             NaN         CIRCLE    CA
# 16           Los Angeles             NaN            NaN    CA
# 17             Hapeville             NaN            NaN    GA
# 18                Oneida             NaN      RECTANGLE    TN
# 19            Bering Sea             RED          OTHER    AK
#
#                 Time
# 0     6/1/1930 22:00
# 1    6/30/1930 20:00
# 2    2/15/1931 14:00
# 3     6/1/1931 13:00
# 4    4/18/1933 19:00
# 5    9/15/1934 15:30
# 6     6/15/1935 0:00
# 7     7/15/1936 0:00
# 8   10/15/1936 17:00
# 9     6/15/1937 0:00
# 10   8/15/1937 21:00
# 11    6/1/1939 20:00
# 12   6/30/1939 20:00
# 13     7/7/1939 2:00
# 14    6/1/1941 13:00
# 15    7/2/1941 11:30
# 16    2/25/1942 0:00
# 17    6/1/1942 22:30
# 18    7/15/1942 1:00
# 19   4/30/1943 23:00

# %% [markdown]
# We can also have the last five rows using `tail()` function, check the index numbers:

# %%
ufo.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %% [markdown]
# We can focus on a specific column:

# %%
ufo['City']
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: str

# %% [markdown]
# We can select a subset of rows by integer indexing:

# %%
ufo[1:3]
# Out:
#           City Colors Reported Shape Reported State             Time
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %% [markdown]
# **Note**：Only the rows wiht index 1 and 2 returned.

# %% [markdown]
# We can also select rows by specific values:

# %%
ufo[ufo.State == 'NJ'][['City','State']]
# Out:
#                   City State
# 1          Willingboro    NJ
# 141             Newark    NJ
# 147         Sandy Hook    NJ
# 255          Keansburg    NJ
# 311           Red Bank    NJ
# ...                ...   ...
# 17961         Freehold    NJ
# 17976   East Brunswick    NJ
# 18006  West Allenhurst    NJ
# 18023        Elizabeth    NJ
# 18148    Highland Park    NJ
#
# [370 rows x 2 columns]

# %% [markdown]
# **Note**: `ufo.State == 'NJ'` is an example of using conditional indexing. We can also have other conditions like `<`, `>`, `<=`, `>=` or `!=` (not equal).

# %%
ufo[['City','State']][ufo.State != 'NJ']
# Out:
#                        City State
# 0                    Ithaca    NY
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# 5               Valley City    ND
# ...                     ...   ...
# 18236            Grant Park    IL
# 18237           Spirit Lake    IA
# 18238           Eagle River    WI
# 18239           Eagle River    WI
# 18240                  Ybor    FL
#
# [17871 rows x 2 columns]

# %% [markdown]
# What is the difference between the following two functions `loc` and `iloc`?

# %%
ufo.loc[:,'City':'State'].head()
# Out:
#                    City Colors Reported Shape Reported State
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY

# %%
ufo.iloc[1:6,2:6]
# Out:
#   Shape Reported State             Time
# 1          OTHER    NJ  6/30/1930 20:00
# 2           OVAL    CO  2/15/1931 14:00
# 3           DISK    KS   6/1/1931 13:00
# 4          LIGHT    NY  4/18/1933 19:00
# 5           DISK    ND  9/15/1934 15:30

# %% [markdown]
# Enter your answer here....

# %% [markdown]
# ---

# %% [markdown]
# ## **Task 1: Load data and get the basic information**
#
# In this task, you are asked to load a data file from Google Drive with your Monash account. Open the file to create a Pandas dataframe and explore it using the functions introduced above and see what information you can get from the data.

# %% [markdown]
# ### **Connect with your Google Drive to access files**

# %%
# Note: google.colab is not available in local Jupyter environments
# This cell is for Google Colab only
# from google.colab import drive
# drive.mount('/content/drive')
print("Running in local environment - no need to mount Google Drive")
# Out:
# Running in local environment - no need to mount Google Drive

# %% [markdown]
# After you run the cell, then it asks you to click on a url and login in order to give premissions to Colab. If you successfully followed the steps, you should now see a drive folder in the left pane of this notebook. see below figure.
#
# ![](https://drive.google.com/uc?export=download&id=1B2sooICEr_QDLEyFHOSwIQO89LODLfAq)
#
# If you click on it, you should be able to see the "FIT5196_S1_2025" shared drive. If you are unable to see that, let us know ASAP. But if you can see it, then it means that now this notebook have access to everything on that shared drive. Let's read the `xmart` data from there.

# %%
xmart = pd.read_csv('xmart.csv',skiprows=1)

# %% [markdown]
# Now, it is your turn to write Python codes and try to find out:
# 1. How many records in the dataset?
# 2. How many attributes in the dataset? What are they?
# 3. What is the data type for each of the attribute?
# 4. Without any description provided, can you summarize what information contains in this dataset?
#
# **Note**: Don't forget to use markdown to explain your findings.

# %%
# How many records in the dataset?
xmart.shape[0]
# Out:
# 940

# %%
# How many attributes in the dataset? What are they?
xmart.shape[1], xmart.columns.tolist()
# Out:
# (4, ['Country', 'Data Source', 'Beverage Types', ' 2012'])

# %%
# What is the data type for each of the attribute?
xmart.dtypes
# Out:
# Country               str
# Data Source           str
# Beverage Types        str
#  2012             float64
# dtype: object

# %%
# Without any description provided, can you summarize what information contains in this dataset?
xmart.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         940 non-null    str
#  1   Data Source     940 non-null    str
#  2   Beverage Types  940 non-null    str
#  3    2012           940 non-null    float64
# dtypes: float64(1), str(3)
# memory usage: 29.5 KB

# %% [markdown]
# ---

# %% [markdown]
# ## **3. Editing data in DataFrame**
#
# We can apply basic editing operations to DataFrame objects, such as updating, deleting, duplication, adding new columns, insert new rows, and etc.

# %% [markdown]
# ### **3.1 Dealing with missing values (simplest ways)**
#
# Continue with ufo data, we are looking for the data rows having missing city data and simply remove them.

# %%
ufo[10:20]
# Out:
#            City Colors Reported Shape Reported State             Time
# 10      Fontana             NaN          LIGHT    CA  8/15/1937 21:00
# 11     Waterloo             NaN       FIREBALL    AL   6/1/1939 20:00
# 12       Belton             RED         SPHERE    SC  6/30/1939 20:00
# 13       Keokuk             NaN           OVAL    IA    7/7/1939 2:00
# 14    Ludington             NaN           DISK    MI   6/1/1941 13:00
# 15  Forest Home             NaN         CIRCLE    CA   7/2/1941 11:30
# 16  Los Angeles             NaN            NaN    CA   2/25/1942 0:00
# 17    Hapeville             NaN            NaN    GA   6/1/1942 22:30
# 18       Oneida             NaN      RECTANGLE    TN   7/15/1942 1:00
# 19   Bering Sea             RED          OTHER    AK  4/30/1943 23:00

# %%
# check whether the values is NaN or not
ufo.isna()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 0      False             True           False  False  False
# 1      False             True           False  False  False
# 2      False             True           False  False  False
# 3      False             True           False  False  False
# 4      False             True           False  False  False
# ...      ...              ...             ...    ...    ...
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False
#
# [18241 rows x 5 columns]

# %%
# find out how many missing values in each attribute
ufo.isna().sum()
# Out:
# City                  26
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
# list all the rows with missing values
ufo[ufo.isna().any(axis=1)]
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18235        Fountain Hills             NaN            NaN    AZ
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# 18235  12/31/2000 23:00
# 18236  12/31/2000 23:00
# 18237  12/31/2000 23:00
# 18238  12/31/2000 23:45
# 18240  12/31/2000 23:59
#
# [15755 rows x 5 columns]

# %% [markdown]
# **Note**: The ufo dataset has 18,241 rows in total, but 15,755  of them have at least one missing value. We can simply remove all of them to keep the rows with complete data for next step analysis. To keep the original data, we create a new data frame to store the subset of data rows with complete values.

# %%
# remove data rows with missing values
ufo1 = ufo.dropna()
ufo1.head(20)
# Out:
#               City Colors Reported Shape Reported State             Time
# 12          Belton             RED         SPHERE    SC  6/30/1939 20:00
# 19      Bering Sea             RED          OTHER    AK  4/30/1943 23:00
# 36      Portsmouth             RED      FORMATION    VA   7/10/1945 1:30
# 44       Blairsden           GREEN         SPHERE    CA  6/30/1946 19:00
# 82        San Jose            BLUE        CHEVRON    CA  7/15/1947 21:00
# 84         Modesto            BLUE           DISK    CA   8/8/1947 22:00
# 91          Scipio             RED         SPHERE    IN  5/10/1948 19:00
# 111   Tarrant City          ORANGE         CIRCLE    AL  8/15/1949 22:00
# 129           Napa           GREEN           DISK    CA   6/10/1950 0:00
# 138  Coeur d'Alene          ORANGE          CIGAR    ID   7/2/1950 13:00
# 152         Irving            BLUE           DISK    KS   4/15/1951 0:30
# 157     Greenville           GREEN           DISK    MS  6/15/1951 20:30
# 163    Green River           GREEN         SPHERE    WY   7/3/1951 12:00
# 164          Provo            BLUE           DISK    UT  7/10/1951 23:30
# 174     Greenville          ORANGE       TRIANGLE    TX  4/15/1952 16:00
# 178        Norfolk             RED       FIREBALL    VA   6/1/1952 22:00
# 202      Arlington           GREEN           OVAL    VA  7/13/1952 21:00
# 226      Cambridge             RED         SPHERE    MA   4/1/1953 18:00
# 229   Midwest City          YELLOW       FIREBALL    OK  4/15/1953 16:00
# 238      Cleveland             RED       FIREBALL    OH   6/30/1953 0:00

# %%
ufo1.isna().sum()
# Out:
# City               0
# Colors Reported    0
# Shape Reported     0
# State              0
# Time               0
# dtype: int64

# %% [markdown]
# In this way, only a very small part of the data is kept and we may not have enough data to work out any useful knowledge. Instead of removing all the missing values, we can replace missing parts with some specific values. For example, set them all to zero.

# %%
ufo2 = ufo.fillna(value=0)
ufo2.head(20)
# Out:
#                     City Colors Reported Shape Reported State  \
# 0                 Ithaca               0       TRIANGLE    NY
# 1            Willingboro               0          OTHER    NJ
# 2                Holyoke               0           OVAL    CO
# 3                Abilene               0           DISK    KS
# 4   New York Worlds Fair               0          LIGHT    NY
# 5            Valley City               0           DISK    ND
# 6            Crater Lake               0         CIRCLE    CA
# 7                   Alma               0           DISK    MI
# 8                Eklutna               0          CIGAR    AK
# 9                Hubbard               0       CYLINDER    OR
# 10               Fontana               0          LIGHT    CA
# 11              Waterloo               0       FIREBALL    AL
# 12                Belton             RED         SPHERE    SC
# 13                Keokuk               0           OVAL    IA
# 14             Ludington               0           DISK    MI
# 15           Forest Home               0         CIRCLE    CA
# 16           Los Angeles               0              0    CA
# 17             Hapeville               0              0    GA
# 18                Oneida               0      RECTANGLE    TN
# 19            Bering Sea             RED          OTHER    AK
#
#                 Time
# 0     6/1/1930 22:00
# 1    6/30/1930 20:00
# 2    2/15/1931 14:00
# 3     6/1/1931 13:00
# 4    4/18/1933 19:00
# 5    9/15/1934 15:30
# 6     6/15/1935 0:00
# 7     7/15/1936 0:00
# 8   10/15/1936 17:00
# 9     6/15/1937 0:00
# 10   8/15/1937 21:00
# 11    6/1/1939 20:00
# 12   6/30/1939 20:00
# 13     7/7/1939 2:00
# 14    6/1/1941 13:00
# 15    7/2/1941 11:30
# 16    2/25/1942 0:00
# 17    6/1/1942 22:30
# 18    7/15/1942 1:00
# 19   4/30/1943 23:00

# %% [markdown]
# Oops... we have nominal attributes, not numeric. Zeros do not work!!!
#
# First, let's copy the DataFrame to have a new one to work on.

# %%
ufo3 = ufo.copy()
ufo3[10:20]
# Out:
#            City Colors Reported Shape Reported State             Time
# 10      Fontana             NaN          LIGHT    CA  8/15/1937 21:00
# 11     Waterloo             NaN       FIREBALL    AL   6/1/1939 20:00
# 12       Belton             RED         SPHERE    SC  6/30/1939 20:00
# 13       Keokuk             NaN           OVAL    IA    7/7/1939 2:00
# 14    Ludington             NaN           DISK    MI   6/1/1941 13:00
# 15  Forest Home             NaN         CIRCLE    CA   7/2/1941 11:30
# 16  Los Angeles             NaN            NaN    CA   2/25/1942 0:00
# 17    Hapeville             NaN            NaN    GA   6/1/1942 22:30
# 18       Oneida             NaN      RECTANGLE    TN   7/15/1942 1:00
# 19   Bering Sea             RED          OTHER    AK  4/30/1943 23:00

# %%
ufo3['Colors Reported'].fillna('BLUE')
ufo3[10:20]
# Out:
#            City Colors Reported Shape Reported State             Time
# 10      Fontana             NaN          LIGHT    CA  8/15/1937 21:00
# 11     Waterloo             NaN       FIREBALL    AL   6/1/1939 20:00
# 12       Belton             RED         SPHERE    SC  6/30/1939 20:00
# 13       Keokuk             NaN           OVAL    IA    7/7/1939 2:00
# 14    Ludington             NaN           DISK    MI   6/1/1941 13:00
# 15  Forest Home             NaN         CIRCLE    CA   7/2/1941 11:30
# 16  Los Angeles             NaN            NaN    CA   2/25/1942 0:00
# 17    Hapeville             NaN            NaN    GA   6/1/1942 22:30
# 18       Oneida             NaN      RECTANGLE    TN   7/15/1942 1:00
# 19   Bering Sea             RED          OTHER    AK  4/30/1943 23:00

# %% [markdown]
# Why do we stil have the missing values? Nothing happened?
#
# Let's try it again:

# %%
# Change the null values with 'BLUE' in 'Colors Reported'
ufo3['Colors Reported'].fillna('BLUE', inplace=True)
ufo3[10:20]
# Out:
# /var/folders/6s/bb6mgp0x50q3fjlqfsfpffjm0000gn/T/ipykernel_68489/3793977870.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   ufo3['Colors Reported'].fillna('BLUE', inplace=True)
#            City Colors Reported Shape Reported State             Time
# 10      Fontana             NaN          LIGHT    CA  8/15/1937 21:00
# 11     Waterloo             NaN       FIREBALL    AL   6/1/1939 20:00
# 12       Belton             RED         SPHERE    SC  6/30/1939 20:00
# 13       Keokuk             NaN           OVAL    IA    7/7/1939 2:00
# 14    Ludington             NaN           DISK    MI   6/1/1941 13:00
# 15  Forest Home             NaN         CIRCLE    CA   7/2/1941 11:30
# 16  Los Angeles             NaN            NaN    CA   2/25/1942 0:00
# 17    Hapeville             NaN            NaN    GA   6/1/1942 22:30
# 18       Oneida             NaN      RECTANGLE    TN   7/15/1942 1:00
# 19   Bering Sea             RED          OTHER    AK  4/30/1943 23:00

# %% [markdown]
# ### **3.2 Create a new column**
#
# Let's create a new column with the combined City and State place names, called `place` with an empty string in every row. This isn't absolutely necessary when using proper Pandas methods but for the demonstration it will make it more straight forward.

# %%
ufo4 = ufo.copy()
ufo4['place']=''
ufo4
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time place
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...   ...
# 18236  12/31/2000 23:00
# 18237  12/31/2000 23:00
# 18238  12/31/2000 23:45
# 18239  12/31/2000 23:45
# 18240  12/31/2000 23:59
#
# [18241 rows x 6 columns]

# %% [markdown]
# **Note**: By default, the new column is always added at the end

# %% [markdown]
# Before we combine the city and state, we need to check whether there are missing values in these two columns. From above, we know the `City` column has 26 rows with missing values and the `State` is complete. So we need to fill the `City` column before merging.

# %%
ufo4['City'].fillna('No city', inplace=True)
# Out:
# /var/folders/6s/bb6mgp0x50q3fjlqfsfpffjm0000gn/T/ipykernel_68489/721252561.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   ufo4['City'].fillna('No city', inplace=True)
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: str

# %%
ufo4['place'] = ufo4['City'] + ', ' + ufo4['State']
ufo4
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time                     place
# 0        6/1/1930 22:00                Ithaca, NY
# 1       6/30/1930 20:00           Willingboro, NJ
# 2       2/15/1931 14:00               Holyoke, CO
# 3        6/1/1931 13:00               Abilene, KS
# 4       4/18/1933 19:00  New York Worlds Fair, NY
# ...                 ...                       ...
# 18236  12/31/2000 23:00            Grant Park, IL
# 18237  12/31/2000 23:00           Spirit Lake, IA
# 18238  12/31/2000 23:45           Eagle River, WI
# 18239  12/31/2000 23:45           Eagle River, WI
# 18240  12/31/2000 23:59                  Ybor, FL
#
# [18241 rows x 6 columns]

# %% [markdown]
# We can use a `for` loop to achieve the same result.
#
# Before we apply any operations that take use of index, remember to check the valid index range to avoid any errors.

# %%
ufo4.index
# Out:
# RangeIndex(start=0, stop=18241, step=1)

# %%
ufo4['address']=''
ufo4
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time                     place address
# 0        6/1/1930 22:00                Ithaca, NY
# 1       6/30/1930 20:00           Willingboro, NJ
# 2       2/15/1931 14:00               Holyoke, CO
# 3        6/1/1931 13:00               Abilene, KS
# 4       4/18/1933 19:00  New York Worlds Fair, NY
# ...                 ...                       ...     ...
# 18236  12/31/2000 23:00            Grant Park, IL
# 18237  12/31/2000 23:00           Spirit Lake, IA
# 18238  12/31/2000 23:45           Eagle River, WI
# 18239  12/31/2000 23:45           Eagle River, WI
# 18240  12/31/2000 23:59                  Ybor, FL
#
# [18241 rows x 7 columns]

# %%
for i in ufo4.index:
    # check whether the value in 'City' is null or not
    if pd.isna(ufo4.iloc[i,0]):
        print('Missing value in City')
# Out:
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City
# Missing value in City

# %%
# Using a for loop to create each entry in turn

# for i in ufo4.index:
#     ufo4.iloc[i,6] = ufo4.iloc[i,0] + ', ' + ufo4.iloc[i,3]

for i in ufo4.index:
    ufo4.iloc[i,6] = str(ufo4.iloc[i,0]) + ', ' + str(ufo4.iloc[i,3])

# %%
ufo4
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time                     place                   address
# 0        6/1/1930 22:00                Ithaca, NY                Ithaca, NY
# 1       6/30/1930 20:00           Willingboro, NJ           Willingboro, NJ
# 2       2/15/1931 14:00               Holyoke, CO               Holyoke, CO
# 3        6/1/1931 13:00               Abilene, KS               Abilene, KS
# 4       4/18/1933 19:00  New York Worlds Fair, NY  New York Worlds Fair, NY
# ...                 ...                       ...                       ...
# 18236  12/31/2000 23:00            Grant Park, IL            Grant Park, IL
# 18237  12/31/2000 23:00           Spirit Lake, IA           Spirit Lake, IA
# 18238  12/31/2000 23:45           Eagle River, WI           Eagle River, WI
# 18239  12/31/2000 23:45           Eagle River, WI           Eagle River, WI
# 18240  12/31/2000 23:59                  Ybor, FL                  Ybor, FL
#
# [18241 rows x 7 columns]

# %% [markdown]
# We have the same values in both `place` and `address`. But, which way is better?

# %% [markdown]
# ### **3.3 Timing it**
#
# The notebook's magic `%%timeit` will run the cell 1000 times and get the 3 quickest times. We can use it to record the time and then do the comparison.

# %%
ufo5 = ufo.copy()
ufo5['City'].fillna('No city', inplace=True)
ufo5
# Out:
# /var/folders/6s/bb6mgp0x50q3fjlqfsfpffjm0000gn/T/ipykernel_68489/3128832350.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   ufo5['City'].fillna('No city', inplace=True)
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# 18236  12/31/2000 23:00
# 18237  12/31/2000 23:00
# 18238  12/31/2000 23:45
# 18239  12/31/2000 23:45
# 18240  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %%
ufo5['place']=''
ufo5['address']=''
ufo5.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#   place address
# 0
# 1
# 2
# 3
# 4

# %%
# %%timeit

ufo5['place'] = ufo5['City'] + ', ' + ufo5['State']
# Out:
# 1.82 ms ± 32.5 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit

for i in ufo5.index:
    ufo5.iloc[i,6] = str(ufo5.iloc[i,0]) + ', ' + str(ufo5.iloc[i,3])
# Out:
# 834 ms ± 3.84 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# You can run the above codes many times, they may give different time, but using `for` loop is a much slower method.
#
# **Note**: Pandas is based on numpy arrays, so try everything you can to aviod iterating over rows.

# %% [markdown]
# ### **3.4 Delete columns**
#
# We only need to keep one column for merged place, we can easily drop one.

# %%
ufo5.drop(columns=['address'], inplace=True)
ufo5.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                       place
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %% [markdown]
# ---

# %% [markdown]
# ## **Task 2: Reproducing the data wrangling process**
#
# Load an `Air Crashes` data, and try to answer the following questions:
# 1. Give a summary of the data, including size, attributes, data types
# 2. Does the dataset contain missing value? What are you going to deal with them?
# 3. Check if there are any columns can be merged together? Apply the merging operation.
# 4. Remove the column(s) that contains duplicated information after merging.
# 5. Find out a subset that records air crashes with survivors.

# %%
aircrash = pd.read_csv('AirCrashes.csv')
aircrash.head()
# Out:
#            Incident American Airlines Flight 11 involving a Boeing 767-223ER in 2001
# Casualties                                     Extremely High
# Total Dead                                               1692
# Crew                                                       11
# Passengers                                                 81
# Ground                                                   1600

# %%
# Read raw file
with open("AirCrashes.csv", "r", encoding="utf-8", errors="ignore") as f:
    raw = f.read().split("\n")

# print first 10 lines
for line in raw[:20]:
    print(line)
# Out:
# Incident American Airlines Flight 11 involving a Boeing 767-223ER in 2001
# Casualties,Extremely High
# Total Dead,1692
# Crew,11
# Passengers,81
# Ground,1600
# Notes,No survivors
# Type,INH
# Reason,Attack
# Location,New York - New York - US
# Country,US
# Phase,ENR
# Date,2001-09-11
# Latitude,40.7143528
# Longitude,-74.0059731
# Circumstances,Good Visibility by Day
#
# Incident United Airlines Flight 175 involving a Boeing 767-222 in 2001
# Casualties,Extremely High

# %%
# Split blocks by empty line
blocks = []
block = []
for line in raw:
    if line.strip() == "":
        if block:
            blocks.append(block)
            block = []
    else:
        block.append(line.strip())
if block:
    blocks.append(block)

blocks[:5]  # Display the first 5 blocks for inspection
# Out:
# [['Incident American Airlines Flight 11 involving a Boeing 767-223ER in 2001',
#   'Casualties,Extremely High',
#   'Total Dead,1692',
#   'Crew,11',
#   'Passengers,81',
#   'Ground,1600',
#   'Notes,No survivors',
#   'Type,INH',
#   'Reason,Attack',
#   'Location,New York - New York - US',
#   'Country,US',
#   'Phase,ENR',
#   'Date,2001-09-11',
#   'Latitude,40.7143528',
#   'Longitude,-74.0059731',
#   'Circumstances,Good Visibility by Day'],
#  ['Incident United Airlines Flight 175 involving a Boeing 767-222 in 2001',
#   'Casualties,Extremely High',
#   'Total Dead,965',
#   'Crew,9',
#   'Passengers,56',
#   'Ground,900',
#   'Notes,No survivors',
#   'Type,INH',
#   'Reason,Attack',
#   'Location,New York - New York - US',
#   'Country,USA',
#   'Phase,ENR',
#   'Date,2001-09-11',
#   'Latitude,40.7143528',
#   'Longitude,-74.0059731',
#   'Circumstances,Good Visibility by Day'],
#  ['Incident Pan Am Flight 1736 and KLM Flight 4805 involving a Boeing 747-121 and\xa0Boeing 747-206B in 1977',
#   'Casualties,Extremely High',
#   'Total Dead,583',
#   'Crew,23',
#   'Passengers,560',
#   'Ground,0',
#   'Notes,Some survivors',
#   'Type,COM',
#   'Reason,Accident',
#   'Location,Tenerife - Spain',
#   'Country,Spain',
#   'Phase,TOF',
#   'Date,1977-03-27',
#   'Latitude,28.2915637',
#   'Longitude,-16.6291304',
#   'Circumstances,Bad Visibility by Day'],
#  ['Incident Japan Airlines Flight 123 involving a Beoing 747SR-46 in 1985',
#   'Casualties,Extremely High',
#   'Total Dead,520',
#   'Crew,15',
#   'Passengers,505',
#   'Ground,0',
#   'Notes,Some survivors',
#   'Type,COM',
#   'Reason,Accident',
#   'Location,Ueno - Japan',
#   'Country,Japan',
#   'Phase,ENR',
#   'Date,1985-08-12',
#   'Latitude,35.7089461',
#   'Longitude,139.7742683',
#   'Circumstances,Bad Visibility by Night'],
#  ['Incident Saudi Arabian Flight 763 and involving a Boeing 747-168B and\xa0Ilyushin Il-76TD in 1996',
#   'Casualties,Extremely High',
#   'Total Dead,349',
#   'Crew,33',
#   'Passengers,316',
#   'Ground,0',
#   'Notes,No survivors',
#   'Type,',
#   'Reason,Accident',
#   'Location,Charkhi Dadri - India',
#   'Country,India',
#   'Phase,ENR',
#   'Date,1996-11-12',
#   'Latitude,28.6',
#   'Longitude,76.2667',
#   'Circumstances,Bad Visibility by Night']]

# %%
# Convert each block into a dictionary
records = []
for b in blocks:
    rec = {}
    for line in b:
        if "," in line:
            key, val = line.split(",", 1)
            rec[key.strip()] = val.strip()
        else:
            # First line (incident description) without comma
            rec["Incident"] = line
    records.append(rec)

# print the first 5 records
for record in records[:5]:
    print(record)
# Out:
# {'Incident': 'Incident American Airlines Flight 11 involving a Boeing 767-223ER in 2001', 'Casualties': 'Extremely High', 'Total Dead': '1692', 'Crew': '11', 'Passengers': '81', 'Ground': '1600', 'Notes': 'No survivors', 'Type': 'INH', 'Reason': 'Attack', 'Location': 'New York - New York - US', 'Country': 'US', 'Phase': 'ENR', 'Date': '2001-09-11', 'Latitude': '40.7143528', 'Longitude': '-74.0059731', 'Circumstances': 'Good Visibility by Day'}
# {'Incident': 'Incident United Airlines Flight 175 involving a Boeing 767-222 in 2001', 'Casualties': 'Extremely High', 'Total Dead': '965', 'Crew': '9', 'Passengers': '56', 'Ground': '900', 'Notes': 'No survivors', 'Type': 'INH', 'Reason': 'Attack', 'Location': 'New York - New York - US', 'Country': 'USA', 'Phase': 'ENR', 'Date': '2001-09-11', 'Latitude': '40.7143528', 'Longitude': '-74.0059731', 'Circumstances': 'Good Visibility by Day'}
# {'Incident': 'Incident Pan Am Flight 1736 and KLM Flight 4805 involving a Boeing 747-121 and\xa0Boeing 747-206B in 1977', 'Casualties': 'Extremely High', 'Total Dead': '583', 'Crew': '23', 'Passengers': '560', 'Ground': '0', 'Notes': 'Some survivors', 'Type': 'COM', 'Reason': 'Accident', 'Location': 'Tenerife - Spain', 'Country': 'Spain', 'Phase': 'TOF', 'Date': '1977-03-27', 'Latitude': '28.2915637', 'Longitude': '-16.6291304', 'Circumstances': 'Bad Visibility by Day'}
# {'Incident': 'Incident Japan Airlines Flight 123 involving a Beoing 747SR-46 in 1985', 'Casualties': 'Extremely High', 'Total Dead': '520', 'Crew': '15', 'Passengers': '505', 'Ground': '0', 'Notes': 'Some survivors', 'Type': 'COM', 'Reason': 'Accident', 'Location': 'Ueno - Japan', 'Country': 'Japan', 'Phase': 'ENR', 'Date': '1985-08-12', 'Latitude': '35.7089461', 'Longitude': '139.7742683', 'Circumstances': 'Bad Visibility by Night'}
# {'Incident': 'Incident Saudi Arabian Flight 763 and involving a Boeing 747-168B and\xa0Ilyushin Il-76TD in 1996', 'Casualties': 'Extremely High', 'Total Dead': '349', 'Crew': '33', 'Passengers': '316', 'Ground': '0', 'Notes': 'No survivors', 'Type': '', 'Reason': 'Accident', 'Location': 'Charkhi Dadri - India', 'Country': 'India', 'Phase': 'ENR', 'Date': '1996-11-12', 'Latitude': '28.6', 'Longitude': '76.2667', 'Circumstances': 'Bad Visibility by Night'}

# %%
# Create dataframe
df = pd.DataFrame(records)
df
# Out:
#                                              Incident      Casualties  \
# 0   Incident American Airlines Flight 11 involving...  Extremely High
# 1   Incident United Airlines Flight 175 involving ...  Extremely High
# 2   Incident Pan Am Flight 1736 and KLM Flight 480...  Extremely High
# 3   Incident Japan Airlines Flight 123 involving a...  Extremely High
# 4   Incident Saudi Arabian Flight 763 and involvin...  Extremely High
# 5   Incident Turkish Airlines Flight 981 involving...  Extremely High
# 6   Incident Air India Flight 182 involving a Boei...  Extremely High
# 7   Incident Saudia Flight 163 involving a Lockhee...  Extremely High
# 8   Incident Iran Air Flight 655 involving a Airbu...  Extremely High
# 9   Incident Iranian Air Force (15-2280) involving...  Extremely High
# 10  Incident American Airlines Flight 191 involvin...  Extremely High
# 11  Incident Pan Am Flight 103 involving a Boeing ...  Extremely High
# 12  Incident Korean Air Lines Flight 007 involving...  Extremely High
# 13  Incident American Airlines Flight 587 involvin...  Extremely High
# 14  Incident China Airlines Flight 140 involving a...  Extremely High
# 15  Incident Nigeria Airways Flight 2120 involving...  Extremely High
# 16  Incident Air New Zealand Flight 901 involving ...  Extremely High
# 17  Incident Arrow Air Flight 1285 involving a Dou...  Extremely High
# 18  Incident African Air (RA-26222) involving a An...  Extremely High
# 19  Incident Garuda Indonesia Flight 152 involving...  Extremely High
# 20  Incident TWA Flight 800 involving a Boeing 747...  Extremely High
# 21  Incident Swissair Flight 111 involving a McDon...  Extremely High
# 22  Incident Air France Flight 447 involving a Air...  Extremely High
# 23  Incident Korean Air Flight 801 involving a Boe...  Extremely High
# 24  Incident China Airlines Flight 611 involving a...  Extremely High
# 25  Incident Lauda Air Flight 004 involving a Boei...  Extremely High
# 26  Incident EgyptAir Flight 990 involving a Boein...  Extremely High
# 27  Incident Air India Flight 855 involving a Boei...  Extremely High
# 28  Incident China Airlines Flight 676 involving a...  Extremely High
# 29  Incident Aeroflot Flight 7425 involving a Tupo...  Extremely High
# 30  Incident TAM Airlines Flight 3054 involving a ...  Extremely High
# 31  Incident Martinair Holland Flight 138 involvin...  Extremely High
# 32  Incident American Airlines Flight 77 involving...  Extremely High
# 33  Incident Alas Nacionales Flight 301 involving ...  Extremely High
# 34  Incident Alia Royal Jordanian (JY-AEE) involvi...  Extremely High
# 35  Incident LOT Flight 5055 involving a Ilyushin ...  Extremely High
# 36  Incident Icelandic Airlines Flight LL 001 invo...  Extremely High
# 37  Incident Avianca Flight 011 involving a Boeing...  Extremely High
# 38  Incident Inex-Adria Aviopromet Flight 1308 inv...  Extremely High
# 39  Incident Aeroflot Flight 3352 involving a Tupo...  Extremely High
# 40  Incident Aeroflot/Moldovia (CCCP-65816) involv...  Extremely High
# 41  Incident British Airways Flight 476 and involv...  Extremely High
# 42  Incident Surinam Airways Flight 764 involving ...  Extremely High
# 43  Incident Nigeria Airways (JY-ADO) involving a ...  Extremely High
# 44  Incident Aeroflot Flight 217 involving a Ilyus...  Extremely High
# 45  Incident Cubana de Aviación Flight 9646 involv...  Extremely High
# 46  Incident Pulkovo Flight 612 involving a Tupole...  Extremely High
# 47  Incident Union de Transportes Aériens Flight 7...  Extremely High
# 48  Incident Kenya Airways Flight 431 involving a ...  Extremely High
# 49  Incident Caspian Airlines Flight 7908 involvin...  Extremely High
# 50  Incident Pakistan International Airlines Fligh...  Extremely High
# 51  Incident Mexicana Flight 940 involving a Boein...  Extremely High
# 52  Incident Aeroflot Flight 4227 involving a Tupo...  Extremely High
# 53  Incident Dana Air Flight 992 involving a McDon...  Extremely High
# 54  Incident All Nippon Airways Flight 58 and invo...  Extremely High
# 55  Incident West Caribbean Airways Flight 708 inv...  Extremely High
# 56  Incident China Northwest Airlines Flight 2303 ...  Extremely High
# 57  Incident American Airlines Flight 965 involvin...  Extremely High
#
#    Total Dead Crew Passengers Ground           Notes Type    Reason  \
# 0        1692   11         81   1600    No survivors  INH    Attack
# 1         965    9         56    900    No survivors  INH    Attack
# 2         583   23        560      0  Some survivors  COM  Accident
# 3         520   15        505      0  Some survivors  COM  Accident
# 4         349   33        316      0    No survivors       Accident
# 5         346   11        335      0    No survivors  COM  Accident
# 6         329   22        307      0    No survivors  INB    Attack
# 7         301   14        287      0    No survivors  COM  Accident
# 8         290   16        274      0    No survivors  EXG    Attack
# 9         275   18        257      0    No survivors  MIL  Accident
# 10        273   13        258      2    No survivors  COM  Accident
# 11        270   16        243     11    No survivors  INB    Attack
# 12        269   23        246      0    No survivors  EXS    Attack
# 13        265    9        251      5    No survivors  COM  Accident
# 14        264   15        249      0  Some survivors  COM  Accident
# 15        261   14        247      0    No survivors  COM  Accident
# 16        257   20        237      0    No survivors  COM  Accident
# 17        256    8        248      0    No survivors  COM  Accident
# 18         37    0          0    237  Some survivors  COM  Accident
# 19        234   12        222      0    No survivors  COM  Accident
# 20        230   18        212      0    No survivors  COM  Accident
# 21        229   14        215      0    No survivors  COM  Accident
# 22        228   12        216      0    No survivors  COM  Accident
# 23        228   22        206      0  Some survivors  COM  Accident
# 24        225   19        206      0    No survivors  COM  Accident
# 25        223   10        213      0    No survivors  COM  Accident
# 26        217   15        202      0    No survivors  COM  Accident
# 27        213   23        190      0    No survivors  COM  Accident
# 28        202   14        182      7    No survivors  COM  Accident
# 29          0    9        191      0    No survivors  COM  Accident
# 30        199    6        181     12    No survivors  COM  Accident
# 31        191    9        182      0    No survivors  COM  Accident
# 32        189    6         64    125    No survivors  INH    Attack
# 33        189   13        176      0    No survivors  COM  Accident
# 34        188    7        181      0    No survivors  COM  Accident
# 35        183   11        172      0    No survivors  COM  Accident
# 36        183    8        175      0  Some survivors  COM  Accident
# 37        181             162      0  Some survivors  COM  Accident
# 38        180    7        173      0    No survivors  COM  Accident
# 39        178    5        169      4  Some survivors  COM  Accident
# 40        178   13        165      0    No survivors  COM  Accident
# 41        177   14        162      1    No survivors  COM  Accident
# 42        176    9        167      0    No survivors  COM  Accident
# 43        176    6        170      0  Some survivors  COM  Accident
# 44        174   10        164      0    No survivors  COM  Accident
# 45        171   11        115     45    No survivors  COM  Accident
# 46        170   10        160      0    No survivors  COM  Accident
# 47        170   14        156      0    No survivors  INB    Attack
# 48        169   10        159      0  Some survivors  COM  Accident
# 49        168   12        156      0    No survivors  COM  Accident
# 50        167   12        155      0    No survivors  COM  Accident
# 51        167    8        159      0    No survivors  COM  Accident
# 52        166   10        156      0    No survivors  COM  Accident
# 53        163    6        147     10    No survivors  COM  Accident
# 54        162    7        155      0    One survivor  COM  Accident
# 55        160    8        152      0    No survivors  COM  Accident
# 56        150   14        146      0    No survivors  COM  Accident
# 57        159    8        151      0  Some survivors  COM  Accident
#
#                                              Location             Country  \
# 0                            New York - New York - US                  US
# 1                            New York - New York - US                 USA
# 2                                    Tenerife - Spain               Spain
# 3                                        Ueno - Japan               Japan
# 4                               Charkhi Dadri - India               India
# 5                           Fontaine-Chaalis - France              France
# 6                     Atlantic Ocean - Cork - Ireland             Ireland
# 7                               Riyadh - Saudi Arabia        Saudi Arabia
# 8                             Strait of Hormuz - Iran                Iran
# 9                                       Kerman - Iran                Iran
# 10                        Des Plaines - Illinois - US                  US
# 11                          Lockerbie - Scotland - UK                  UK
# 12             Sea of Japan - Moneron Island - Russia              Russia
# 13                       Belle Harbor - New York - US                  US
# 14                                     Komaki - Japan               Japan
# 15                              Jeddah - Saudi Arabia        Saudi Arabia
# 16                            Mt. Erebus - Antarctica          Antarctica
# 17                              Gander - NL. - Canada              Canada
# 18                                Kinshasa - DR Congo            DR Congo
# 19                                  Medan - Indonesia           Indonesia
# 20     Atlantic Ocean - East Moriches - New York - US                  US
# 21       Atlantic Ocean - Peggys Cove - N.S. - Canada              Canada
# 22                         Atlantic Ocean - Sao Pedro           Sao Pedro
# 23                                   Asan - Guam - US                  US
# 24             Taiwan Strait - Penghu Islands - China               China
# 25                  Phu Toei National Park - Thailand            Thailand
# 26    Atlantic Ocean - Nantucket - Massachusetts - US                  US
# 27                      Arabian Sea -  Mumbai - India               India
# 28                            Dayuan - Taiwan - China               China
# 29                              Uchkuduk - Uzbekistan          Uzbekistan
# 30                                 Sao Paulo - Brazil              Brazil
# 31                              Maskeliya - Sri Lanka           Sri Lanka
# 32                          Arlington - Virginia - US                  US
# 33  Atlantic Ocean - Puerto Plata - Dominican Repu...  Dominican Republic
# 34                                    Tamri - Morocco             Morocco
# 35                                    Warsaw - Poland              Poland
# 36                             Katunayake - Sri Lanka           Sri Lanka
# 37                                     Madrid - Spain               Spain
# 38  Mt. San Pietro - Petreto-Bicchisano - Corsica ...              France
# 39                                      Omsk - Russia              Russia
# 40                                Saykyn - Kazakhstan          Kazakhstan
# 41                                  Vrbovec - Croatia             Croatia
# 42                               Paramaribo - Surinam             Surinam
# 43                                     Kano - Nigeria             Nigeria
# 44                                    Moscow - Russia              Russia
# 45                                      Havana - Cuba                Cuba
# 46               Novoselivka - Donetsk Obl. - Ukraine             Ukraine
# 47                                     Tenere - Niger               Niger
# 48                    Gulf of Guinea -  Cote d'Ivoire       Cote d'Ivoire
# 49                                      Qazvin - Iran                Iran
# 50                                  Kathmandu - Nepal               Nepal
# 51           Sierra Madre Oriental Mountains - Mexico              Mexico
# 52                                Almaty - Kazakhstan          Kazakhstan
# 53                                    Lagos - Nigeria             Nigeria
# 54                                Shizukuishi - Japan               Japan
# 55                              Machiques - Venezuela           Venezuela
# 56                                       Xian - China               China
# 57                                    Buga - Colombia            Colombia
#
#    Phase        Date      Latitude     Longitude            Circumstances
# 0    ENR  2001-09-11    40.7143528   -74.0059731   Good Visibility by Day
# 1    ENR  2001-09-11    40.7143528   -74.0059731   Good Visibility by Day
# 2    TOF  1977-03-27    28.2915637   -16.6291304    Bad Visibility by Day
# 3    ENR  1985-08-12    35.7089461   139.7742683  Bad Visibility by Night
# 4    ENR  1996-11-12          28.6       76.2667  Bad Visibility by Night
# 5    ENR  1974-03-03     49.171795      2.684157  Bad Visibility by Night
# 6    ENR  1985-06-23    51.8968917    -8.4863157  Bad Visibility by Night
# 7    ENR  1980-08-19    24.7116667    46.7241667  Bad Visibility by Night
# 8    ENR  1988-07-03    26.5944754    56.4719928  Bad Visibility by Night
# 9    ENR  2003-02-19      30.28027      57.06702  Bad Visibility by Night
# 10   TOF  1979-05-25    42.0333623   -87.8833991  Bad Visibility by Night
# 11   ENR  1988-12-21     55.122245     -3.349008  Bad Visibility by Night
# 12   ENR  1983-09-01         46.25   141.2333333  Bad Visibility by Night
# 13   ENR  2001-11-12    40.5759385   -73.8481906  Bad Visibility by Night
# 14   APR  1994-04-26    35.2903104   136.9109515  Bad Visibility by Night
# 15   APR  1991-07-11    21.5433333    39.1727778  Bad Visibility by Night
# 16   ENR  1979-11-28   -77.5310559   167.0757008  Bad Visibility by Night
# 17   ICL  1985-12-12     48.954408   -54.6103488  Bad Visibility by Night
# 18   ICL  1996-01-08    -4.3316667    15.3138889  Bad Visibility by Night
# 19   APR  1997-09-26      3.585242    98.6755979  Bad Visibility by Night
# 20   ENR  1996-07-17    40.8050989   -72.7609336  Bad Visibility by Night
# 21   ENR  1998-09-02    44.4927778      -63.9175    Bad Visibility by Day
# 22   ENR  2009-06-01     03.065833    -30.561667  Bad Visibility by Night
# 23   APR  1997-08-06    13.4666808   144.7454685  Bad Visibility by Night
# 24   ENR  2002-05-25       23.5025   119.5052778  Bad Visibility by Night
# 25   ENR  1991-05-26    14.9413999    99.4490951  Bad Visibility by Night
# 26   ENR  1999-10-31    41.2834704    -70.099451  Bad Visibility by Night
# 27   ENR  1978-01-01    19.0759837    72.8776559  Bad Visibility by Night
# 28   APR  1998-02-16    25.0492632    121.193945  Bad Visibility by Night
# 29   ENR  1985-07-10    42.1566667    63.5555556  Bad Visibility by Night
# 30   LDG  2007-07-17   -23.5489433   -46.6388182  Bad Visibility by Night
# 31   ENR  1974-12-04     6.8329294    80.5709256  Bad Visibility by Night
# 32   ENR  2001-09-11    38.8799697   -77.1067698    Bad Visibility by Day
# 33   ENR  1996-02-06    19.7807686   -70.6871091  Bad Visibility by Night
# 34   ENR  1975-08-03    30.6981676    -9.8208632  Bad Visibility by Night
# 35   ENR  1987-05-09    52.2296756    21.0122287  Bad Visibility by Night
# 36   APR  1978-11-15     7.1696231    79.8912813  Bad Visibility by Night
# 37   APR  1983-11-27    40.4167754    -3.7037902  Bad Visibility by Night
# 38   ENR  1981-12-01    41.7588889     8.9916667  Bad Visibility by Night
# 39   LDG  1984-10-11    54.9666667    73.3833333  Bad Visibility by Night
# 40   ENR  1979-08-11       48.8125    46.7636111  Bad Visibility by Night
# 41   ENR  1976-09-10    45.8839523     16.416766  Bad Visibility by Night
# 42   APR  1989-06-07      5.823201     -55.16788    Bad Visibility by Day
# 43   LDG  1973-01-22            12      8.516667    Bad Visibility by Day
# 44   APR  1972-10-13     55.755826       37.6173    Bad Visibility by Day
# 45   ICL  1989-09-03       23.1168    -82.388557    Bad Visibility by Day
# 46   ENR  2006-08-22    49.0702778    37.6913889  Bad Visibility by Night
# 47   ENR  1989-19-09    18.9546137    10.9134609  Bad Visibility by Night
# 48   ENR  2000-01-30     3.7355442      3.743509  Bad Visibility by Night
# 49   ENR  2009-07-15     36.266819     50.003811  Bad Visibility by Night
# 50   APR  1992-09-28          27.7    85.3333333  Bad Visibility by Night
# 51   ENR  1986-03-31  -100.4233685  -100.4233685  Bad Visibility by Night
# 52   ENR  1890-07-08     43.255058     76.912628  Bad Visibility by Night
# 53   APR  2012-06-03      6.441158      3.417977  Bad Visibility by Night
# 54   ENR  1971-07-30    39.6962875   140.9757756  Bad Visibility by Night
# 55   ENR  2005-08-16      10.06592    -72.551872  Bad Visibility by Night
# 56   ENR  1984-06-06     34.341568    108.940175  Bad Visibility by Night
# 57   APR  1995-12-20           3.9         -76.3  Bad Visibility by Night

# %%
# check missing values
df.isnull().sum()
# Out:
# Incident         0
# Casualties       0
# Total Dead       0
# Crew             0
# Passengers       0
# Ground           0
# Notes            0
# Type             0
# Reason           0
# Location         0
# Country          0
# Phase            0
# Date             0
# Latitude         0
# Longitude        0
# Circumstances    0
# dtype: int64

# %%
df.iloc[37]['Crew']
# Out:
# ''

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Incident       58 non-null     str
#  1   Casualties     58 non-null     str
#  2   Total Dead     58 non-null     str
#  3   Crew           58 non-null     str
#  4   Passengers     58 non-null     str
#  5   Ground         58 non-null     str
#  6   Notes          58 non-null     str
#  7   Type           58 non-null     str
#  8   Reason         58 non-null     str
#  9   Location       58 non-null     str
#  10  Country        58 non-null     str
#  11  Phase          58 non-null     str
#  12  Date           58 non-null     str
#  13  Latitude       58 non-null     str
#  14  Longitude      58 non-null     str
#  15  Circumstances  58 non-null     str
# dtypes: str(16)
# memory usage: 7.4 KB

# %%
def clean_and_infer(df: pd.DataFrame) -> pd.DataFrame:
    out = df.copy()

    # 去掉字符串列首尾空白
    for col in out.select_dtypes(include="object").columns:
        out[col] = out[col].str.strip()

    # 转日期
    if "Date" in out.columns:
        out["Date"] = pd.to_datetime(out["Date"], errors="coerce")

    # 转整数（可空 Int64）
    for col in ["Total Dead", "Crew", "Passengers", "Ground"]:
        if col in out.columns:
            out[col] = pd.to_numeric(out[col], errors="coerce").astype("Int64")

    # 转浮点（Float64）
    for col in ["Latitude", "Longitude"]:
        if col in out.columns:
            out[col] = pd.to_numeric(out[col], errors="coerce").astype("Float64")

    return out

df = clean_and_infer(df)

df.dtypes
# Out:
# /var/folders/6s/bb6mgp0x50q3fjlqfsfpffjm0000gn/T/ipykernel_68489/898140417.py:5: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   for col in out.select_dtypes(include="object").columns:
# Incident                    str
# Casualties                  str
# Total Dead                Int64
# Crew                      Int64
# Passengers                Int64
# Ground                    Int64
# Notes                       str
# Type                        str
# Reason                      str
# Location                    str
# Country                     str
# Phase                       str
# Date             datetime64[us]
# Latitude                Float64
# Longitude               Float64
# Circumstances               str
# dtype: object

# %%
df.isnull().sum()
# Out:
# Incident         0
# Casualties       0
# Total Dead       0
# Crew             1
# Passengers       0
# Ground           0
# Notes            0
# Type             0
# Reason           0
# Location         0
# Country          0
# Phase            0
# Date             1
# Latitude         0
# Longitude        0
# Circumstances    0
# dtype: int64

# %% [markdown]
# pandas.DataFrame.isnull()（或者 df.isna()）默认只会把 真正的缺失值（NaN, None, NaT 等）当作缺失，不会把空字符串 "" 识别为缺失。

# %%
dft = pd.DataFrame({
    "a": [1, np.nan, ""]
})

print(dft.isnull())
# Out:
#        a
# 0  False
# 1   True
# 2  False

# %%
# handle missing values
# first see those rows
df[df.isnull().any(axis=1)]
# Out:
#                                              Incident      Casualties  \
# 37  Incident Avianca Flight 011 involving a Boeing...  Extremely High
# 47  Incident Union de Transportes Aériens Flight 7...  Extremely High
#
#     Total Dead  Crew  Passengers  Ground           Notes Type    Reason  \
# 37         181  <NA>         162       0  Some survivors  COM  Accident
# 47         170    14         156       0    No survivors  INB    Attack
#
#           Location Country Phase       Date   Latitude  Longitude  \
# 37  Madrid - Spain   Spain   APR 1983-11-27  40.416775   -3.70379
# 47  Tenere - Niger   Niger   ENR        NaT  18.954614  10.913461
#
#               Circumstances
# 37  Bad Visibility by Night
# 47  Bad Visibility by Night

# %%
df[df.isnull().any(axis=1)].loc[df["Incident"].str.contains("Boeing", na=False), "Incident"].tolist()
# Out:
# ['Incident Avianca Flight 011 involving a Boeing 747-283B in 1983']

# %%
# find incident include Boeing
df[df["Incident"].str.contains("Boeing 747", na=False)][["Incident", "Crew"]]
# Out:
#                                              Incident  Crew
# 2   Incident Pan Am Flight 1736 and KLM Flight 480...    23
# 4   Incident Saudi Arabian Flight 763 and involvin...    33
# 6   Incident Air India Flight 182 involving a Boei...    22
# 11  Incident Pan Am Flight 103 involving a Boeing ...    16
# 12  Incident Korean Air Lines Flight 007 involving...    23
# 20  Incident TWA Flight 800 involving a Boeing 747...    18
# 23  Incident Korean Air Flight 801 involving a Boe...    22
# 24  Incident China Airlines Flight 611 involving a...    19
# 27  Incident Air India Flight 855 involving a Boei...    23
# 37  Incident Avianca Flight 011 involving a Boeing...  <NA>

# %%
# simply remove the rows with missing values
df = df.dropna()
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Incident, Casualties, Total Dead, Crew, Passengers, Ground, Notes, Type, Reason, Location, Country, Phase, Date, Latitude, Longitude, Circumstances]
# Index: []

# %%
# 3. Check if there are any columns can be merged together? Apply the merging operation.
if "Crew" in df.columns and "Passengers" in df.columns:
    df["Total"] = df["Crew"] + df["Passengers"]
    # 4. Remove the column(s) that contains duplicated information after merging.
    df.drop(columns=["Crew", "Passengers"], inplace=True)

df.head()
# Out:
#                                             Incident      Casualties  \
# 0  Incident American Airlines Flight 11 involving...  Extremely High
# 1  Incident United Airlines Flight 175 involving ...  Extremely High
# 2  Incident Pan Am Flight 1736 and KLM Flight 480...  Extremely High
# 3  Incident Japan Airlines Flight 123 involving a...  Extremely High
# 4  Incident Saudi Arabian Flight 763 and involvin...  Extremely High
#
#    Total Dead  Ground           Notes Type    Reason  \
# 0        1692    1600    No survivors  INH    Attack
# 1         965     900    No survivors  INH    Attack
# 2         583       0  Some survivors  COM  Accident
# 3         520       0  Some survivors  COM  Accident
# 4         349       0    No survivors       Accident
#
#                    Location Country Phase       Date   Latitude   Longitude  \
# 0  New York - New York - US      US   ENR 2001-09-11  40.714353  -74.005973
# 1  New York - New York - US     USA   ENR 2001-09-11  40.714353  -74.005973
# 2          Tenerife - Spain   Spain   TOF 1977-03-27  28.291564   -16.62913
# 3              Ueno - Japan   Japan   ENR 1985-08-12  35.708946  139.774268
# 4     Charkhi Dadri - India   India   ENR 1996-11-12       28.6     76.2667
#
#              Circumstances  Total
# 0   Good Visibility by Day     92
# 1   Good Visibility by Day     65
# 2    Bad Visibility by Day    583
# 3  Bad Visibility by Night    520
# 4  Bad Visibility by Night    349

# %%
# 5. Find out a subset that records air crashes with survivors.
df_survivors = df[df["Total"] > df["Total Dead"]]
df_survivors
# Out:
#                                              Incident      Casualties  \
# 29  Incident Aeroflot Flight 7425 involving a Tupo...  Extremely High
# 56  Incident China Northwest Airlines Flight 2303 ...  Extremely High
#
#     Total Dead  Ground         Notes Type    Reason               Location  \
# 29           0       0  No survivors  COM  Accident  Uchkuduk - Uzbekistan
# 56         150       0  No survivors  COM  Accident           Xian - China
#
#        Country Phase       Date   Latitude   Longitude  \
# 29  Uzbekistan   ENR 1985-07-10  42.156667   63.555556
# 56       China   ENR 1984-06-06  34.341568  108.940175
#
#               Circumstances  Total
# 29  Bad Visibility by Night    200
# 56  Bad Visibility by Night    160
