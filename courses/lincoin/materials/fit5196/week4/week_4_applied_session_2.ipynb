# %% [markdown]
# # **Week 4 Applied Session: Data Parsing**

# %%
# ignore FutureWarning, UserWarning
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %% [markdown]
# ## **1. Parsing Excel Files**
#
# We will provide some generic instructions on how to scrape data from excel files this week. In this circumstance, data is generated purely for human consumption.
# The person who generated the data often tries to make it easily readable for human,
# disregarding the importance of releasing it in a machine readable format.
# You will find that the scraping process becomes much more difficult and time-consuming comparing with dealing with machine readable files, e.g. JSON, CSV, XML.
# But the ultimate goal stays the same, i.e., <font color = "red"> extracting data and converting it into a machine readable format</font>.
# * * *
#
# ### 1.1 Introduction to Excel
#
# Excel is a popular spreadsheet application originally
# developed for Windows.
# You can also find free alternatives that run on Mac OS and Linux,
# for example, LibreOffice Calc and OpenOffice Calc can both work with Excel files.
# An Excel document is also called a workbook.
# It is usually saved in a file with either .xlsx extension or .xls extension,
# depending on the Excel version you use.
# A workbook can contain multiple worksheets, each of which is a grid of cells
# where you keep and manipulate the data.
# Those cells are arranged in numbered rows and letter-named columns.
# Excel can display not only tabular data but also data like line graphs, histograms and charts.
# It also provides a set of data analysis functions for statistical, engineering and financial needs.
# Presumably, most of you know what a Excel file looks like.
# If not, please find some Excel files online and have a look or open the Excel file used in this tutorial.
#
# There are many ways of manipulating data stored in Excel spreadsheets.
# For instance,
# "[Working with Excel Files in Python](http://www.python-excel.org/)" contains pointers to
# the best information available about working with Excel files in Python.
# The website lists the following Python packages that deal with Excel:
#
# * `openpyxl`: Reads/writes Excel 2010 xlsx/xlsm/xltx/xltm files.
# * `xlsxwriter`: write text, numbers, formulas and hyperlinks to multiple worksheets in an Excel 2007+ XLSX file.
# * `xlrd`: Extracts data from Excel files (.xls and .xlsx, versions 2.0 onwards).
# * `xlwt`: Writes and formats Excel files compatible with Microsoft Excel versions 95 to 2003.
# * `xlutils`: Contains a set of advanced tools for manipulating Excel files (requires `xlrd` and `xlwt`).
#
# You would need to install each separately if you want to use them;
# however, in this tutorial we will use Pandas `ExcelFile` class that requires `xlrd` to demonstrate how to
# parse Excel files.
#
# Some tutorials on working with Excel files that might be of your interest:
# * [Working with Excel Spreadsheets](https://automatetheboringstuff.com/chapter12/): It utilizes openyxl to read
# data from spreadsheets. Read the following sections:
#     * Reading Excel Documents 📖
#     * Project: Reading Data from a Spreadsheet 📖
# * [How to read Excel files with Python (xlrd tutorial)](https://www.youtube.com/watch?v=p0DNcTnreuY):
# a Youtube video on extracting data from a simple Excel file. (Optional)
#
#
# This tutorial will use a running example to show
# you how to extract data from Excel spreadsheets step-by-step using Pandas.
# The example we use in this tutorial is "[Table 2: Nutrition](https://data.unicef.org/resources/state-worlds-children-2016-statistical-tables/)" from Unicef's report on
# [The State of the Worlds Children](https://www.unicef.org/reports/state-worlds-children-2014) for 2014.
#
#
# * <font color = "red"> Note: </font>
#     * <font color = "red">Our task is to extract the statistic data table on the child's issues of
# underweight, stunting, wasting and overweight prevalence in different countries.</font>
#
#     * <font color = "red">Link for Table 2 data is related to the 2016 dataset. However, We will be using 2014 dataset which is provided in the zip folder.</font>
# * * *

# %% [markdown]
# ### 1.2 Parsing Excel with Pandas
# In this section we will walk through the process of parsing our example Excel file with Pandas.
# A short tutorial on how to use Pandas `read_excel` function and the ExcelFile class  can
# be found at Pandas [webpage on IO](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html). 📖  (Just read the section "Reading Excel Files".)
#
# Before we start parsing our Excel file,
# we need to first make sure the Python package `xlrd` is installed,
# as Pandas `ExcelFile` class makes use of `xlrd`.
# The `xlrd` package can be run on Linux and Mac as well as Windows.
# Here we assume you use either Linux or Mac.
# If you use Anaconda, you do not need to worry about this,
# as Anaconda includes the most popular Python packages for data analysis, including `xlrd`.
# Otherwise, you might need to install `xlrd` in order to run `read_excel`.
# To install `xlrd`, you can use [pip](https://pypi.python.org/pypi/pip),
# a Python package management system.
# In your command line, simply type
# ```shell
#     pip install xlrd
# ```
#
# Now to start our script,
# we need to import Pandas
# and open our Excel file by creating a Pandas `ExcelFile` object.

# %%
# install xlrd package
# !pip install xlrd
# !pip install openpyxl

# %%
import pandas as pd

excel_data = pd.ExcelFile("SOWC 2014 Stat Tables_Table 2.xlsx")

# %% [markdown]
# By running the code above, we have loaded the Excel file as a Pandas' ExcelFile object into Python.
#
# Are we ready to parse our Excel File? Before starting to parse the file,
# we probably need to ask ourselves a couple of questions. For instance,
# <font color = "red">
# * How many sheets does our Excel file have?
# * Which data sheet does contain our data? What is the name of the sheet? Or what is the index of the sheet?
#  </font>

# %% [markdown]
# Unlike CSV files, an Excel file can have multiple worksheets.
# For example, our Excel file contains two worksheets, one contains data notes,
# and the other contains the data we want.
# In order to get our data, we will just pull the sheet with the data we want.
#
# If your Excel file has a couple of worksheets and you can guess the index of
# the worksheet that contains the data you want, or you have been told from which
# worksheet you are going to extract data, you can directly use Panda's
# [`read_excel`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html#pandas.read_excel)
# fuction
# ```python
#     pandas.read_excel()
# ```
# This function reads an Excel table in a given worksheet into a Pandas DataFrame,
# where you can start further manipulating the data.
#
# However, in some cases, particularly while an Excel file has a lot of worksheets,
# it might be good to view all the sheets by their names.
# So, let's check out what the names of the sheets we have in our Excel file are:

# %%
# show the names of all the sheets

excel_data.sheet_names
# Out:
# ['Data Notes', 'Table 2 ']

# %% [markdown]
# There are two worksheets in our Excel file.
# The one that we are looking for is "Table 2 ".
# So, let's read the second worksheet into a Pandas DataFrame.
# Note that <font color = "red"> there is an extra space in the worksheet name </font>.
# Without this space, running the following parsing code
# will result in the following error
# ```
#     XLRDError: No sheet named <'Table 2'>
# ```

# %%
try:
    # parse the first sheet and show the first 5 rows
    df = excel_data.parse('Table 2')
except Exception as e:
    print(e)
# Out:
# Worksheet named 'Table 2' not found

# %%
# excel_data is an excel object
# after use the parse function, the result is a dataframe
df = excel_data.parse('Table 2 ')
df.head(30)
# Out:
#     Unnamed: 0   TABLE 2. NUTRITION            Unnamed: 2  \
# 0          NaN                  NaN  TABLEAU 2. NUTRITION
# 1          NaN                  NaN                   NaN
# 2          NaN                  NaN                   NaN
# 3          NaN  Countries and areas                   NaN
# 4          NaN                  NaN                   NaN
# 5          NaN                  NaN                   NaN
# 6          NaN                  NaN                   NaN
# 7          NaN      FRENCH HEADINGS         Pays et zones
# 8          NaN                  NaN                   NaN
# 9          NaN                  NaN                   NaN
# 10         NaN                  NaN                   NaN
# 11         NaN     SPANISH HEADINGS                   NaN
# 12         NaN                  NaN                   NaN
# 13         NaN                  NaN                   NaN
# 14         NaN                  NaN                   NaN
# 15         NaN                  NaN  FRENCH COUNTRY NAMES
# 16         NaN          Afghanistan           Afghanistan
# 17         NaN              Albania               Albanie
# 18         NaN              Algeria               Algérie
# 19         NaN              Andorra               Andorre
# 20         NaN               Angola                Angola
# 21         NaN  Antigua and Barbuda    Antigua-et-Barbuda
# 22         NaN            Argentina             Argentine
# 23         NaN              Armenia               Arménie
# 24         NaN            Australia             Australie
# 25         NaN              Austria              Autriche
# 26         NaN           Azerbaijan           Azerbaïdjan
# 27         NaN              Bahamas               Bahamas
# 28         NaN              Bahrain               Bahreïn
# 29         NaN           Bangladesh            Bangladesh
#
#                Unnamed: 3                                      Unnamed: 4  \
# 0                     NaN                                             NaN
# 1      TABLA 2. NUTRICIÓN                                             NaN
# 2                     NaN                                             NaN
# 3                     NaN                             Low birthweight (%)
# 4                     NaN                                             NaN
# 5                     NaN                                             NaN
# 6                     NaN                                      2008–2012*
# 7                     NaN  Insuffisance\npondérale à la\nnaissance\n(%)\n
# 8                     NaN                                             NaN
# 9                     NaN                                             NaN
# 10                    NaN                                      2008–2012*
# 11         Países y zonas                         Bajo peso al nacer (%)
# 12                    NaN                                             NaN
# 13                    NaN                                             NaN
# 14                    NaN                                      2008–2012*
# 15  SPANISH COUNTRY NAMES                                             NaN
# 16             Afganistán                                               –
# 17                Albania                                             3.6
# 18                Argelia                                               6
# 19                Andorra                                               –
# 20                 Angola                                              12
# 21      Antigua y Barbuda                                               5
# 22              Argentina                                             7.2
# 23                Armenia                                               8
# 24              Australia                                               7
# 25                Austria                                               7
# 26             Azerbaiyán                                              10
# 27                Bahamas                                              11
# 28                Bahrein                                               –
# 29             Bangladesh                                              22
#
#    Unnamed: 5                                      Unnamed: 6 Unnamed: 7  \
# 0         NaN                                             NaN        NaN
# 1         NaN                                             NaN        NaN
# 2         NaN                                             NaN        NaN
# 3         NaN           Early initiation of breastfeeding (%)        NaN
# 4         NaN                                             NaN        NaN
# 5         NaN                                             NaN        NaN
# 6         NaN                                      2008–2012*        NaN
# 7         NaN      Initiation\nprécoce de\nl’allaitement\n(%)        NaN
# 8         NaN                                             NaN        NaN
# 9         NaN                                             NaN        NaN
# 10        NaN                                      2008−2012*        NaN
# 11        NaN  Iniciación temprana a la lactancia materna (%)        NaN
# 12        NaN                                             NaN        NaN
# 13        NaN                                             NaN        NaN
# 14        NaN                                      2008−2012*        NaN
# 15        NaN                                             NaN        NaN
# 16        NaN                                               –        NaN
# 17        NaN                                            42.9        NaN
# 18          x                                            49.5          x
# 19        NaN                                               –        NaN
# 20          x                                            54.9          x
# 21          x                                               –        NaN
# 22        NaN                                               –        NaN
# 23        NaN                                            35.7        NaN
# 24          x                                               –        NaN
# 25          x                                               –        NaN
# 26          x                                            31.9          x
# 27          x                                               –        NaN
# 28        NaN                                               –        NaN
# 29          x                                            47.1        NaN
#
#                                           Unnamed: 8 Unnamed: 9  ...  \
# 0                                                NaN        NaN  ...
# 1                                                NaN        NaN  ...
# 2                                                NaN        NaN  ...
# 3             Exclusive breastfeeding\n<6 months (%)        NaN  ...
# 4                                                NaN        NaN  ...
# 5                                                NaN        NaN  ...
# 6                                                NaN        NaN  ...
# 7   Allaitement\nexclusivement\nau sein <6 mois\n(%)        NaN  ...
# 8                                                NaN        NaN  ...
# 9                                                NaN        NaN  ...
# 10                                               NaN        NaN  ...
# 11         Lactancia materna exclusiva\n<6 meses (%)        NaN  ...
# 12                                               NaN        NaN  ...
# 13                                               NaN        NaN  ...
# 14                                               NaN        NaN  ...
# 15                                               NaN        NaN  ...
# 16                                                 –        NaN  ...
# 17                                              38.6        NaN  ...
# 18                                                 7          x  ...
# 19                                                 –        NaN  ...
# 20                                                11          x  ...
# 21                                                 –        NaN  ...
# 22                                                54        NaN  ...
# 23                                              34.6        NaN  ...
# 24                                                 –        NaN  ...
# 25                                                 –        NaN  ...
# 26                                                12          x  ...
# 27                                                 –        NaN  ...
# 28                                                 –        NaN  ...
# 29                                              64.1        NaN  ...
#
#                     Unnamed: 18 Unnamed: 19             Unnamed: 20  \
# 0                           NaN         NaN                     NaN
# 1                           NaN         NaN                     NaN
# 2                           NaN         NaN                     NaN
# 3                  Stunting (%)         NaN             Wasting (%)
# 4        moderate \nand severeθ         NaN  moderate \nand severeθ
# 5                           NaN         NaN                     NaN
# 6                           NaN         NaN                     NaN
# 7   Retard de\ncroissance (%)\n         NaN        Émaciation (%)\n
# 8             modérée et graveθ         NaN       modérée et graveθ
# 9                           NaN         NaN                     NaN
# 10                          NaN         NaN                     NaN
# 11       Cortedad de\ntalla (%)         NaN          Emaciación (%)
# 12            moderada y graveθ         NaN       moderada y graveθ
# 13                          NaN         NaN                     NaN
# 14                          NaN         NaN                     NaN
# 15                          NaN         NaN                     NaN
# 16                           59           x                       9
# 17                           19         NaN                       9
# 18                           15           x                       4
# 19                            –         NaN                       –
# 20                           29           x                     8.2
# 21                            –         NaN                       –
# 22                          8.2           x                     1.2
# 23                         19.3         NaN                       4
# 24                            –         NaN                       –
# 25                            –         NaN                       –
# 26                           25           x                       7
# 27                            –         NaN                       –
# 28                            –         NaN                       –
# 29                         41.3         NaN                    15.6
#
#    Unnamed: 21           Unnamed: 22 Unnamed: 23  \
# 0          NaN                   NaN         NaN
# 1          NaN                   NaN         NaN
# 2          NaN                   NaN         NaN
# 3          NaN        Overweight (%)         NaN
# 4          NaN  moderate and severeθ         NaN
# 5          NaN                   NaN         NaN
# 6          NaN                   NaN         NaN
# 7          NaN        Surpoids (%)\n         NaN
# 8          NaN     modérée et graveθ         NaN
# 9          NaN                   NaN         NaN
# 10         NaN                   NaN         NaN
# 11         NaN         Sobrepeso (%)         NaN
# 12         NaN     moderada y graveθ         NaN
# 13         NaN                   NaN         NaN
# 14         NaN                   NaN         NaN
# 15         NaN                   NaN         NaN
# 16           x                   4.6           x
# 17         NaN                  21.7         NaN
# 18           x                  12.9           x
# 19         NaN                     –         NaN
# 20           x                     –         NaN
# 21         NaN                     –         NaN
# 22           x                   9.9           x
# 23         NaN                  15.3         NaN
# 24         NaN                     –         NaN
# 25         NaN                     –         NaN
# 26           x                  12.9           x
# 27         NaN                     –         NaN
# 28         NaN                     –         NaN
# 29         NaN                   1.5         NaN
#
#                                           Unnamed: 24 Unnamed: 25  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3       Vitamin A supplementation, full coverageΔ (%)         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6                                                2012         NaN
# 7   Couverture\ntotale par la\nsupplémentation en\...         NaN
# 8                                                 NaN         NaN
# 9                                                 NaN         NaN
# 10                                               2012         NaN
# 11  Suplementos de vitamina A cobertura completa Δ...         NaN
# 12                                                NaN         NaN
# 13                                                NaN         NaN
# 14                                               2012         NaN
# 15                                                NaN         NaN
# 16                                                  –         NaN
# 17                                                  –         NaN
# 18                                                  –         NaN
# 19                                                  –         NaN
# 20                                                 44         NaN
# 21                                                  –         NaN
# 22                                                  –         NaN
# 23                                                  –         NaN
# 24                                                  –         NaN
# 25                                                  –         NaN
# 26                                                 90           w
# 27                                                  –         NaN
# 28                                                  –         NaN
# 29                                                 99         NaN
#
#                       Unnamed: 26 Unnamed: 27
# 0                             NaN         NaN
# 1                             NaN         NaN
# 2                             NaN         NaN
# 3    Iodized salt consumption (%)         NaN
# 4                             NaN         NaN
# 5                             NaN         NaN
# 6                      2008–2012*         NaN
# 7   Consommation\nde sel iodé (%)         NaN
# 8                             NaN         NaN
# 9                             NaN         NaN
# 10                     2008–2012*         NaN
# 11      Consumo de sal yodada (%)         NaN
# 12                            NaN         NaN
# 13                            NaN         NaN
# 14                     2008–2012*         NaN
# 15                            NaN         NaN
# 16                           20.4         NaN
# 17                           75.6         NaN
# 18                           60.7           x
# 19                              –         NaN
# 20                           44.7           x
# 21                              –         NaN
# 22                              –         NaN
# 23                             97           x
# 24                              –         NaN
# 25                              –         NaN
# 26                           53.8           x
# 27                              –         NaN
# 28                              –         NaN
# 29                           82.3           y
#
# [30 rows x 28 columns]

# %%
print(f"The shape of the dataframe is: {df.shape}")
# Out:
# The shape of the dataframe is: (322, 28)

# %% [markdown]
# We have loaded the target worksheet into Python.
# There are 322 rows and 28 columns (You can use `df.shape` to
# see the dimensionality of the DataFrame).
#
# If you scroll through the output, you will notice <font color = "red">  that the loaded data table is quite messy </font>.
# The messiness includes
# * Rows only contain missing values that are indicated by NaN in Pandas DataFrame.
# * Column heads are in three languages, i.e., English, French and Spanish.
# * Column heads in one language spread over multiple rows.
# * Country names also appear in three languages.
# * Notes shown in the original Excel file appear in rows towards the end of the data frame.
#
# <font color = "red"> Remember that our goal is to extract the data table in English. </font>
# It is clear that we need to further process the data frame.
# For demonstration purpose,
# we will try to keep the example as simple as possible,
# so we will not extract column heads here.
# Instead, if you are interested in programmatically extracting column heads,
# you can try it by yourself.

# %% [markdown]
# ### **1.3 Tasks**

# %% [markdown]
# #### **Task 1: drop useless columns and rows**
#
# You can start with removing country names in French and Spanish,
# which corresponds to remove two columns, labeled "Unnamed: 2" and "Unnamed: 3" in our data frame.
# To do this, you can use DataFrame's [`drop()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html) function,
# which returns a new object with labels in requested axis removed.
# You will frequently use this function later in this section.

# %%
# Drop columns "Unnamed: 2" and "Unnamed: 3" from df
df = df.drop(['Unnamed: 2', 'Unnamed: 3'], axis=1)
df.head()
# Out:
#    Unnamed: 0   TABLE 2. NUTRITION           Unnamed: 4 Unnamed: 5  \
# 0         NaN                  NaN                  NaN        NaN
# 1         NaN                  NaN                  NaN        NaN
# 2         NaN                  NaN                  NaN        NaN
# 3         NaN  Countries and areas  Low birthweight (%)        NaN
# 4         NaN                  NaN                  NaN        NaN
#
#                               Unnamed: 6 Unnamed: 7  \
# 0                                    NaN        NaN
# 1                                    NaN        NaN
# 2                                    NaN        NaN
# 3  Early initiation of breastfeeding (%)        NaN
# 4                                    NaN        NaN
#
#                                Unnamed: 8 Unnamed: 9  \
# 0                                     NaN        NaN
# 1                                     NaN        NaN
# 2                                     NaN        NaN
# 3  Exclusive breastfeeding\n<6 months (%)        NaN
# 4                                     NaN        NaN
#
#                                          Unnamed: 10 Unnamed: 11  ...  \
# 0                                                NaN         NaN  ...
# 1                                                NaN         NaN  ...
# 2                                                NaN         NaN  ...
# 3  Introduction of solid, semi-solid or soft food...         NaN  ...
# 4                                                NaN         NaN  ...
#
#               Unnamed: 18 Unnamed: 19             Unnamed: 20 Unnamed: 21  \
# 0                     NaN         NaN                     NaN         NaN
# 1                     NaN         NaN                     NaN         NaN
# 2                     NaN         NaN                     NaN         NaN
# 3            Stunting (%)         NaN             Wasting (%)         NaN
# 4  moderate \nand severeθ         NaN  moderate \nand severeθ         NaN
#
#             Unnamed: 22 Unnamed: 23  \
# 0                   NaN         NaN
# 1                   NaN         NaN
# 2                   NaN         NaN
# 3        Overweight (%)         NaN
# 4  moderate and severeθ         NaN
#
#                                      Unnamed: 24 Unnamed: 25  \
# 0                                            NaN         NaN
# 1                                            NaN         NaN
# 2                                            NaN         NaN
# 3  Vitamin A supplementation, full coverageΔ (%)         NaN
# 4                                            NaN         NaN
#
#                     Unnamed: 26 Unnamed: 27
# 0                           NaN         NaN
# 1                           NaN         NaN
# 2                           NaN         NaN
# 3  Iodized salt consumption (%)         NaN
# 4                           NaN         NaN
#
# [5 rows x 26 columns]

# %%
print(f"The shape of the dataframe is: {df.shape}")
# Out:
# The shape of the dataframe is: (322, 26)

# %% [markdown]
# Now you should have 26 columns.
#
# Next, you can <font color = "red"> remove all the rows and columns that are empty </font>, i.e., only contains NaNs.

# %%
# Drop all rows and columns that are completely empty (all NaN)
df = df.dropna(axis=0, how='all')
df = df.dropna(axis=1, how='all')
df.head()
# Out:
#     TABLE 2. NUTRITION                                      Unnamed: 4  \
# 3  Countries and areas                             Low birthweight (%)
# 4                  NaN                                             NaN
# 6                  NaN                                      2008–2012*
# 7      FRENCH HEADINGS  Insuffisance\npondérale à la\nnaissance\n(%)\n
# 8                  NaN                                             NaN
#
#   Unnamed: 5                                  Unnamed: 6 Unnamed: 7  \
# 3        NaN       Early initiation of breastfeeding (%)        NaN
# 4        NaN                                         NaN        NaN
# 6        NaN                                  2008–2012*        NaN
# 7        NaN  Initiation\nprécoce de\nl’allaitement\n(%)        NaN
# 8        NaN                                         NaN        NaN
#
#                                          Unnamed: 8 Unnamed: 9  \
# 3            Exclusive breastfeeding\n<6 months (%)        NaN
# 4                                               NaN        NaN
# 6                                               NaN        NaN
# 7  Allaitement\nexclusivement\nau sein <6 mois\n(%)        NaN
# 8                                               NaN        NaN
#
#                                          Unnamed: 10 Unnamed: 11  \
# 3  Introduction of solid, semi-solid or soft food...         NaN
# 4                                                NaN         NaN
# 6                                                NaN         NaN
# 7  Introduction\nd’aliments\nsolides, semisolides...         NaN
# 8                                                NaN         NaN
#
#                               Unnamed: 12  ...                  Unnamed: 18  \
# 3              Breastfeeding at age 2 (%)  ...                 Stunting (%)
# 4                                     NaN  ...       moderate \nand severeθ
# 6                                     NaN  ...                          NaN
# 7  Nourris au sein\nà l’âge de\n2 ans (%)  ...  Retard de\ncroissance (%)\n
# 8                                     NaN  ...            modérée et graveθ
#
#   Unnamed: 19             Unnamed: 20 Unnamed: 21           Unnamed: 22  \
# 3         NaN             Wasting (%)         NaN        Overweight (%)
# 4         NaN  moderate \nand severeθ         NaN  moderate and severeθ
# 6         NaN                     NaN         NaN                   NaN
# 7         NaN        Émaciation (%)\n         NaN        Surpoids (%)\n
# 8         NaN       modérée et graveθ         NaN     modérée et graveθ
#
#   Unnamed: 23                                        Unnamed: 24 Unnamed: 25  \
# 3         NaN      Vitamin A supplementation, full coverageΔ (%)         NaN
# 4         NaN                                                NaN         NaN
# 6         NaN                                               2012         NaN
# 7         NaN  Couverture\ntotale par la\nsupplémentation en\...         NaN
# 8         NaN                                                NaN         NaN
#
#                      Unnamed: 26 Unnamed: 27
# 3   Iodized salt consumption (%)         NaN
# 4                            NaN         NaN
# 6                     2008–2012*         NaN
# 7  Consommation\nde sel iodé (%)         NaN
# 8                            NaN         NaN
#
# [5 rows x 25 columns]

# %%
print(f"The shape of the dataframe is: {df.shape}")
# Out:
# The shape of the dataframe is: (245, 25)

# %% [markdown]
# Here you can use the [`dropna`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dropna.html) function of DataFrame. The first argument is axis (0 or 'index' means row, and 1 or 'columns' means column),
# and the second argument indicates deleting rows/columns with all NaNs.
# We further removed 77 rows and 1 column.
#
# Now, you can <font color = "red"> reset the row indices with a list of integers. </font>

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#     TABLE 2. NUTRITION                                      Unnamed: 4  \
# 0  Countries and areas                             Low birthweight (%)
# 1                  NaN                                             NaN
# 2                  NaN                                      2008–2012*
# 3      FRENCH HEADINGS  Insuffisance\npondérale à la\nnaissance\n(%)\n
# 4                  NaN                                             NaN
#
#   Unnamed: 5                                  Unnamed: 6 Unnamed: 7  \
# 0        NaN       Early initiation of breastfeeding (%)        NaN
# 1        NaN                                         NaN        NaN
# 2        NaN                                  2008–2012*        NaN
# 3        NaN  Initiation\nprécoce de\nl’allaitement\n(%)        NaN
# 4        NaN                                         NaN        NaN
#
#                                          Unnamed: 8 Unnamed: 9  \
# 0            Exclusive breastfeeding\n<6 months (%)        NaN
# 1                                               NaN        NaN
# 2                                               NaN        NaN
# 3  Allaitement\nexclusivement\nau sein <6 mois\n(%)        NaN
# 4                                               NaN        NaN
#
#                                          Unnamed: 10 Unnamed: 11  \
# 0  Introduction of solid, semi-solid or soft food...         NaN
# 1                                                NaN         NaN
# 2                                                NaN         NaN
# 3  Introduction\nd’aliments\nsolides, semisolides...         NaN
# 4                                                NaN         NaN
#
#                               Unnamed: 12  ...                  Unnamed: 18  \
# 0              Breastfeeding at age 2 (%)  ...                 Stunting (%)
# 1                                     NaN  ...       moderate \nand severeθ
# 2                                     NaN  ...                          NaN
# 3  Nourris au sein\nà l’âge de\n2 ans (%)  ...  Retard de\ncroissance (%)\n
# 4                                     NaN  ...            modérée et graveθ
#
#   Unnamed: 19             Unnamed: 20 Unnamed: 21           Unnamed: 22  \
# 0         NaN             Wasting (%)         NaN        Overweight (%)
# 1         NaN  moderate \nand severeθ         NaN  moderate and severeθ
# 2         NaN                     NaN         NaN                   NaN
# 3         NaN        Émaciation (%)\n         NaN        Surpoids (%)\n
# 4         NaN       modérée et graveθ         NaN     modérée et graveθ
#
#   Unnamed: 23                                        Unnamed: 24 Unnamed: 25  \
# 0         NaN      Vitamin A supplementation, full coverageΔ (%)         NaN
# 1         NaN                                                NaN         NaN
# 2         NaN                                               2012         NaN
# 3         NaN  Couverture\ntotale par la\nsupplémentation en\...         NaN
# 4         NaN                                                NaN         NaN
#
#                      Unnamed: 26 Unnamed: 27
# 0   Iodized salt consumption (%)         NaN
# 1                            NaN         NaN
# 2                     2008–2012*         NaN
# 3  Consommation\nde sel iodé (%)         NaN
# 4                            NaN         NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# After resetting all the row indices, and if you print out the
# first 15 rows using the slicing method

# %%
df[:15]
# Out:
#      TABLE 2. NUTRITION                                      Unnamed: 4  \
# 0   Countries and areas                             Low birthweight (%)
# 1                   NaN                                             NaN
# 2                   NaN                                      2008–2012*
# 3       FRENCH HEADINGS  Insuffisance\npondérale à la\nnaissance\n(%)\n
# 4                   NaN                                             NaN
# 5                   NaN                                      2008–2012*
# 6      SPANISH HEADINGS                         Bajo peso al nacer (%)
# 7                   NaN                                             NaN
# 8                   NaN                                      2008–2012*
# 9           Afghanistan                                               –
# 10              Albania                                             3.6
# 11              Algeria                                               6
# 12              Andorra                                               –
# 13               Angola                                              12
# 14  Antigua and Barbuda                                               5
#
#    Unnamed: 5                                      Unnamed: 6 Unnamed: 7  \
# 0         NaN           Early initiation of breastfeeding (%)        NaN
# 1         NaN                                             NaN        NaN
# 2         NaN                                      2008–2012*        NaN
# 3         NaN      Initiation\nprécoce de\nl’allaitement\n(%)        NaN
# 4         NaN                                             NaN        NaN
# 5         NaN                                      2008−2012*        NaN
# 6         NaN  Iniciación temprana a la lactancia materna (%)        NaN
# 7         NaN                                             NaN        NaN
# 8         NaN                                      2008−2012*        NaN
# 9         NaN                                               –        NaN
# 10        NaN                                            42.9        NaN
# 11          x                                            49.5          x
# 12        NaN                                               –        NaN
# 13          x                                            54.9          x
# 14          x                                               –        NaN
#
#                                           Unnamed: 8 Unnamed: 9  \
# 0             Exclusive breastfeeding\n<6 months (%)        NaN
# 1                                                NaN        NaN
# 2                                                NaN        NaN
# 3   Allaitement\nexclusivement\nau sein <6 mois\n(%)        NaN
# 4                                                NaN        NaN
# 5                                                NaN        NaN
# 6          Lactancia materna exclusiva\n<6 meses (%)        NaN
# 7                                                NaN        NaN
# 8                                                NaN        NaN
# 9                                                  –        NaN
# 10                                              38.6        NaN
# 11                                                 7          x
# 12                                                 –        NaN
# 13                                                11          x
# 14                                                 –        NaN
#
#                                           Unnamed: 10 Unnamed: 11  \
# 0   Introduction of solid, semi-solid or soft food...         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3   Introduction\nd’aliments\nsolides, semisolides...         NaN
# 4                                                 NaN         NaN
# 5                                                 NaN         NaN
# 6   Incorporación de alimentos sóli- dos, semisóli...         NaN
# 7                                                 NaN         NaN
# 8                                                 NaN         NaN
# 9                                                  29           x
# 10                                          78.278804         NaN
# 11                                                 39         x,y
# 12                                                  –         NaN
# 13                                               77.2           x
# 14                                                  –         NaN
#
#                                Unnamed: 12  ...                  Unnamed: 18  \
# 0               Breastfeeding at age 2 (%)  ...                 Stunting (%)
# 1                                      NaN  ...       moderate \nand severeθ
# 2                                      NaN  ...                          NaN
# 3   Nourris au sein\nà l’âge de\n2 ans (%)  ...  Retard de\ncroissance (%)\n
# 4                                      NaN  ...            modérée et graveθ
# 5                                      NaN  ...                          NaN
# 6       Lactancia materna a los 2 anos (%)  ...       Cortedad de\ntalla (%)
# 7                                      NaN  ...            moderada y graveθ
# 8                                      NaN  ...                          NaN
# 9                                       54  ...                           59
# 10                                      31  ...                           19
# 11                                    22.2  ...                           15
# 12                                       –  ...                            –
# 13                                      37  ...                           29
# 14                                       –  ...                            –
#
#    Unnamed: 19             Unnamed: 20 Unnamed: 21           Unnamed: 22  \
# 0          NaN             Wasting (%)         NaN        Overweight (%)
# 1          NaN  moderate \nand severeθ         NaN  moderate and severeθ
# 2          NaN                     NaN         NaN                   NaN
# 3          NaN        Émaciation (%)\n         NaN        Surpoids (%)\n
# 4          NaN       modérée et graveθ         NaN     modérée et graveθ
# 5          NaN                     NaN         NaN                   NaN
# 6          NaN          Emaciación (%)         NaN         Sobrepeso (%)
# 7          NaN       moderada y graveθ         NaN     moderada y graveθ
# 8          NaN                     NaN         NaN                   NaN
# 9            x                       9           x                   4.6
# 10         NaN                       9         NaN                  21.7
# 11           x                       4           x                  12.9
# 12         NaN                       –         NaN                     –
# 13           x                     8.2           x                     –
# 14         NaN                       –         NaN                     –
#
#    Unnamed: 23                                        Unnamed: 24 Unnamed: 25  \
# 0          NaN      Vitamin A supplementation, full coverageΔ (%)         NaN
# 1          NaN                                                NaN         NaN
# 2          NaN                                               2012         NaN
# 3          NaN  Couverture\ntotale par la\nsupplémentation en\...         NaN
# 4          NaN                                                NaN         NaN
# 5          NaN                                               2012         NaN
# 6          NaN  Suplementos de vitamina A cobertura completa Δ...         NaN
# 7          NaN                                                NaN         NaN
# 8          NaN                                               2012         NaN
# 9            x                                                  –         NaN
# 10         NaN                                                  –         NaN
# 11           x                                                  –         NaN
# 12         NaN                                                  –         NaN
# 13         NaN                                                 44         NaN
# 14         NaN                                                  –         NaN
#
#                       Unnamed: 26 Unnamed: 27
# 0    Iodized salt consumption (%)         NaN
# 1                             NaN         NaN
# 2                      2008–2012*         NaN
# 3   Consommation\nde sel iodé (%)         NaN
# 4                             NaN         NaN
# 5                      2008–2012*         NaN
# 6       Consumo de sal yodada (%)         NaN
# 7                             NaN         NaN
# 8                      2008–2012*         NaN
# 9                            20.4         NaN
# 10                           75.6         NaN
# 11                           60.7           x
# 12                              –         NaN
# 13                           44.7           x
# 14                              –         NaN
#
# [15 rows x 25 columns]

# %% [markdown]
# You will find that the data starts from row index 9.
# The first 9 rows contain column heads in three different languages.
# As mentioned above, to keep the script simple, you should not extract column heads here,
# rather you need to delete them.
#
# Similarly, if you print out the last 40 rows, the data wanted ends at row 205.
# Therefore, you need to <font color = "red">delete the first 9 rows and the
# last 39 rows, and then reindex all the rows left.</font>

# %%
df.tail(40)
# Out:
#                                     TABLE 2. NUTRITION Unnamed: 4 Unnamed: 5  \
# 205                                           Zimbabwe         11        NaN
# 206                                SUMMARY INDICATORS#        NaN        NaN
# 207                                 Sub-Saharan Africa  13.052633        NaN
# 208                        Eastern and Southern Africa  11.254036        NaN
# 209                            West and Central Africa  14.170071        NaN
# 210                       Middle East and North Africa          –        NaN
# 211                                         South Asia   27.75447        NaN
# 212                          East Asia and the Pacific   5.525951        NaN
# 213                    Latin America and the Caribbean   8.861783        NaN
# 214                                            CEE/CIS          –        NaN
# 215                          Least developed countries  12.829081        NaN
# 216                                              World  14.657427        NaN
# 217  # For a complete list of countries and areas i...        NaN        NaN
# 218                                              NOTES        NaN        NaN
# 219                              – Data not available.        NaN        NaN
# 220  w Identifies countries with national vitamin A...        NaN        NaN
# 221  x Data refer to years or periods other than th...        NaN        NaN
# 222  y Data differ from the standard definition or ...        NaN        NaN
# 223  Δ Full coverage with vitamin A supplements is ...        NaN        NaN
# 224  * Data refer to the most recent year available...        NaN        NaN
# 225                                 ** Excludes China.        NaN        NaN
# 226  θ Regional averages for underweight (moderate ...        NaN        NaN
# 227                      DEFINITIONS OF THE INDICATORS        NaN        NaN
# 228  Low birthweight – Percentage of infants weighi...        NaN        NaN
# 229  Early initiation of breastfeeding – Percentage...        NaN        NaN
# 230  Exclusive breastfeeding <6 months – Percentage...        NaN        NaN
# 231  Introduction of solid, semi-solid or soft food...        NaN        NaN
# 232  Breastfeeding at age 2 – Percentage of childre...        NaN        NaN
# 233  Underweight – Moderate and severe: Percentage ...        NaN        NaN
# 234  Stunting – Moderate and severe: Percentage of ...        NaN        NaN
# 235  Wasting – Moderate and severe: Percentage of c...        NaN        NaN
# 236  Overweight – Moderate and severe: Percentage o...        NaN        NaN
# 237  Vitamin A supplementation, full coverage – The...        NaN        NaN
# 238  Iodized salt consumption – Percentage of house...        NaN        NaN
# 239                                  MAIN DATA SOURCES        NaN        NaN
# 240  Low birthweight – Demographic and Health Surve...        NaN        NaN
# 241  Breastfeeding – DHS, MICS, other national hous...        NaN        NaN
# 242  Underweight, stunting, wasting and overweight ...        NaN        NaN
# 243                Vitamin A supplementation – UNICEF.        NaN        NaN
# 244  Iodized salt consumption – DHS, MICS, other na...        NaN        NaN
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 205       65.2        NaN       31.4        NaN          86         NaN
# 206        NaN        NaN        NaN        NaN         NaN         NaN
# 207  45.297565        NaN  36.056241        NaN   56.498691         NaN
# 208  59.847888        NaN  51.540234        NaN   72.309396         NaN
# 209  34.508419        NaN  24.691961        NaN   45.081478         NaN
# 210          –        NaN          –        NaN           –         NaN
# 211         41        NaN  48.957027        NaN          57         NaN
# 212  41.345298        NaN  30.164535        NaN   50.562937         NaN
# 213  48.815863        NaN  39.053019        NaN           –         NaN
# 214          –        NaN          –        NaN           –         NaN
# 215  53.358497        NaN   48.12101        NaN          63         NaN
# 216  43.241378        NaN         38        NaN   54.851283         NaN
# 217        NaN        NaN        NaN        NaN         NaN         NaN
# 218        NaN        NaN        NaN        NaN         NaN         NaN
# 219        NaN        NaN        NaN        NaN         NaN         NaN
# 220        NaN        NaN        NaN        NaN         NaN         NaN
# 221        NaN        NaN        NaN        NaN         NaN         NaN
# 222        NaN        NaN        NaN        NaN         NaN         NaN
# 223        NaN        NaN        NaN        NaN         NaN         NaN
# 224        NaN        NaN        NaN        NaN         NaN         NaN
# 225        NaN        NaN        NaN        NaN         NaN         NaN
# 226        NaN        NaN        NaN        NaN         NaN         NaN
# 227        NaN        NaN        NaN        NaN         NaN         NaN
# 228        NaN        NaN        NaN        NaN         NaN         NaN
# 229        NaN        NaN        NaN        NaN         NaN         NaN
# 230        NaN        NaN        NaN        NaN         NaN         NaN
# 231        NaN        NaN        NaN        NaN         NaN         NaN
# 232        NaN        NaN        NaN        NaN         NaN         NaN
# 233        NaN        NaN        NaN        NaN         NaN         NaN
# 234        NaN        NaN        NaN        NaN         NaN         NaN
# 235        NaN        NaN        NaN        NaN         NaN         NaN
# 236        NaN        NaN        NaN        NaN         NaN         NaN
# 237        NaN        NaN        NaN        NaN         NaN         NaN
# 238        NaN        NaN        NaN        NaN         NaN         NaN
# 239        NaN        NaN        NaN        NaN         NaN         NaN
# 240        NaN        NaN        NaN        NaN         NaN         NaN
# 241        NaN        NaN        NaN        NaN         NaN         NaN
# 242        NaN        NaN        NaN        NaN         NaN         NaN
# 243        NaN        NaN        NaN        NaN         NaN         NaN
# 244        NaN        NaN        NaN        NaN         NaN         NaN
#
#     Unnamed: 12  ... Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21  \
# 205        19.5  ...          32         NaN           3         NaN
# 206         NaN  ...         NaN         NaN         NaN         NaN
# 207   50.482704  ...       37.97         NaN        9.05         NaN
# 208   60.837445  ...       38.82         NaN        7.26         NaN
# 209   43.714518  ...       36.91         NaN        10.6         NaN
# 210           –  ...       18.17         NaN        7.74         NaN
# 211   78.168149  ...       37.69         NaN       16.04         NaN
# 212   45.213429  ...       11.84         NaN        3.52         NaN
# 213           –  ...       11.23         NaN        1.39         NaN
# 214           –  ...       11.25         NaN        1.49         NaN
# 215   63.828834  ...        37.4         NaN         9.7         NaN
# 216   58.045467  ...        24.7         NaN         7.8         NaN
# 217         NaN  ...         NaN         NaN         NaN         NaN
# 218         NaN  ...         NaN         NaN         NaN         NaN
# 219         NaN  ...         NaN         NaN         NaN         NaN
# 220         NaN  ...         NaN         NaN         NaN         NaN
# 221         NaN  ...         NaN         NaN         NaN         NaN
# 222         NaN  ...         NaN         NaN         NaN         NaN
# 223         NaN  ...         NaN         NaN         NaN         NaN
# 224         NaN  ...         NaN         NaN         NaN         NaN
# 225         NaN  ...         NaN         NaN         NaN         NaN
# 226         NaN  ...         NaN         NaN         NaN         NaN
# 227         NaN  ...         NaN         NaN         NaN         NaN
# 228         NaN  ...         NaN         NaN         NaN         NaN
# 229         NaN  ...         NaN         NaN         NaN         NaN
# 230         NaN  ...         NaN         NaN         NaN         NaN
# 231         NaN  ...         NaN         NaN         NaN         NaN
# 232         NaN  ...         NaN         NaN         NaN         NaN
# 233         NaN  ...         NaN         NaN         NaN         NaN
# 234         NaN  ...         NaN         NaN         NaN         NaN
# 235         NaN  ...         NaN         NaN         NaN         NaN
# 236         NaN  ...         NaN         NaN         NaN         NaN
# 237         NaN  ...         NaN         NaN         NaN         NaN
# 238         NaN  ...         NaN         NaN         NaN         NaN
# 239         NaN  ...         NaN         NaN         NaN         NaN
# 240         NaN  ...         NaN         NaN         NaN         NaN
# 241         NaN  ...         NaN         NaN         NaN         NaN
# 242         NaN  ...         NaN         NaN         NaN         NaN
# 243         NaN  ...         NaN         NaN         NaN         NaN
# 244         NaN  ...         NaN         NaN         NaN         NaN
#
#     Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27
# 205         5.5         NaN          61         NaN          94           y
# 206         NaN         NaN         NaN         NaN         NaN         NaN
# 207        5.54         NaN   68.456849         NaN   53.993565         NaN
# 208        4.92         NaN   55.955394         NaN   60.509784         NaN
# 209         5.9         NaN   77.446049         NaN   52.612735         NaN
# 210       10.97         NaN           –         NaN           –         NaN
# 211        3.59         NaN   69.131567         NaN   71.165538         NaN
# 212        5.29         NaN          81          **   90.917443         NaN
# 213        7.46         NaN           –         NaN           –         NaN
# 214       15.11         NaN           –         NaN           –         NaN
# 215         4.5         NaN   70.463517         NaN   60.224219         NaN
# 216         6.7         NaN   69.814414          **    75.55683         NaN
# 217         NaN         NaN         NaN         NaN         NaN         NaN
# 218         NaN         NaN         NaN         NaN         NaN         NaN
# 219         NaN         NaN         NaN         NaN         NaN         NaN
# 220         NaN         NaN         NaN         NaN         NaN         NaN
# 221         NaN         NaN         NaN         NaN         NaN         NaN
# 222         NaN         NaN         NaN         NaN         NaN         NaN
# 223         NaN         NaN         NaN         NaN         NaN         NaN
# 224         NaN         NaN         NaN         NaN         NaN         NaN
# 225         NaN         NaN         NaN         NaN         NaN         NaN
# 226         NaN         NaN         NaN         NaN         NaN         NaN
# 227         NaN         NaN         NaN         NaN         NaN         NaN
# 228         NaN         NaN         NaN         NaN         NaN         NaN
# 229         NaN         NaN         NaN         NaN         NaN         NaN
# 230         NaN         NaN         NaN         NaN         NaN         NaN
# 231         NaN         NaN         NaN         NaN         NaN         NaN
# 232         NaN         NaN         NaN         NaN         NaN         NaN
# 233         NaN         NaN         NaN         NaN         NaN         NaN
# 234         NaN         NaN         NaN         NaN         NaN         NaN
# 235         NaN         NaN         NaN         NaN         NaN         NaN
# 236         NaN         NaN         NaN         NaN         NaN         NaN
# 237         NaN         NaN         NaN         NaN         NaN         NaN
# 238         NaN         NaN         NaN         NaN         NaN         NaN
# 239         NaN         NaN         NaN         NaN         NaN         NaN
# 240         NaN         NaN         NaN         NaN         NaN         NaN
# 241         NaN         NaN         NaN         NaN         NaN         NaN
# 242         NaN         NaN         NaN         NaN         NaN         NaN
# 243         NaN         NaN         NaN         NaN         NaN         NaN
# 244         NaN         NaN         NaN         NaN         NaN         NaN
#
# [40 rows x 25 columns]

# %%
# Delete the first 9 rows
df = df.drop(df.index[0:9])
# Delete the last 39 rows
df = df.drop(df.index[-39:])
# Reset the row indices
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#   TABLE 2. NUTRITION Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        Afghanistan          –        NaN          –        NaN          –
# 1            Albania        3.6        NaN       42.9        NaN       38.6
# 2            Algeria          6          x       49.5          x          7
# 3            Andorra          –        NaN          –        NaN          –
# 4             Angola         12          x       54.9          x         11
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  ... Unnamed: 18 Unnamed: 19  \
# 0        NaN          29           x          54  ...          59           x
# 1        NaN   78.278804         NaN          31  ...          19         NaN
# 2          x          39         x,y        22.2  ...          15           x
# 3        NaN           –         NaN           –  ...           –         NaN
# 4          x        77.2           x          37  ...          29           x
#
#   Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# 0           9           x         4.6           x           –         NaN
# 1           9         NaN        21.7         NaN           –         NaN
# 2           4           x        12.9           x           –         NaN
# 3           –         NaN           –         NaN           –         NaN
# 4         8.2           x           –         NaN          44         NaN
#
#   Unnamed: 26 Unnamed: 27
# 0        20.4         NaN
# 1        75.6         NaN
# 2        60.7           x
# 3           –         NaN
# 4        44.7           x
#
# [5 rows x 25 columns]

# %% [markdown]
# ####  **Task 2: Set country index**
#
# So far you have extracted all the records (or rows) for 196 countries in the Excel file.
# Let's set the country names as row indices, and reset the column labels.

# %%
# Set the first column (country names) as index
df = df.set_index("TABLE 2. NUTRITION")

# Reset the column labels (remove 'Unnamed' prefixes etc.)
df.columns = [f"col_{i}" if "Unnamed" in str(col) else col for i, col in enumerate(df.columns)]

# Quick check
df.head()
# Out:
#                    col_0 col_1 col_2 col_3 col_4 col_5      col_6 col_7 col_8  \
# TABLE 2. NUTRITION
# Afghanistan            –   NaN     –   NaN     –   NaN         29     x    54
# Albania              3.6   NaN  42.9   NaN  38.6   NaN  78.278804   NaN    31
# Algeria                6     x  49.5     x     7     x         39   x,y  22.2
# Andorra                –   NaN     –   NaN     –   NaN          –   NaN     –
# Angola                12     x  54.9     x    11     x       77.2     x    37
#
#                    col_9  ... col_14 col_15 col_16 col_17 col_18 col_19  \
# TABLE 2. NUTRITION        ...
# Afghanistan            x  ...     59      x      9      x    4.6      x
# Albania              NaN  ...     19    NaN      9    NaN   21.7    NaN
# Algeria                x  ...     15      x      4      x   12.9      x
# Andorra              NaN  ...      –    NaN      –    NaN      –    NaN
# Angola                 x  ...     29      x    8.2      x      –    NaN
#
#                    col_20 col_21 col_22 col_23
# TABLE 2. NUTRITION
# Afghanistan             –    NaN   20.4    NaN
# Albania                 –    NaN   75.6    NaN
# Algeria                 –    NaN   60.7      x
# Andorra                 –    NaN      –    NaN
# Angola                 44    NaN   44.7      x
#
# [5 rows x 24 columns]

# %% [markdown]
# #### **Task 3 Tidy up all columns**
#
# However, those records are still messy.
# As you can see in the printout, there are a lot of NaNs,
# and cell values with both numbers and letters (e.g., "6 x", " 39 x,y",) spread over two columns.
# Therefore, <font color = "red">we need to merge every two columns together</font>.
#
# How can you do that?
#
# Let us have a look at the first 10 rows and 2 columns.

# %%
df.iloc[:10, :2]
# Out:
#                     col_0 col_1
# TABLE 2. NUTRITION
# Afghanistan             –   NaN
# Albania               3.6   NaN
# Algeria                 6     x
# Andorra                 –   NaN
# Angola                 12     x
# Antigua and Barbuda     5     x
# Argentina             7.2   NaN
# Armenia                 8   NaN
# Australia               7     x
# Austria                 7     x

# %% [markdown]
# A close look at the printout will give you the following patterns:
# * If the cell contains only a float or '-', the corresponding cell value in the odd-numbered column is "NaN".
# See the rows labeled "**Afghanistan**", "**Albania**", etc.
# * If the original cell contains a float and a couple of letters, the cell in the even-numbered column contains the float, and the one in the odd-numbered column contains the letters.
# See the rows labeled "**Algeria**", "**Angola**". etc.
#
# Assume that you are going to merge the two cells containing a float and letters respectively.
# You need a `FOR` loop iterating over either odd- or even-numbered columns.
# Within this `FOR` loop, another `FOR` loop is needed to iterate over rows.
# For each row, you can check if the cell in the odd-numbered column contains `NaN`.
# If it does, then you can merge it with the cell in the corresponding even-numbered column on the left.

# %%
for i in range(1, len(df.columns), 2):  # odd-numbered columns
    even_col = df.columns[i - 1]
    odd_col = df.columns[i]
    for idx in df.index:
        odd_val = df.at[idx, odd_col]
        if not pd.isna(odd_val):
            even_val = df.at[idx, even_col]
            # If even_val is nan, just use the odd_val
            if pd.isna(even_val):
                df.at[idx, even_col] = str(odd_val)
            else:
                df.at[idx, even_col] = f"{even_val} {odd_val}"

df
# Out:
#                                    col_0 col_1   col_2 col_3 col_4 col_5  \
# TABLE 2. NUTRITION
# Afghanistan                            –   NaN       –   NaN     –   NaN
# Albania                              3.6   NaN    42.9   NaN  38.6   NaN
# Algeria                              6 x     x  49.5 x     x   7 x     x
# Andorra                                –   NaN       –   NaN     –   NaN
# Angola                              12 x     x  54.9 x     x  11 x     x
# ...                                  ...   ...     ...   ...   ...   ...
# Venezuela (Bolivarian Republic of)     8   NaN       –   NaN     –   NaN
# Viet Nam                             5.1   NaN    39.7   NaN    17   NaN
# Yemen                                  –   NaN    30 x     x  12 x     x
# Zambia                              11 x     x  56.5 x     x  61 x     x
# Zimbabwe                              11   NaN    65.2   NaN  31.4   NaN
#
#                                                 col_6 col_7   col_8 col_9  \
# TABLE 2. NUTRITION
# Afghanistan                                      29 x     x    54 x     x
# Albania                                     78.278804   NaN      31   NaN
# Algeria                                        39 x,y   x,y  22.2 x     x
# Andorra                                             –   NaN       –   NaN
# Angola                                         77.2 x     x    37 x     x
# ...                                               ...   ...     ...   ...
# Venezuela (Bolivarian Republic of)                  –   NaN       –   NaN
# Viet Nam                                         50.4   NaN    19.4   NaN
# Yemen                                        76.3 x,y   x,y       –   NaN
# Zambia                              94.341801380852 x     x  41.7 x     x
# Zimbabwe                                           86   NaN    19.5   NaN
#
#                                     ...  col_14 col_15  col_16 col_17  col_18  \
# TABLE 2. NUTRITION                  ...
# Afghanistan                         ...    59 x      x     9 x      x   4.6 x
# Albania                             ...      19    NaN       9    NaN    21.7
# Algeria                             ...    15 x      x     4 x      x  12.9 x
# Andorra                             ...       –    NaN       –    NaN       –
# Angola                              ...    29 x      x   8.2 x      x       –
# ...                                 ...     ...    ...     ...    ...     ...
# Venezuela (Bolivarian Republic of)  ...  15.6 x      x     5 x      x   6.1 x
# Viet Nam                            ...    22.7    NaN     4.1    NaN     4.4
# Yemen                               ...  57.7 x      x  15.2 x      x     5 x
# Zambia                              ...  45.4 x      x   5.2 x      x   7.9 x
# Zimbabwe                            ...      32    NaN       3    NaN     5.5
#
#                                    col_19 col_20 col_21  col_22 col_23
# TABLE 2. NUTRITION
# Afghanistan                             x      –    NaN    20.4    NaN
# Albania                               NaN      –    NaN    75.6    NaN
# Algeria                                 x      –    NaN  60.7 x      x
# Andorra                               NaN      –    NaN       –    NaN
# Angola                                NaN     44    NaN  44.7 x      x
# ...                                   ...    ...    ...     ...    ...
# Venezuela (Bolivarian Republic of)      x      –    NaN       –    NaN
# Viet Nam                              NaN   98 w      w    45.1    NaN
# Yemen                                   x     11    NaN  29.5 x      x
# Zambia                                  x      –    NaN  77.4 x      x
# Zimbabwe                              NaN     61    NaN    94 y      y
#
# [197 rows x 24 columns]

# %% [markdown]
# The next step is to remove the odd-numbered columns in the data frame, as they are redundant now.
# To do this, you can use DataFrame's `drop()` function again as follows

# %%
# Drop odd-numbered columns
df = df.drop(df.columns[1::2], axis=1)

# Check result
df.head()
# Out:
#                    col_0   col_2 col_4      col_6   col_8 col_10  col_12  \
# TABLE 2. NUTRITION
# Afghanistan            –       –     –       29 x    54 x   33 x  12.2 x
# Albania              3.6    42.9  38.6  78.278804      31      5     1.7
# Algeria              6 x  49.5 x   7 x     39 x,y  22.2 x    3 x   0.9 x
# Andorra                –       –     –          –       –      –       –
# Angola              12 x  54.9 x  11 x     77.2 x    37 x   16 x   6.6 x
#
#                    col_14 col_16  col_18 col_20  col_22
# TABLE 2. NUTRITION
# Afghanistan          59 x    9 x   4.6 x      –    20.4
# Albania                19      9    21.7      –    75.6
# Algeria              15 x    4 x  12.9 x      –  60.7 x
# Andorra                 –      –       –      –       –
# Angola               29 x  8.2 x       –     44  44.7 x

# %% [markdown]
# Now the data is in a pretty good shape aside from the column heads.
# You can extract the column heads from the Excel file using either manual or programmatic method.
# Here, you can do it manually. Considering that you need to save results in an csv file, you can use the long name from the raw data.

# %%
# Set the column names manually as per the provided list (skipping the NaN columns)
df.columns = [
    "Low birthweight (%)",
    "Early initiation of breastfeeding (%)",
    "Exclusive breastfeeding <6 months (%)",
    "Introduction of solid, semi-solid or soft foods (%)",
    "Breastfeeding at age 2 (%)",
    "Underweight (%) - Moderate and Severe",
    "Underweight (%) - Severe",
    "Stunting (%)",
    "Wasting (%)",
    "Overweight (%)",
    "Vitamin A supplementation, full coverageΔ (%)",
    "Iodized salt consumption (%)"
]

df.index.name = "Countries and areas"
df.head()
# Out:
#                     Low birthweight (%) Early initiation of breastfeeding (%)  \
# Countries and areas
# Afghanistan                           –                                     –
# Albania                             3.6                                  42.9
# Algeria                             6 x                                49.5 x
# Andorra                               –                                     –
# Angola                             12 x                                54.9 x
#
#                     Exclusive breastfeeding <6 months (%)  \
# Countries and areas
# Afghanistan                                             –
# Albania                                              38.6
# Algeria                                               7 x
# Andorra                                                 –
# Angola                                               11 x
#
#                     Introduction of solid, semi-solid or soft foods (%)  \
# Countries and areas
# Afghanistan                                                       29 x
# Albania                                                      78.278804
# Algeria                                                         39 x,y
# Andorra                                                              –
# Angola                                                          77.2 x
#
#                     Breastfeeding at age 2 (%)  \
# Countries and areas
# Afghanistan                               54 x
# Albania                                     31
# Algeria                                 22.2 x
# Andorra                                      –
# Angola                                    37 x
#
#                     Underweight (%) - Moderate and Severe  \
# Countries and areas
# Afghanistan                                          33 x
# Albania                                                 5
# Algeria                                               3 x
# Andorra                                                 –
# Angola                                               16 x
#
#                     Underweight (%) - Severe Stunting (%) Wasting (%)  \
# Countries and areas
# Afghanistan                           12.2 x         59 x         9 x
# Albania                                  1.7           19           9
# Algeria                                0.9 x         15 x         4 x
# Andorra                                    –            –           –
# Angola                                 6.6 x         29 x       8.2 x
#
#                     Overweight (%)  \
# Countries and areas
# Afghanistan                  4.6 x
# Albania                       21.7
# Algeria                     12.9 x
# Andorra                          –
# Angola                           –
#
#                     Vitamin A supplementation, full coverageΔ (%)  \
# Countries and areas
# Afghanistan                                                     –
# Albania                                                         –
# Algeria                                                         –
# Andorra                                                         –
# Angola                                                         44
#
#                     Iodized salt consumption (%)
# Countries and areas
# Afghanistan                                 20.4
# Albania                                     75.6
# Algeria                                   60.7 x
# Andorra                                        –
# Angola                                    44.7 x

# %%
print(f"The shape of the dataframe is: {df.shape}")
# Out:
# The shape of the dataframe is: (197, 12)

# %% [markdown]
# Finally, you have extracted the data table from our Excel file, and put it into a Pandas DataFrame.
# The DataFrame has 197 rows and 12 columns, where rows correspond to records for individual countries
# and columns are variables (or attributes).
# Our last step is to save the data table in a CSV file.

# %%
df = df.reset_index()
df
# Out:
#                     Countries and areas Low birthweight (%)  \
# 0                           Afghanistan                   –
# 1                               Albania                 3.6
# 2                               Algeria                 6 x
# 3                               Andorra                   –
# 4                                Angola                12 x
# ..                                  ...                 ...
# 192  Venezuela (Bolivarian Republic of)                   8
# 193                            Viet Nam                 5.1
# 194                               Yemen                   –
# 195                              Zambia                11 x
# 196                            Zimbabwe                  11
#
#     Early initiation of breastfeeding (%)  \
# 0                                       –
# 1                                    42.9
# 2                                  49.5 x
# 3                                       –
# 4                                  54.9 x
# ..                                    ...
# 192                                     –
# 193                                  39.7
# 194                                  30 x
# 195                                56.5 x
# 196                                  65.2
#
#     Exclusive breastfeeding <6 months (%)  \
# 0                                       –
# 1                                    38.6
# 2                                     7 x
# 3                                       –
# 4                                    11 x
# ..                                    ...
# 192                                     –
# 193                                    17
# 194                                  12 x
# 195                                  61 x
# 196                                  31.4
#
#     Introduction of solid, semi-solid or soft foods (%)  \
# 0                                                 29 x
# 1                                            78.278804
# 2                                               39 x,y
# 3                                                    –
# 4                                               77.2 x
# ..                                                 ...
# 192                                                  –
# 193                                               50.4
# 194                                           76.3 x,y
# 195                                  94.341801380852 x
# 196                                                 86
#
#     Breastfeeding at age 2 (%) Underweight (%) - Moderate and Severe  \
# 0                         54 x                                  33 x
# 1                           31                                     5
# 2                       22.2 x                                   3 x
# 3                            –                                     –
# 4                         37 x                                  16 x
# ..                         ...                                   ...
# 192                          –                                 3.7 x
# 193                       19.4                                  11.7
# 194                          –                                43.1 x
# 195                     41.7 x                                14.6 x
# 196                       19.5                                   9.7
#
#     Underweight (%) - Severe Stunting (%) Wasting (%) Overweight (%)  \
# 0                     12.2 x         59 x         9 x          4.6 x
# 1                        1.7           19           9           21.7
# 2                      0.9 x         15 x         4 x         12.9 x
# 3                          –            –           –              –
# 4                      6.6 x         29 x       8.2 x              –
# ..                       ...          ...         ...            ...
# 192                        –       15.6 x         5 x          6.1 x
# 193                      1.8         22.7         4.1            4.4
# 194                   18.5 x       57.7 x      15.2 x            5 x
# 195                    2.9 x       45.4 x       5.2 x          7.9 x
# 196                      1.9           32           3            5.5
#
#     Vitamin A supplementation, full coverageΔ (%) Iodized salt consumption (%)
# 0                                               –                         20.4
# 1                                               –                         75.6
# 2                                               –                       60.7 x
# 3                                               –                            –
# 4                                              44                       44.7 x
# ..                                            ...                          ...
# 192                                             –                            –
# 193                                          98 w                         45.1
# 194                                            11                       29.5 x
# 195                                             –                       77.4 x
# 196                                            61                         94 y
#
# [197 rows x 13 columns]

# %%
df.to_csv("nutrition.csv", index=False)

# %% [markdown]
# ## 2. Parsing CSV & JSON Files
#
# Due to advances in technologies for data storage, data from various sources is always stored in different formats
# and file types.
# Some data formats store data in a way that can be easily handled by a machine, such as CSV, JSON, and XML.
# Those formats are usually referred to as machine-readable formats.
# In contrast, some other data formats or file types store data in a way meant to be read by a human
# using front-end desktop tools.
# Those formats or file types are often referred to as hard-to-parse formats.
# We will use a series of examples to demonstrate how to extract data stored in
# both machine-readable and hard-to-parse formats,
# and then store the extracted data in formats that can be easily adopted by the downstream data wranngling tasks.
# This chapter will cover how to read the common machine-readable formats:
# * **CSV**: Comma Separated Values
# * **JSON**: JavaScript Object Notation
#
# In most cases, the two formats togeather with XML are the best available resource while you are scraping data from
# the web or requesting data directly from an organization or agency.
# They are more easily used and ingested by programming languages, like Python.
# Our suggestion is that you should try your best to get data in these formats, before you start looking
# into other formats that might be hard to parse, like PDFs.
#
# There are many ways of reading and storing data in those formats,
# which depends on the programming language you use.
# Here we are going to focus on Python.
# Searching the Internet, you will find there are a lot of online tutorials on handling data stored in different
# data formats with Python.
# We suggest the following:
# * "*Data Loading, Storage, and File Formats*", Chapter 6 of "**Python for Data Analysis**": This chapter covers reading files in a variety of formats, loading data from databases and interacting with Internet via APIs. Please read pages 155-166, and download and run the Python scripts from [the author's github site](https://github.com/pydata/pydata-book). 📖
#
# The dataset used in this chapter was downloaded from
# [data.gov.au](https://data.melbourne.vic.gov.au/explore/dataset/melbourne-bike-share-station-readings-2011-2017/information/).
# It is available in the following formats: CSV, JSON, XML, RDF, etc.
# The first two formats are used, i.e., the following two files
# * Melbourne_bike_share.csv
# * Melbourne_bike_share.json
#
# In the following sections, you will learn how to scrape data from the two
# example files, and store the extracted data into Pandas DataFrame.
#
# ### 2.1 Example scenario
# Assume that you are going to analyze and predict bicycle hubway station status to answer the following questions:
# * What do usage patterns look like with respect to specific stations and how that translates to imbalances in the system?
# * Can we integrate these explanatory variables and these usage patterns into a predictive algorithm that would predict empty and full stations in the near future?
# * What form should that algorithm take?
# * How do environmental variables affect the future state of Hubway stations?
#
# See <a href="http://cs109hubway.github.io/classp/"><font color="red">Predicting Hubway Stations status in Boston</font></a> for more discussion.
#
# The first step we have to do is to acquire the hub station data and as well as weather data. Here, for demonstration purpose, we use the Melbourne bike share data published by the government. The files have been downloaded and come along with this notebook.
#
# * * *

# %% [markdown]
# ### 2.2 Parsing CSV file
# A CSV is a Comma Separated Values file, which allows data to be saved in a tabular format.
# Each row of the file is a data record; each column is a field (or an attribute).
# Each data record consists of one or more fields, separated by commas.
# As one of the most popular file formats,
# it is supported by any spreadsheet programs, such as
# Microsoft Excel, Open Office Calc, and Google Spreadsheets,
# Because of its simplicity,
# it differs from other spreadsheet file types, such as Excel, in that one can only store a single sheet in a file.
# It cannot be used to store cell, columns or row styling, figures and formulas.
# To make our CSV file, i.e., Melbourne_bike_share.csv, easier to view here,
# a sample of the data with trimmed down records is shown below.
# You should see something similar to this when you open the excel file in your text editor,
# ![csv1.png](./csv1.png)
#
# Note that tabs can also be used to separate values of different fields.
# This type of files is usually called TSV, Tab Separated Values.
# Sometimes TSVs get classified as CSVs.
# The only difference between CSVs and TSVs is the delimiter.
# Essentially, the two types of files will act the same in Python and most of the other
# programming languages.
# It is worth mentioning that they often take the form of a text file containing information
# separated by commas.
# This section will show you how to use Pandas
# [read_csv()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html) function to
# load our CSV file, and how to tidy the loaded data a bit.
# Before we start importing our CSV file, it might be good for you to read [Pandas tutorial
# on reading CSV files](http://pandas.pydata.org/pandas-docs/stable/io.html#io-read-csv-table) 📖.

# %% [markdown]
# ### 2.3 Alternative approach to inspect your data

# %%
with open("parsing_csv_json/Melbourne_bike_share.csv", 'r') as f:
    for line in f.readlines()[:10]:
        print (line)
# Out:
# ID,Featurename,TerminalName,NBBikes,NBEmptydoc,UploadDate,Coordinates
#
# 2,Harbour Town - Docklands Dve - Docklands,60000,9,14,28/01/2016 12:30:05 PM +0000,"(-37.814022, 144.939521)"
#
# 4,Federation Square - Flinders St / Swanston St - City,60001,12,10,28/01/2016 12:30:05 PM +0000,"(-37.817523, 144.967814)"
#
# 5,Plum Garland Reserve - Beaconsfield Pde - Albert Park,60002,16,1,28/01/2016 12:30:05 PM +0000,"(-37.84782, 144.948196)"
#
# 6,State Library - Swanston St / Little Lonsdale St - City,60003,9,2,28/01/2016 12:30:05 PM +0000,"(-37.810702, 144.964417)"
#
# 7,Bourke Street Mall - 205 Bourke St - City,60004,9,2,28/01/2016 12:30:05 PM +0000,"(-37.813088, 144.967437)"
#
# 8,Melbourne Uni - Tin Alley - Carlton,60005,2,17,28/01/2016 12:30:05 PM +0000,"(-37.79625, 144.960858)"
#
# 9,RMIT - Swanston St / Franklin St - City,60006,9,2,28/01/2016 12:30:05 PM +0000,"(-37.807699, 144.963095)"
#
# 10,St Paul's Cathedral - Swanston St / Flinders St - City,60007,4,7,28/01/2016 12:30:05 PM +0000,"(-37.817189, 144.967409)"
#
# 11,MSAC - Aughtie Dve - Albert Park,60008,9,18,28/01/2016 12:30:05 PM +0000,"(-37.842395, 144.961868)"

# %%
with open("parsing_csv_json/Melbourne_bike_share.csv", 'r') as f:
    for line in f.readlines()[-10:]:
        print (line)
# Out:
# 46,South Melbourne Market - York St / Cecil St - South Melbourne,60039,9,6,28/01/2016 12:30:06 PM +0000,"(-37.831475, 144.957511)"
#
# 47,VCAM - St Kilda Rd / Southbank Blvd - Southbank,60040,6,5,28/01/2016 12:30:06 PM +0000,"(-37.824088, 144.970085)"
#
# 48,Museum - Rathdowne St - Carlton,60041,4,11,28/01/2016 12:30:06 PM +0000,"(-37.803868, 144.969609)"
#
# 49,Jolimont Station - Wellington Pde South - East Melbourne,60042,3,8,28/01/2016 12:30:06 PM +0000,"(-37.816731, 144.982006)"
#
# 50,ACCA - Sturt St - Southbank,60043,15,8,28/01/2016 12:30:06 PM +0000,"(-37.826578, 144.966542)"
#
# 51,ANZ - Collins St - Docklands,60044,9,10,28/01/2016 12:30:06 PM +0000,"(-37.821568, 144.944488)"
#
# 52,Flagstaff Gardens - Peel St - West Melbourne,60048,6,5,28/01/2016 12:30:06 PM +0000,"(-37.809216, 144.955223)"
#
# 53,Victoria Market - Elizabeth St / Victoria St - City,60049,15,10,28/01/2016 12:30:06 PM +0000,"(-37.806091, 144.959017)"
#
# 55,Coventry St / Clarendon St - South Melbourne,60050,7,4,28/01/2016 12:30:06 PM +0000,"(-37.831776, 144.960818)"
#
# 57,Fitzroy Street - St Kilda,60052,19,12,28/01/2016 12:30:06 PM +0000,"(-37.858655, 144.978818)"

# %% [markdown]
# ### 2.4 Importing CSV data
# Importing CSV files with Pandas <a href='http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html'><font color = "blue">read_csv()</font></a> function and converting the data into a form Python can understand
# is simple.
# It only takes a couple of lines of code.
# The imported data will be stored in Pandas DataFrame.

# %%
import pandas as pd
csvdf = pd.read_csv("parsing_csv_json/Melbourne_bike_share.csv")
type(csvdf)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Or you can use the <a href="http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_table.html"><font color='blue'>read_table()</font></a> function

# %%
csvdf_1 = pd.read_table("parsing_csv_json/Melbourne_bike_share.csv", sep=",")
type(csvdf_1)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Now, the data should be loaded into Python.
# Let's have a look at the first 5 records in the dataset.
# There are a coupe of ways to retrieve these records.
# For example, you can use
# * <font color='blue'>csvdf.head(n = 5)</font>: It will return first `n` rows in a DataFrame, n = 5 by default.
# * <font color='blue'>csvdf[:5]</font>: It uses the slicing method to retrieve the first 5 rows
#
# Refer to "[Indexing and Selecting Data](http://pandas.pydata.org/pandas-docs/stable/indexing.html)"
# for how to slice, dice, and generally get and set subsets of pandas objects.
# Here, we use the `head` function.

# %%
csvdf.head()
#csvdf.loc[:4]
#csvdf[:5]
# Out:
#    ID                                        Featurename  TerminalName  \
# 0   2           Harbour Town - Docklands Dve - Docklands         60000
# 1   4  Federation Square - Flinders St / Swanston St ...         60001
# 2   5  Plum Garland Reserve - Beaconsfield Pde - Albe...         60002
# 3   6  State Library - Swanston St / Little Lonsdale ...         60003
# 4   7          Bourke Street Mall - 205 Bourke St - City         60004
#
#    NBBikes  NBEmptydoc                    UploadDate               Coordinates
# 0        9          14  28/01/2016 12:30:05 PM +0000  (-37.814022, 144.939521)
# 1       12          10  28/01/2016 12:30:05 PM +0000  (-37.817523, 144.967814)
# 2       16           1  28/01/2016 12:30:05 PM +0000   (-37.84782, 144.948196)
# 3        9           2  28/01/2016 12:30:05 PM +0000  (-37.810702, 144.964417)
# 4        9           2  28/01/2016 12:30:05 PM +0000  (-37.813088, 144.967437)

# %%
csvdf.tail()
# Out:
#     ID                                        Featurename  TerminalName  \
# 45  51                       ANZ - Collins St - Docklands         60044
# 46  52       Flagstaff Gardens - Peel St - West Melbourne         60048
# 47  53  Victoria Market - Elizabeth St / Victoria St -...         60049
# 48  55       Coventry St / Clarendon St - South Melbourne         60050
# 49  57                          Fitzroy Street - St Kilda         60052
#
#     NBBikes  NBEmptydoc                    UploadDate  \
# 45        9          10  28/01/2016 12:30:06 PM +0000
# 46        6           5  28/01/2016 12:30:06 PM +0000
# 47       15          10  28/01/2016 12:30:06 PM +0000
# 48        7           4  28/01/2016 12:30:06 PM +0000
# 49       19          12  28/01/2016 12:30:06 PM +0000
#
#                  Coordinates
# 45  (-37.821568, 144.944488)
# 46  (-37.809216, 144.955223)
# 47  (-37.806091, 144.959017)
# 48  (-37.831776, 144.960818)
# 49  (-37.858655, 144.978818)

# %% [markdown]
# Currently, the row indices are integers automatically generated by Pandas.
# Suppose you want to set IDs as row indices and delete the ID column.
# Resetting the row indices can be easily done with the following DataFrame function
# ```python
#     DataFrame.set_index(keys, drop=True, append=False, inplace=False, verify_integrity=False)
# ```
# See its [API webpage](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.set_index.html)
# for the detailed usage.
# The keys are going to be the IDs in the first column.
# By setting `inplace = True`, the corresponding change is done inplace and won't return a new DataFrame object.

# %%
csvdf.set_index(csvdf.ID, inplace = True)
csvdf.head()
# Out:
#     ID                                        Featurename  TerminalName  \
# ID
# 2    2           Harbour Town - Docklands Dve - Docklands         60000
# 4    4  Federation Square - Flinders St / Swanston St ...         60001
# 5    5  Plum Garland Reserve - Beaconsfield Pde - Albe...         60002
# 6    6  State Library - Swanston St / Little Lonsdale ...         60003
# 7    7          Bourke Street Mall - 205 Bourke St - City         60004
#
#     NBBikes  NBEmptydoc                    UploadDate  \
# ID
# 2         9          14  28/01/2016 12:30:05 PM +0000
# 4        12          10  28/01/2016 12:30:05 PM +0000
# 5        16           1  28/01/2016 12:30:05 PM +0000
# 6         9           2  28/01/2016 12:30:05 PM +0000
# 7         9           2  28/01/2016 12:30:05 PM +0000
#
#                  Coordinates
# ID
# 2   (-37.814022, 144.939521)
# 4   (-37.817523, 144.967814)
# 5    (-37.84782, 144.948196)
# 6   (-37.810702, 144.964417)
# 7   (-37.813088, 144.967437)

# %% [markdown]
# To remove the ID column that is now redundant, you use DataFrame `drop` function and set `inplace = True`
# ```python
#     DataFrame.drop(labels, axis=0, level=None, inplace=False, errors='raise')
# ```

# %%
csvdf.drop('ID', axis=1, inplace = True)
csvdf.head()
# Out:
#                                           Featurename  TerminalName  NBBikes  \
# ID
# 2            Harbour Town - Docklands Dve - Docklands         60000        9
# 4   Federation Square - Flinders St / Swanston St ...         60001       12
# 5   Plum Garland Reserve - Beaconsfield Pde - Albe...         60002       16
# 6   State Library - Swanston St / Little Lonsdale ...         60003        9
# 7           Bourke Street Mall - 205 Bourke St - City         60004        9
#
#     NBEmptydoc                    UploadDate               Coordinates
# ID
# 2           14  28/01/2016 12:30:05 PM +0000  (-37.814022, 144.939521)
# 4           10  28/01/2016 12:30:05 PM +0000  (-37.817523, 144.967814)
# 5            1  28/01/2016 12:30:05 PM +0000   (-37.84782, 144.948196)
# 6            2  28/01/2016 12:30:05 PM +0000  (-37.810702, 144.964417)
# 7            2  28/01/2016 12:30:05 PM +0000  (-37.813088, 144.967437)

# %% [markdown]
# Instead of using the above method of setting row indices to IDs, you can specify which column to
# be used as row indices while reading the CSV file. See the API reference page for
# [pandas.read_csv](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html).
# To do so, you can use the <font color='blue'>index_col</font> argument of <font color='blue'>read_csv()</font>.

# %%
csvdf = pd.read_csv("parsing_csv_json/Melbourne_bike_share.csv", index_col = "ID")
csvdf.head()
# Out:
#                                           Featurename  TerminalName  NBBikes  \
# ID
# 2            Harbour Town - Docklands Dve - Docklands         60000        9
# 4   Federation Square - Flinders St / Swanston St ...         60001       12
# 5   Plum Garland Reserve - Beaconsfield Pde - Albe...         60002       16
# 6   State Library - Swanston St / Little Lonsdale ...         60003        9
# 7           Bourke Street Mall - 205 Bourke St - City         60004        9
#
#     NBEmptydoc                    UploadDate               Coordinates
# ID
# 2           14  28/01/2016 12:30:05 PM +0000  (-37.814022, 144.939521)
# 4           10  28/01/2016 12:30:05 PM +0000  (-37.817523, 144.967814)
# 5            1  28/01/2016 12:30:05 PM +0000   (-37.84782, 144.948196)
# 6            2  28/01/2016 12:30:05 PM +0000  (-37.810702, 144.964417)
# 7            2  28/01/2016 12:30:05 PM +0000  (-37.813088, 144.967437)

# %% [markdown]
# Similarly, with the <font color='blue'>read_table()</font> function, you can also set the value of <font color='blue'> index_col</font> to "ID".

# %% [markdown]
# ### 2.5 Manipulating the Data
#
# So far, you have learned a little bit about the Melbourne_bike_share data.
# Let's further process the data by splitting the coordinates into latitude and longitude.
# First figure out what type of data we're dealing with, i.e., the data type of the "Coordinates" column.

# %%
type(csvdf['Coordinates'])
# type(csvdf.Coordinates)
# Out:
# pandas.core.series.Series

# %%
print(csvdf['Coordinates'].iloc[0])
type(csvdf['Coordinates'].iloc[0])
# Out:
# (-37.814022, 144.939521)
# str

# %% [markdown]
# Those coordinates are indeed strings. Thus, to extract both latitude and longitude, you
# can either use regular expressions introduced in the previous chapter or common string operations.
#
# To use regular expressions, the key is figuring out the patterns of characters. Then
# according to those patterns, you formulate your regular expressions.
# Looking at the first couple of coordinates in the Series object, i.e.:
# ```
#     (-37.814022, 144.939521)
#     (-37.817523, 144.967814)
#     (-37.84782, 144.948196)
# ```
# You will find that latitudes are always negative real values, and longitudes are positive real values.
# That is because Australia lies between latitudes 9° and 44°S, and longitudes 112° and 154°E.
# The regular expression is
# ```
#     r"-?\d+\.?\d*"
# ```
# ![](./regex1.jpg)
#
# It contains four parts
# * "-?": optionally matches a single '-'.
# * "\d+": matches one or more digits.
# * "\\.?": optionally matches a single dot.
# * "\d*": matches zero or more digits.
#
# The following code extracts all real values matching this regular expression.
# The <font color="blue">re.findall()</font> returns all matched values in a Python list.

# %%
import re
str1 = csvdf['Coordinates'].iloc[0] # csvdf.Coordinates
re.findall(r"-?\d+\.?\d*", str1)
# Out:
# ['-37.814022', '144.939521']

# %% [markdown]
# Using common string operations might be simpler than using regular expressions.
# <font color="blue">str.split()</font> is the function used here to extract both latitudes and longitudes.
# However, you should choose a proper delimiter to split a string.
# First, split the string by ',':

# %%
s = csvdf['Coordinates'].iloc[1].split(', ') # assuming they're all '(x, y)'
print ('lat = ', s[0], ' long = ', s[1])
# Out:
# lat =  (-37.817523  long =  144.967814)

# %% [markdown]
# The printout shows that the latitude contains '(', and the longitude contains ')'.
# You should consider removing both the left and the right parentheses.
# Of course, the `split` function can be used again.
# Note that the goal here is to remove the leading and trailing parentheses.
# Python string class provides two functions to do the two operations,
# which are:
# * <font color="blue">string.lstrip()</font>: returns a copy of the string with leading characters removed
# * <font color="blue">string.rstrip()</font>: returns a copy of the string with trailing characters removed.
#
# Let's try the two functions.

# %%
print(s[0].lstrip('('))
print(s[1].rstrip(')'))
# Out:
# -37.817523
# 144.967814

# %% [markdown]
# The latitude and longitude in the first coordinate have been successfully extracted.
# Next, we are going to apply the extracting process to every coordinate in the DataFrame.
# There are multiple ways of doing that.
# The most straightforward way is to write a FOR loop to iterate over all the coordinates,
# and apply the above scripts to each individual coordinate.
# Two Pandas Series can be then used to store latitudes and longitudes.
# However, we are going to show you how to use some advanced Python programming functionality.
#
# Pandas Series class implements an [`apply()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.apply.html) method that applies a given function
# to all values in a Series object, and returns a new one.
# Please note that this function can only works on single values.
# To apply <font color="blue">str.split()</font> to every coordinate and
# get latitudes and longitudes, you can use the following two lines of code:

# %%
csvdf['lat'] = csvdf['Coordinates'].apply(lambda x: x.split(', ')[0])
csvdf['lon'] = csvdf['Coordinates'].apply(lambda x: x.split(', ')[1])
csvdf.head()
# Out:
#                                           Featurename  TerminalName  NBBikes  \
# ID
# 2            Harbour Town - Docklands Dve - Docklands         60000        9
# 4   Federation Square - Flinders St / Swanston St ...         60001       12
# 5   Plum Garland Reserve - Beaconsfield Pde - Albe...         60002       16
# 6   State Library - Swanston St / Little Lonsdale ...         60003        9
# 7           Bourke Street Mall - 205 Bourke St - City         60004        9
#
#     NBEmptydoc                    UploadDate               Coordinates  \
# ID
# 2           14  28/01/2016 12:30:05 PM +0000  (-37.814022, 144.939521)
# 4           10  28/01/2016 12:30:05 PM +0000  (-37.817523, 144.967814)
# 5            1  28/01/2016 12:30:05 PM +0000   (-37.84782, 144.948196)
# 6            2  28/01/2016 12:30:05 PM +0000  (-37.810702, 144.964417)
# 7            2  28/01/2016 12:30:05 PM +0000  (-37.813088, 144.967437)
#
#             lat          lon
# ID
# 2   (-37.814022  144.939521)
# 4   (-37.817523  144.967814)
# 5    (-37.84782  144.948196)
# 6   (-37.810702  144.964417)
# 7   (-37.813088  144.967437)

# %% [markdown]
# The first line extracts all the latitudes and store them in a column in our DataFrame.
# The second line extracts all the longitudes.
# You might wonder what "lambda" is in the code.
# It is a Python keyword used to construct small anonymous functions at runtime. (See [Section 4.7.5. Lambda Expressions](https://docs.python.org/2/tutorial/controlflow.html) 📖 )
# You can use a similar approach to remove the heading and trailing parentheses.

# %%
csvdf['lat'] = csvdf['lat'].apply(lambda x: x.lstrip('('))
csvdf['lon'] = csvdf['lon'].apply(lambda x: x.rstrip(')'))
csvdf.drop('Coordinates', axis=1, inplace = True)
csvdf.head()
# Out:
#                                           Featurename  TerminalName  NBBikes  \
# ID
# 2            Harbour Town - Docklands Dve - Docklands         60000        9
# 4   Federation Square - Flinders St / Swanston St ...         60001       12
# 5   Plum Garland Reserve - Beaconsfield Pde - Albe...         60002       16
# 6   State Library - Swanston St / Little Lonsdale ...         60003        9
# 7           Bourke Street Mall - 205 Bourke St - City         60004        9
#
#     NBEmptydoc                    UploadDate         lat         lon
# ID
# 2           14  28/01/2016 12:30:05 PM +0000  -37.814022  144.939521
# 4           10  28/01/2016 12:30:05 PM +0000  -37.817523  144.967814
# 5            1  28/01/2016 12:30:05 PM +0000   -37.84782  144.948196
# 6            2  28/01/2016 12:30:05 PM +0000  -37.810702  144.964417
# 7            2  28/01/2016 12:30:05 PM +0000  -37.813088  144.967437

# %% [markdown]
# So far, we have split the "Coordinates" column into two columns, i.e., "lat" and 'lon' in the DataFrame,
# and dumped the "Coordinates" column.
# The last step is to infer better type for object columns.
# All the numerical values and dates are encoded as strings in the current DataFrame.
# We would like to convert those values to types that they are supposed to have.

# %%
csvdf.dtypes
# Out:
# Featurename     object
# TerminalName     int64
# NBBikes          int64
# NBEmptydoc       int64
# UploadDate      object
# lat             object
# lon             object
# dtype: object

# %%
csvdf = csvdf.apply(pd.to_numeric, errors='ignore')
csvdf.dtypes
# Out:
# Featurename      object
# TerminalName      int64
# NBBikes           int64
# NBEmptydoc        int64
# UploadDate       object
# lat             float64
# lon             float64
# dtype: object

# %% [markdown]
# However, dates are still strings, which means the `convert_object` function cannot convert data strings to datatime
# object.
# Here you need to force them to be converted to datatime object with [`pd.to_datetime`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html).

# %%
csvdf['UploadDate'] = pd.to_datetime(csvdf['UploadDate'])
print (csvdf.dtypes)
csvdf
# Out:
# Featurename                  object
# TerminalName                  int64
# NBBikes                       int64
# NBEmptydoc                    int64
# UploadDate      datetime64[ns, UTC]
# lat                         float64
# lon                         float64
# dtype: object
#                                           Featurename  TerminalName  NBBikes  \
# ID
# 2            Harbour Town - Docklands Dve - Docklands         60000        9
# 4   Federation Square - Flinders St / Swanston St ...         60001       12
# 5   Plum Garland Reserve - Beaconsfield Pde - Albe...         60002       16
# 6   State Library - Swanston St / Little Lonsdale ...         60003        9
# 7           Bourke Street Mall - 205 Bourke St - City         60004        9
# 8                 Melbourne Uni - Tin Alley - Carlton         60005        2
# 9             RMIT - Swanston St / Franklin St - City         60006        9
# 10  St Paul's Cathedral - Swanston St / Flinders S...         60007        4
# 11                   MSAC - Aughtie Dve - Albert Park         60008        9
# 12              Fitzroy Town Hall - Moor St - Fitzroy         60009        3
# 15              Coventry St / St Kilda Rd - Southbank         60017        5
# 16          NAB - Harbour Esp / Bourke St - Docklands         60011       13
# 17  Yarra's Point - Lorimer St / Yarra River - Doc...         60024        5
# 18                 Argyle Square - Lygon St - Carlton         60021        0
# 20  Parliament Station - Nicholson St / Albert St ...         60025        8
# 21            Bridport St / Montague St - Albert Park         60014        8
# 22            Pickles St / Ingles St - Port Melbourne         60027       12
# 23  Yarra's Edge - River Esp / Yarra River - Dockl...         60015        6
# 24  North Melbourne Station - Adderley St - North ...         60038        7
# 25                       Sandridge Bridge - Southbank         60026        1
# 26                          Beach St - Port Melbourne         60029       20
# 27            New Quay Prom / Harbour Esp - Docklands         60028        6
# 28          Queensbridge St / Yarra River - Southbank         60035        4
# 29         Southern Cross Station - Spencer St - City         60034        2
# 30      Gasworks Arts Park - Pickles St - Albert Park         60023        6
# 31              Cleve Gardens - Fitzroy St - St Kilda         60032       12
# 32  West Beach Pavilion - Beaconsfield Pde - St Ki...         60030        6
# 33         Siddeley St / Seafarers Bridge - Docklands         60031       19
# 34          RACV - Bourke St / New Chancery Ln - City         60013        8
# 35    Yorkshire Brewery - Wellington St - Collingwood         60033        5
# 36                 Napier St / Victoria Pde - Fitzroy         60022        7
# 37           University Square - Grattan St - Carlton         60045        4
# 38          Aquarium - Kings Way / Flinders St - City         60046        7
# 39    Richmond Station - Brunton Ave - East Melbourne         60020       11
# 40      Rod Laver Arena - Batman Ave / Swan St - City         60047       12
# 41  Domain Interchange - Park St / St Kilda Rd - M...         60016       14
# 42                Kings Way / St Kilda Rd - Melbourne         60018       21
# 43                      Spring St / Collins St - City         60019        8
# 44                 Queens Rd / Bowen Cres - Melbourne         60036       12
# 45                   Luna Park - Lower Esp - St Kilda         60037       19
# 46  South Melbourne Market - York St / Cecil St - ...         60039        9
# 47    VCAM - St Kilda Rd / Southbank Blvd - Southbank         60040        6
# 48                    Museum - Rathdowne St - Carlton         60041        4
# 49  Jolimont Station - Wellington Pde South - East...         60042        3
# 50                        ACCA - Sturt St - Southbank         60043       15
# 51                       ANZ - Collins St - Docklands         60044        9
# 52       Flagstaff Gardens - Peel St - West Melbourne         60048        6
# 53  Victoria Market - Elizabeth St / Victoria St -...         60049       15
# 55       Coventry St / Clarendon St - South Melbourne         60050        7
# 57                          Fitzroy Street - St Kilda         60052       19
#
#     NBEmptydoc                UploadDate        lat         lon
# ID
# 2           14 2016-01-28 12:30:05+00:00 -37.814022  144.939521
# 4           10 2016-01-28 12:30:05+00:00 -37.817523  144.967814
# 5            1 2016-01-28 12:30:05+00:00 -37.847820  144.948196
# 6            2 2016-01-28 12:30:05+00:00 -37.810702  144.964417
# 7            2 2016-01-28 12:30:05+00:00 -37.813088  144.967437
# 8           17 2016-01-28 12:30:05+00:00 -37.796250  144.960858
# 9            2 2016-01-28 12:30:05+00:00 -37.807699  144.963095
# 10           7 2016-01-28 12:30:05+00:00 -37.817189  144.967409
# 11          18 2016-01-28 12:30:05+00:00 -37.842395  144.961868
# 12           4 2016-01-28 12:30:05+00:00 -37.801813  144.979209
# 15           6 2016-01-28 12:30:05+00:00 -37.828887  144.970822
# 16          20 2016-01-28 12:30:05+00:00 -37.818306  144.945923
# 17           9 2016-01-28 12:30:05+00:00 -37.823805  144.943051
# 18          11 2016-01-28 12:30:05+00:00 -37.802129  144.966770
# 20           7 2016-01-28 12:30:05+00:00 -37.809072  144.972762
# 21          15 2016-01-28 12:30:05+00:00 -37.840885  144.955303
# 22          11 2016-01-28 12:30:05+00:00 -37.835803  144.948520
# 23           5 2016-01-28 12:30:05+00:00 -37.824468  144.946033
# 24           8 2016-01-28 12:30:05+00:00 -37.807021  144.941854
# 25          26 2016-01-28 12:30:05+00:00 -37.820836  144.962266
# 26          19 2016-01-28 12:30:05+00:00 -37.841954  144.935296
# 27          21 2016-01-28 12:30:05+00:00 -37.814117  144.944081
# 28          11 2016-01-28 12:30:05+00:00 -37.821071  144.961113
# 29          24 2016-01-28 12:30:05+00:00 -37.818124  144.953581
# 30           5 2016-01-28 12:30:05+00:00 -37.842174  144.946051
# 31           3 2016-01-28 12:30:05+00:00 -37.861984  144.973410
# 32           9 2016-01-28 12:30:05+00:00 -37.858553  144.969101
# 33           4 2016-01-28 12:30:05+00:00 -37.823124  144.951918
# 34           3 2016-01-28 12:30:05+00:00 -37.815505  144.959278
# 35           2 2016-01-28 12:30:05+00:00 -37.805997  144.986953
# 36           4 2016-01-28 12:30:05+00:00 -37.808266  144.979005
# 37          11 2016-01-28 12:30:05+00:00 -37.800214  144.960313
# 38           4 2016-01-28 12:30:05+00:00 -37.821324  144.958318
# 39           8 2016-01-28 12:30:06+00:00 -37.822962  144.988507
# 40          10 2016-01-28 12:30:06+00:00 -37.822987  144.978459
# 41           1 2016-01-28 12:30:06+00:00 -37.832396  144.971678
# 42           5 2016-01-28 12:30:06+00:00 -37.836323  144.975162
# 43           3 2016-01-28 12:30:06+00:00 -37.813774  144.974054
# 44           3 2016-01-28 12:30:06+00:00 -37.835383  144.973699
# 45          20 2016-01-28 12:30:06+00:00 -37.867068  144.976428
# 46           6 2016-01-28 12:30:06+00:00 -37.831475  144.957511
# 47           5 2016-01-28 12:30:06+00:00 -37.824088  144.970085
# 48          11 2016-01-28 12:30:06+00:00 -37.803868  144.969609
# 49           8 2016-01-28 12:30:06+00:00 -37.816731  144.982006
# 50           8 2016-01-28 12:30:06+00:00 -37.826578  144.966542
# 51          10 2016-01-28 12:30:06+00:00 -37.821568  144.944488
# 52           5 2016-01-28 12:30:06+00:00 -37.809216  144.955223
# 53          10 2016-01-28 12:30:06+00:00 -37.806091  144.959017
# 55           4 2016-01-28 12:30:06+00:00 -37.831776  144.960818
# 57          12 2016-01-28 12:30:06+00:00 -37.858655  144.978818

# %% [markdown]
# Finally, you have loaded the given CSV file into Python with Pandas.
# You have also tidied the data a bit by getting latitudes and longitudes out
# from the strings.
#
# Besides `read_csv`, there are other parsing functions in pandas for
# reading tabular data as a DataFrame object. They include
# * [`read_table`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_table.html): Reads general delimited file into DataFrame. The default delimiter is '\t'.
# * [`read_fwf`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_fwf.html): Reads a table of fixed-width formatted lines into DataFrame.
# * [`read_clipboard`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_clipboard.html): Reads text from clipboard and passes to read_table. See read_table for the full argument list.
# * * *

# %% [markdown]
# ### 2.6 Parsing JSON files
#
# JSON (JavaScript Object Notation) is one of the most commonly used formats
# for transferring data between web services and other applications via HTTP requests.
# Nowadays, many sites have JSON-enabled APIs and
# JSON is quickly becoming the encoding protocol of choice.
# As a light weighted data-interchange format inspired by JavaScript,
# it is clean, easy to read, and easy to parse.
# Here is a simple example adapted from [Wikipedia page on JSON](https://en.wikipedia.org/wiki/JSON)
# ```
# [
# {
#   "firstName": "John",
#   "lastName": "Smith",
#   "age": 25,
#   "address": {
#     "streetAddress": "21 2nd Street",
#     "city": "New York",
#     "state": "NY",
#     "postalCode": "10021"
#    }
# }
# ]
#
# ```
#
# From the above example, you will see that each data record looks like a [Python dictionary](https://docs.python.org/2/tutorial/datastructures.html#dictionaries).
# A JSON file usually contains a list of dictionaries, which is defined by '[' and ']'.
# In each of those dictionaries,
# there is a key-value pair for each row and the key and value are separated by a colon.
# Different key-value pairs are separated by commas.
# Note that a value can also be a dictionary, see "address" in the example.
# The basic types are object, array, value, string and number.
# If you would like to know more about JSON, please refer to
# * [Introducing to JSON](http://www.json.org/): the JSON org website gives a very good diagrammatic explanation
# of JSON 📖.
# * [Introduction to JSON](https://www.youtube.com/watch?v=WWa0cg_xMC8): a 15-minutes Youtube video on JSON, recommended for visual learners.
#
# (Of course, you can also go and find your own materials on JSON by searching the Internet.)
#
# In the rest of this section, we will start from an simple example, walking through steps of acquiring JSON Data from Google Maps Elevation API and normalizing those data into a flat table. Then, we revisit the dataset mentioned in the previous section (except that it is now in JSON format), parsing the data and store them in a Pandas DataFrame object.
# Before we start, it might be good for you to view one of the following tutorials on parsing JSON files:
# * [Working with JSON data](https://www.linkedin.com/learning/learning-python-14393370/working-with-json-data?u=2046060): A Lynda tutorial on parsing JSON data. You need a Monash account to access this website.
# [here](http://resources.lib.monash.edu.au/eresources/lynda-guide.pdf) is the lynda settup guide.
# * A [Youtube video](https://www.youtube.com/watch?v=9Xt2e9x4xwQ ) on extracting data from JSON files (**optional**).

# %% [markdown]
# #### 2.6.1 Acquiring JSON Data From The Internet
# This section will start with showing you how to acquire a small chunk of JSON data
# from Internet via HTTP requests and load it into Python with `json` library.
# The example we used is inspired by the [DBLP database Access API](https://dblp.org/faq/How+to+use+the+dblp+search+API.html). Whcih are used to search for publications in the DBLP database using the DBLP search API.
#
# The first step is to make a HTTP request to get the data from the Google Maps API.
# Here we are going to use [`urllib2`](https://docs.python.org/2/library/urllib2.html) library.
# It defines a set of functions and classes that help in opening URLs.

# %%
from urllib.request import urlopen, Request # for python 3
request = Request("https://dblp.org/search/publ/api?q=data%20wrangling&format=json")
response = urlopen(request)
elevations = response.read()
elevations.splitlines()
# Out:
# [b'{',
#  b'"result":{',
#  b'"query":"data* wrangling*",',
#  b'"status":{',
#  b'"@code":"200",',
#  b'"text":"OK"',
#  b'},',
#  b'"time":{',
#  b'"@unit":"msecs",',
#  b'"text":"17.07"',
#  b'},',
#  b'"completions":{',
#  b'"@total":"1",',
#  b'"@computed":"1",',
#  b'"@sent":"1",',
#  b'"c":{',
#  b'"@sc":"101",',
#  b'"@dc":"100",',
#  b'"@oc":"101",',
#  b'"@id":"62492294",',
#  b'"text":"wrangling"',
#  b'}',
#  b'},',
#  b'"hits":{',
#  b'"@total":"100",',
#  b'"@computed":"100",',
#  b'"@sent":"30",',
#  b'"@first":"0",',
#  b'"hit":[{',
#  b'"@score":"5",',
#  b'"@id":"2369905",',
#  b'"info":{"authors":{"author":{"@pid":"22/3551","text":"Antonio Badia"}},"title":"SQL for Data Science - Data Cleaning, Wrangling and Analytics with Relational Databases","venue":"Data-Centric Systems and Applications","pages":"1-259","publisher":"Springer","year":"2020","type":"Books and Theses","access":"closed","key":"series/dcsa/Badia20","doi":"10.1007/978-3-030-57592-2","ee":"https://doi.org/10.1007/978-3-030-57592-2","url":"https://dblp.org/rec/series/dcsa/Badia20"},',
#  b'"url":"URL#2369905"',
#  b'},',
#  b'{',
#  b'"@score":"5",',
#  b'"@id":"2417006",',
#  b'"info":{"authors":{"author":{"@pid":"221/5219","text":"Otmane Azeroual"}},"title":"Data Wrangling in Database Systems: Purging of Dirty Data.","venue":"Data","volume":"5","number":"2","pages":"50","year":"2020","type":"Journal Articles","access":"open","key":"journals/data/Azeroual20","doi":"10.3390/DATA5020050","ee":"https://doi.org/10.3390/data5020050","url":"https://dblp.org/rec/journals/data/Azeroual20"},',
#  b'"url":"URL#2417006"',
#  b'},',
#  b'{',
#  b'"@score":"5",',
#  b'"@id":"4078610",',
#  b'"info":{"authors":{"author":[{"@pid":"f/TimFurche","text":"Tim Furche"},{"@pid":"g/GeorgGottlob","text":"Georg Gottlob"},{"@pid":"76/970","text":"Bernd Neumayr"},{"@pid":"20/9117","text":"Emanuel Sallinger"}]},"title":"Data Wrangling for Big Data: Towards a Lingua Franca for Data Wrangling.","venue":"AMW","year":"2016","type":"Conference and Workshop Papers","access":"open","key":"conf/amw/FurcheGNS16","ee":"https://ceur-ws.org/Vol-1644/paper20.pdf","url":"https://dblp.org/rec/conf/amw/FurcheGNS16"},',
#  b'"url":"URL#4078610"',
#  b'},',
#  b'{',
#  b'"@score":"4",',
#  b'"@id":"37762",',
#  b'"info":{"authors":{"author":[{"@pid":"412/0399","text":"Wellington Kanyongo"},{"@pid":"44/10879","text":"Absalom El-Shamir Ezugwu"},{"@pid":"412/0315","text":"Tsitsi Moyo"},{"@pid":"74/3508","text":"Jean Vincent Fonou Dombeu"}]},"title":"Data Wrangling and Generation for Machine Learning Models in Medication Adherence Analytics: A practical Standpoint using Patient-Level and Medical Claims Data.","venue":"Data Intell.","volume":"7","number":"2","pages":"485-526","year":"2025","type":"Journal Articles","access":"open","key":"journals/dint/KanyongoEMD25","doi":"10.3724/2096-7004.DI.2024.0037","ee":"https://doi.org/10.3724/2096-7004.di.2024.0037","url":"https://dblp.org/rec/journals/dint/KanyongoEMD25"},',
#  b'"url":"URL#37762"',
#  b'},',
#  b'{',
#  b'"@score":"4",',
#  b'"@id":"1680223",',
#  b'"info":{"authors":{"author":[{"@pid":"221/5219","text":"Otmane Azeroual"},{"@pid":"130/7996","text":"Joachim Sch\xc3\xb6pfel"},{"@pid":"28/8326","text":"Dragan Ivanovic"},{"@pid":"226/1381","text":"Anastasija Nikiforova"}]},"title":"Combining Data Lake and Data Wrangling for Ensuring Data Quality in CRIS.","venue":"CRIS","pages":"3-16","year":"2022","type":"Conference and Workshop Papers","access":"open","key":"conf/eurocris/AzeroualSIN22","doi":"10.1016/J.PROCS.2022.10.171","ee":"https://doi.org/10.1016/j.procs.2022.10.171","url":"https://dblp.org/rec/conf/eurocris/AzeroualSIN22"},',
#  b'"url":"URL#1680223"',
#  b'},',
#  b'{',
#  b'"@score":"4",',
#  b'"@id":"2068332",',
#  b'"info":{"authors":{"author":[{"@pid":"84/7973","text":"Martin Koehler"},{"@pid":"157/1785","text":"Edward Abel"},{"@pid":"202/0373","text":"Alex Bogatu"},{"@pid":"117/8447","text":"Cristina Civili"},{"@pid":"246/1127","text":"Lacramioara Mazilu"},{"@pid":"53/6696-1","text":"Nikolaos Konstantinou 0001"},{"@pid":"f/AAAFernandes","text":"Alvaro A. A. Fernandes"},{"@pid":"53/358","text":"John A. Keane"},{"@pid":"l/LeonidLibkin","text":"Leonid Libkin"},{"@pid":"p/NWPaton","text":"Norman W. Paton"}]},"title":"Incorporating Data Context to Cost-Effectively Automate End-to-End Data Wrangling.","venue":"IEEE Trans. Big Data","volume":"7","number":"1","pages":"169-186","year":"2021","type":"Journal Articles","access":"open","key":"journals/tbd/KoehlerABCMKFKL21","doi":"10.1109/TBDATA.2019.2907588","ee":"https://doi.org/10.1109/TBDATA.2019.2907588","url":"https://dblp.org/rec/journals/tbd/KoehlerABCMKFKL21"},',
#  b'"url":"URL#2068332"',
#  b'},',
#  b'{',
#  b'"@score":"4",',
#  b'"@id":"3798821",',
#  b'"info":{"authors":{"author":{"@pid":"07/6223","text":"Scott Jensen"}},"title":"Introducing Data Science to Undergraduates through Big Data: Answering Questions by Wrangling and Profiling a Yelp Dataset.","venue":"HICSS","pages":"1-10","year":"2017","type":"Conference and Workshop Papers","access":"open","key":"conf/hicss/Jensen17","ee":"https://hdl.handle.net/10125/41275","url":"https://dblp.org/rec/conf/hicss/Jensen17"},',
#  b'"url":"URL#3798821"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"837793",',
#  b'"info":{"authors":{"author":[{"@pid":"60/5086","text":"Yuqing Wang"},{"@pid":"29/11192","text":"Anna Fariha"}]},"title":"Development of Data Evaluation Benchmark for Data Wrangling Recommendation System.","venue":"CoRR","volume":"abs/2409.10635","year":"2024","type":"Informal and Other Publications","access":"open","key":"journals/corr/abs-2409-10635","doi":"10.48550/ARXIV.2409.10635","ee":"https://doi.org/10.48550/arXiv.2409.10635","url":"https://dblp.org/rec/journals/corr/abs-2409-10635"},',
#  b'"url":"URL#837793"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"1024144",',
#  b'"info":{"authors":{"author":[{"@pid":"261/1970","text":"Nico Sch\xc3\xa4fer"},{"@pid":"266/6160","text":"Damjan Gjurovski"},{"@pid":"261/1893","text":"Angjela Davitkova"},{"@pid":"m/SebastianMichel","text":"Sebastian Michel 0001"}]},"title":"To UDFs and Beyond: Demonstration of a Fully Decomposed Data Processor for General Data Wrangling Tasks.","venue":"Proc. VLDB Endow.","volume":"16","number":"12","pages":"4018-4021","year":"2023","type":"Journal Articles","access":"open","key":"journals/pvldb/SchaferGD023","doi":"10.14778/3611540.3611610","ee":"https://www.vldb.org/pvldb/vol16/p4018-gjurovski.pdf","url":"https://dblp.org/rec/journals/pvldb/SchaferGD023"},',
#  b'"url":"URL#1024144"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"1081793",',
#  b'"info":{"authors":{"author":[{"@pid":"50/8166","text":"Tomas Petricek 0001"},{"@pid":"203/7226","text":"Gerrit J. J. van den Burg"},{"@pid":"13/8853","text":"Alfredo Naz\xc3\xa1bal"},{"@pid":"254/2065","text":"Taha Ceritli"},{"@pid":"22/5749","text":"Ernesto Jim\xc3\xa9nez-Ruiz"},{"@pid":"w/ChristopherKIWilliams","text":"Christopher K. I. Williams"}]},"title":"AI Assistants: A Framework for Semi-Automated Data Wrangling.","venue":"IEEE Trans. Knowl. Data Eng.","volume":"35","number":"9","pages":"9295-9306","year":"2023","type":"Journal Articles","access":"closed","key":"journals/tkde/PetricekBNCJW23","doi":"10.1109/TKDE.2022.3222538","ee":"https://doi.org/10.1109/TKDE.2022.3222538","url":"https://dblp.org/rec/journals/tkde/PetricekBNCJW23"},',
#  b'"url":"URL#1081793"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"1245499",',
#  b'"info":{"authors":{"author":[{"@pid":"185/5926","text":"Florentina Armaselu"},{"@pid":"10/8162","text":"Barbara McGillivray"},{"@pid":"128/7478","text":"Chaya Liebeskind"},{"@pid":"300/5702","text":"Giedre Valunaite Oleskeviciene"},{"@pid":"20/11089","text":"Andrius Utka"},{"@pid":"133/9329","text":"Daniela Gifu"},{"@pid":"222/0968","text":"Anas Fahad Khan"},{"@pid":"65/11004","text":"Elena Simona Apostol"},{"@pid":"174/6740","text":"Ciprian-Octavian Truica"}]},"title":"Workflow Reversal and Data Wrangling in Multilingual Diachronic Analysis and Linguistic Linked Open Data Modelling.","venue":"LDK","pages":"410-416","year":"2023","type":"Conference and Workshop Papers","access":"closed","key":"conf/ldk/ArmaseluMLOUGKAT23","ee":"https://aclanthology.org/2023.ldk-1.43","url":"https://dblp.org/rec/conf/ldk/ArmaseluMLOUGKAT23"},',
#  b'"url":"URL#1245499"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"1289159",',
#  b'"info":{"authors":{"author":[{"@pid":"225/7825","text":"Nischal Shrestha"},{"@pid":"292/9532","text":"Bhavya Chopra"},{"@pid":"144/5345","text":"Austin Z. Henley"},{"@pid":"46/2873","text":"Chris Parnin"}]},"title":"Detangler: Helping Data Scientists Explore, Understand, and Debug Data Wrangling Pipelines.","venue":"VL/HCC","pages":"189-198","year":"2023","type":"Conference and Workshop Papers","access":"closed","key":"conf/vl/ShresthaCHP23","doi":"10.1109/VL-HCC57772.2023.00031","ee":"https://doi.org/10.1109/VL-HCC57772.2023.00031","url":"https://dblp.org/rec/conf/vl/ShresthaCHP23"},',
#  b'"url":"URL#1289159"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"2228408",',
#  b'"info":{"authors":{"author":[{"@pid":"224/2423","text":"Lovisa Sundin"},{"@pid":"177/9165","text":"Nourhan Sakr"},{"@pid":"171/3799-1","text":"Juho Leinonen 0001"},{"@pid":"78/510","text":"Sherif G. Aly 0001"},{"@pid":"c/QICutts","text":"Quintin I. Cutts"}]},"title":"Visual recipes for slicing and dicing data: teaching data wrangling using subgoal graphics.","venue":"Koli Calling","pages":"29:1-29:10","year":"2021","type":"Conference and Workshop Papers","access":"closed","key":"conf/kolicalling/SundinSL0C21","doi":"10.1145/3488042.3488063","ee":"https://doi.org/10.1145/3488042.3488063","url":"https://dblp.org/rec/conf/kolicalling/SundinSL0C21"},',
#  b'"url":"URL#2228408"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"2366389",',
#  b'"info":{"authors":{"author":{"@pid":"202/0373","text":"Alex Bogatu"}},"title":"Cost-effective data wrangling in data lakes.","year":"2020","type":"Books and Theses","access":"closed","key":"phd/ethos/Bogatu20","ee":"https://ethos.bl.uk/OrderDetails.do?uin=uk.bl.ethos.804115","url":"https://dblp.org/rec/phd/ethos/Bogatu20"},',
#  b'"url":"URL#2366389"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"2414650",',
#  b'"info":{"authors":{"author":[{"@pid":"198/6319","text":"Shiyan Jiang"},{"@pid":"230/7231","text":"Jennifer Kahn"}]},"title":"Data wrangling practices and collaborative interactions with aggregated data.","venue":"Int. J. Comput. Support. Collab. Learn.","volume":"15","number":"3","pages":"257-281","year":"2020","type":"Journal Articles","access":"closed","key":"journals/cscl/JiangK20","doi":"10.1007/S11412-020-09327-1","ee":"https://doi.org/10.1007/s11412-020-09327-1","url":"https://dblp.org/rec/journals/cscl/JiangK20"},',
#  b'"url":"URL#2414650"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"2698021",',
#  b'"info":{"authors":{"author":[{"@pid":"274/7458","text":"A. K. Kritzinger"},{"@pid":"19/2671","text":"Andr\xc3\xa9 P. Calitz"},{"@pid":"274/7462","text":"L. Westraadt"}]},"title":"Data Wrangling for South African Smart City Crime Data.","venue":"SAICSIT","pages":"198-209","year":"2020","type":"Conference and Workshop Papers","access":"closed","key":"conf/saicsit/KritzingerCW20","doi":"10.1145/3410886.3410913","ee":"https://doi.org/10.1145/3410886.3410913","url":"https://dblp.org/rec/conf/saicsit/KritzingerCW20"},',
#  b'"url":"URL#2698021"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"2842574",',
#  b'"info":{"authors":{"author":[{"@pid":"202/0373","text":"Alex Bogatu"},{"@pid":"p/NWPaton","text":"Norman W. Paton"},{"@pid":"f/AAAFernandes","text":"Alvaro A. A. Fernandes"},{"@pid":"84/7973","text":"Martin Koehler"}]},"title":"Towards Automatic Data Format Transformations: Data Wrangling at Scale.","venue":"Comput. J.","volume":"62","number":"7","pages":"1044-1060","year":"2019","type":"Journal Articles","access":"closed","key":"journals/cj/BogatuPFK19","doi":"10.1093/COMJNL/BXY118","ee":"https://doi.org/10.1093/comjnl/bxy118","url":"https://dblp.org/rec/journals/cj/BogatuPFK19"},',
#  b'"url":"URL#2842574"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"3010265",',
#  b'"info":{"authors":{"author":[{"@pid":"198/6319","text":"Shiyan Jiang"},{"@pid":"230/7231","text":"Jennifer Kahn"}]},"title":"Data Wrangling Practices and Process in Modeling Family Migration Narratives with Big Data Visualization Technologies.","venue":"CSCL","year":"2019","type":"Conference and Workshop Papers","access":"open","key":"conf/cscl/JiangK19","ee":"https://repository.isls.org/handle/1/4405","url":"https://dblp.org/rec/conf/cscl/JiangK19"},',
#  b'"url":"URL#3010265"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"3064859",',
#  b'"info":{"authors":{"author":[{"@pid":"247/6763","text":"\xc3\x81lvaro Valencia-Parra"},{"@pid":"32/5551","text":"\xc3\x81ngel Jes\xc3\xbas Varela-Vaca"},{"@pid":"44/1706","text":"Mar\xc3\xada Teresa G\xc3\xb3mez-L\xc3\xb3pez"},{"@pid":"93/4640","text":"Paolo Ceravolo"}]},"title":"CHAMALEON: Framework to improve Data Wrangling with Complex Data.","venue":"ICIS","year":"2019","type":"Conference and Workshop Papers","access":"closed","key":"conf/icis/Valencia-ParraV19","ee":"https://aisel.aisnet.org/icis2019/data_science/data_science/16","url":"https://dblp.org/rec/conf/icis/Valencia-ParraV19"},',
#  b'"url":"URL#3064859"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"3150753",',
#  b'"info":{"authors":{"author":[{"@pid":"62/7969","text":"Anamaria Crisan"},{"@pid":"m/TMunzner","text":"Tamara Munzner"}]},"title":"Uncovering Data Landscapes through Data Reconnaissance and Task Wrangling.","venue":"IEEE VIS","pages":"46-50","year":"2019","type":"Conference and Workshop Papers","access":"closed","key":"conf/visualization/CrisanM19","doi":"10.1109/VISUAL.2019.8933542","ee":"https://doi.org/10.1109/VISUAL.2019.8933542","url":"https://dblp.org/rec/conf/visualization/CrisanM19"},',
#  b'"url":"URL#3150753"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"3164779",',
#  b'"info":{"authors":{"author":[{"@pid":"27/4508","text":"Jeffrey Heer"},{"@pid":"h/JosephMHellerstein","text":"Joseph M. Hellerstein"},{"@pid":"57/3823","text":"Sean Kandel"}]},"title":"Data Wrangling.","venue":"Encyclopedia of Big Data Technologies","year":"2019","type":"Reference Works","access":"closed","key":"reference/bdt/HeerHK19","doi":"10.1007/978-3-319-63962-8_9-1","ee":"https://doi.org/10.1007/978-3-319-63962-8_9-1","url":"https://dblp.org/rec/reference/bdt/HeerHK19"},',
#  b'"url":"URL#3164779"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"3499210",',
#  b'"info":{"authors":{"author":[{"@pid":"59/5879","text":"Charles Sutton"},{"@pid":"223/3108","text":"Timothy Hobson"},{"@pid":"223/0817","text":"James Geddes"},{"@pid":"c/RichCaruana","text":"Rich Caruana"}]},"title":"Data Diff: Interpretable, Executable Summaries of Changes in Distributions for Data Wrangling.","venue":"KDD","pages":"2279-2288","year":"2018","type":"Conference and Workshop Papers","access":"closed","key":"conf/kdd/SuttonHGC18","doi":"10.1145/3219819.3220057","ee":"https://doi.org/10.1145/3219819.3220057","url":"https://dblp.org/rec/conf/kdd/SuttonHGC18"},',
#  b'"url":"URL#3499210"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"3595355",',
#  b'"info":{"authors":{"author":[{"@pid":"84/7973","text":"Martin Koehler"},{"@pid":"202/0373","text":"Alex Bogatu"},{"@pid":"117/8447","text":"Cristina Civili"},{"@pid":"53/6696-1","text":"Nikolaos Konstantinou 0001"},{"@pid":"157/1785","text":"Edward Abel"},{"@pid":"f/AAAFernandes","text":"Alvaro A. A. Fernandes"},{"@pid":"53/358","text":"John A. Keane"},{"@pid":"l/LeonidLibkin","text":"Leonid Libkin"},{"@pid":"p/NWPaton","text":"Norman W. Paton"}]},"title":"Data Context Informed Data Wrangling.","venue":"CoRR","volume":"abs/1811.09248","year":"2018","type":"Informal and Other Publications","access":"open","key":"journals/corr/abs-1811-09248","ee":"http://arxiv.org/abs/1811.09248","url":"https://dblp.org/rec/journals/corr/abs-1811-09248"},',
#  b'"url":"URL#3595355"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"3754493",',
#  b'"info":{"authors":{"author":[{"@pid":"84/7973","text":"Martin Koehler"},{"@pid":"202/0373","text":"Alex Bogatu"},{"@pid":"117/8447","text":"Cristina Civili"},{"@pid":"53/6696-1","text":"Nikolaos Konstantinou 0001"},{"@pid":"157/1785","text":"Edward Abel"},{"@pid":"f/AAAFernandes","text":"Alvaro A. A. Fernandes"},{"@pid":"53/358","text":"John A. Keane"},{"@pid":"l/LeonidLibkin","text":"Leonid Libkin"},{"@pid":"p/NWPaton","text":"Norman W. Paton"}]},"title":"Data context informed data wrangling.","venue":"IEEE BigData","pages":"956-963","year":"2017","type":"Conference and Workshop Papers","access":"closed","key":"conf/bigdataconf/KoehlerBC0AFKLP17","doi":"10.1109/BIGDATA.2017.8258015","ee":"https://doi.org/10.1109/BigData.2017.8258015","url":"https://dblp.org/rec/conf/bigdataconf/KoehlerBC0AFKLP17"},',
#  b'"url":"URL#3754493"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"3756804",',
#  b'"info":{"authors":{"author":[{"@pid":"202/0373","text":"Alex Bogatu"},{"@pid":"p/NWPaton","text":"Norman W. Paton"},{"@pid":"f/AAAFernandes","text":"Alvaro A. A. Fernandes"}]},"title":"Towards Automatic Data Format Transformations: Data Wrangling at Scale.","venue":"BICOD","pages":"36-48","year":"2017","type":"Conference and Workshop Papers","access":"closed","key":"conf/bncod/BogatuPF17","doi":"10.1007/978-3-319-60795-5_4","ee":"https://doi.org/10.1007/978-3-319-60795-5_4","url":"https://dblp.org/rec/conf/bncod/BogatuPF17"},',
#  b'"url":"URL#3756804"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"3911326",',
#  b'"info":{"title":"Data Wrangling.","venue":"Encyclopedia of Machine Learning and Data Mining","pages":"327","year":"2017","type":"Reference Works","access":"closed","key":"reference/ml/X17ew","doi":"10.1007/978-1-4899-7687-1_100102","ee":"https://doi.org/10.1007/978-1-4899-7687-1_100102","url":"https://dblp.org/rec/reference/ml/X17ew"},',
#  b'"url":"URL#3911326"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"4110654",',
#  b'"info":{"authors":{"author":[{"@pid":"f/TimFurche","text":"Tim Furche"},{"@pid":"g/GeorgGottlob","text":"Georg Gottlob"},{"@pid":"l/LeonidLibkin","text":"Leonid Libkin"},{"@pid":"60/909","text":"Giorgio Orsi 0001"},{"@pid":"p/NWPaton","text":"Norman W. Paton"}]},"title":"Data Wrangling for Big Data: Challenges and Opportunities.","venue":"EDBT","pages":"473-478","year":"2016","type":"Conference and Workshop Papers","access":"open","key":"conf/edbt/FurcheGLOP16","doi":"10.5441/002/EDBT.2016.44","ee":"https://doi.org/10.5441/002/edbt.2016.44","url":"https://dblp.org/rec/conf/edbt/FurcheGLOP16"},',
#  b'"url":"URL#4110654"',
#  b'},',
#  b'{',
#  b'"@score":"3",',
#  b'"@id":"5458277",',
#  b'"info":{"authors":{"author":[{"@pid":"57/3823","text":"Sean Kandel"},{"@pid":"27/4508","text":"Jeffrey Heer"},{"@pid":"p/CatherinePlaisant","text":"Catherine Plaisant"},{"@pid":"97/8920","text":"Jessie Kennedy"},{"@pid":"v/FrankvanHam","text":"Frank van Ham"},{"@pid":"h/NathalieHenry","text":"Nathalie Henry Riche"},{"@pid":"267/7657","text":"Chris E. Weaver"},{"@pid":"52/5103","text":"Bongshin Lee"},{"@pid":"92/4226","text":"Dominique Brodbeck"},{"@pid":"45/565","text":"Paolo Buono"}]},"title":"Research directions in data wrangling: Visualizations and transformations for usable and credible data.","venue":"Inf. Vis.","volume":"10","number":"4","pages":"271-288","year":"2011","type":"Journal Articles","access":"closed","key":"journals/ivs/KandelHPKHRWLBB11","doi":"10.1177/1473871611415994","ee":"https://doi.org/10.1177/1473871611415994","url":"https://dblp.org/rec/journals/ivs/KandelHPKHRWLBB11"},',
#  b'"url":"URL#5458277"',
#  b'},',
#  b'{',
#  b'"@score":"2",',
#  b'"@id":"140336",',
#  b'"info":{"authors":{"author":[{"@pid":"249/9854","text":"Zhongsu Luo"},{"@pid":"38/6410","text":"Kai Xiong"},{"@pid":"33/2240","text":"Jiajun Zhu"},{"@pid":"95/6235","text":"Ran Chen"},{"@pid":"210/5431","text":"Xinhuan Shu"},{"@pid":"190/2257","text":"Di Weng"},{"@pid":"49/6702","text":"Yingcai Wu"}]},"title":"Ferry: Toward Better Understanding of Input/Output Space for Data Wrangling Scripts.","venue":"IEEE Trans. Vis. Comput. Graph.","volume":"31","number":"1","pages":"1202-1212","year":"2025","type":"Journal Articles","access":"closed","key":"journals/tvcg/LuoXZCSWW25","doi":"10.1109/TVCG.2024.3456328","ee":"https://doi.org/10.1109/TVCG.2024.3456328","url":"https://dblp.org/rec/journals/tvcg/LuoXZCSWW25"},',
#  b'"url":"URL#140336"',
#  b'},',
#  b'{',
#  b'"@score":"2",',
#  b'"@id":"145600",',
#  b'"info":{"authors":{"author":[{"@pid":"246/7819","text":"Ashlesha Akella"},{"@pid":"123/5487","text":"Krishnasuri Narayanam"}]},"title":"Data Wrangling Task Automation Using Code-Generating Language Models.","venue":"AAAI","pages":"29616-29618","year":"2025","type":"Conference and Workshop Papers","access":"open","key":"conf/aaai/AkellaN25","doi":"10.1609/AAAI.V39I28.35344","ee":"https://doi.org/10.1609/aaai.v39i28.35344","url":"https://dblp.org/rec/conf/aaai/AkellaN25"},',
#  b'"url":"URL#145600"',
#  b'}',
#  b']',
#  b'}',
#  b'}',
#  b'}']

# %% [markdown]
# In the above code, we have:
# 1. Imports Request class and the <font color="blue">urlopen() </font> function from `urllibs` module.
# 2. Defines a path with the coordinates of the start and end points
# 3. Creates a URL Request object. Note that you can change the output format by replacing '/json' with '/xml'.
# 4. Opens the URL, and returns a file-like object.
# 5. Reads data returned from the HTTP request.
#
# The returned data is actually stored in a string.
# You can check it out using Python's built-in function `type`,
# ```python
#     type(elevations)
# ```
# What does the data look like?
# In stead of printing the data in one single string, one can use
# ```python
#     elevations.splitlines()
# ```
# to print the data as a list of lines in the string, breaking
# at line boundaries, i.e., '\n'.
#
# It is easy to dump the data into a JSON file, which just takes three lines of code:
# ```python
#     import json
#     with open("elevations.json", "w") as outfile:
#          json.dump(elevations, outfile)
# ```
#
# To read the acquired JSON data, you can use the `json` module as follows:

# %%
import json
data = json.loads(elevations)
print(type(data))
data
# Out:
# <class 'dict'>
# {'result': {'query': 'data* wrangling*',
#   'status': {'@code': '200', 'text': 'OK'},
#   'time': {'@unit': 'msecs', 'text': '17.07'},
#   'completions': {'@total': '1',
#    '@computed': '1',
#    '@sent': '1',
#    'c': {'@sc': '101',
#     '@dc': '100',
#     '@oc': '101',
#     '@id': '62492294',
#     'text': 'wrangling'}},
#   'hits': {'@total': '100',
#    '@computed': '100',
#    '@sent': '30',
#    '@first': '0',
#    'hit': [{'@score': '5',
#      '@id': '2369905',
#      'info': {'authors': {'author': {'@pid': '22/3551',
#         'text': 'Antonio Badia'}},
#       'title': 'SQL for Data Science - Data Cleaning, Wrangling and Analytics with Relational Databases',
#       'venue': 'Data-Centric Systems and Applications',
#       'pages': '1-259',
#       'publisher': 'Springer',
#       'year': '2020',
#       'type': 'Books and Theses',
#       'access': 'closed',
#       'key': 'series/dcsa/Badia20',
#       'doi': '10.1007/978-3-030-57592-2',
#       'ee': 'https://doi.org/10.1007/978-3-030-57592-2',
#       'url': 'https://dblp.org/rec/series/dcsa/Badia20'},
#      'url': 'URL#2369905'},
#     {'@score': '5',
#      '@id': '2417006',
#      'info': {'authors': {'author': {'@pid': '221/5219',
#         'text': 'Otmane Azeroual'}},
#       'title': 'Data Wrangling in Database Systems: Purging of Dirty Data.',
#       'venue': 'Data',
#       'volume': '5',
#       'number': '2',
#       'pages': '50',
#       'year': '2020',
#       'type': 'Journal Articles',
#       'access': 'open',
#       'key': 'journals/data/Azeroual20',
#       'doi': '10.3390/DATA5020050',
#       'ee': 'https://doi.org/10.3390/data5020050',
#       'url': 'https://dblp.org/rec/journals/data/Azeroual20'},
#      'url': 'URL#2417006'},
#     {'@score': '5',
#      '@id': '4078610',
#      'info': {'authors': {'author': [{'@pid': 'f/TimFurche',
#          'text': 'Tim Furche'},
#         {'@pid': 'g/GeorgGottlob', 'text': 'Georg Gottlob'},
#         {'@pid': '76/970', 'text': 'Bernd Neumayr'},
#         {'@pid': '20/9117', 'text': 'Emanuel Sallinger'}]},
#       'title': 'Data Wrangling for Big Data: Towards a Lingua Franca for Data Wrangling.',
#       'venue': 'AMW',
#       'year': '2016',
#       'type': 'Conference and Workshop Papers',
#       'access': 'open',
#       'key': 'conf/amw/FurcheGNS16',
#       'ee': 'https://ceur-ws.org/Vol-1644/paper20.pdf',
#       'url': 'https://dblp.org/rec/conf/amw/FurcheGNS16'},
#      'url': 'URL#4078610'},
#     {'@score': '4',
#      '@id': '37762',
#      'info': {'authors': {'author': [{'@pid': '412/0399',
#          'text': 'Wellington Kanyongo'},
#         {'@pid': '44/10879', 'text': 'Absalom El-Shamir Ezugwu'},
#         {'@pid': '412/0315', 'text': 'Tsitsi Moyo'},
#         {'@pid': '74/3508', 'text': 'Jean Vincent Fonou Dombeu'}]},
#       'title': 'Data Wrangling and Generation for Machine Learning Models in Medication Adherence Analytics: A practical Standpoint using Patient-Level and Medical Claims Data.',
#       'venue': 'Data Intell.',
#       'volume': '7',
#       'number': '2',
#       'pages': '485-526',
#       'year': '2025',
#       'type': 'Journal Articles',
#       'access': 'open',
#       'key': 'journals/dint/KanyongoEMD25',
#       'doi': '10.3724/2096-7004.DI.2024.0037',
#       'ee': 'https://doi.org/10.3724/2096-7004.di.2024.0037',
#       'url': 'https://dblp.org/rec/journals/dint/KanyongoEMD25'},
#      'url': 'URL#37762'},
#     {'@score': '4',
#      '@id': '1680223',
#      'info': {'authors': {'author': [{'@pid': '221/5219',
#          'text': 'Otmane Azeroual'},
#         {'@pid': '130/7996', 'text': 'Joachim Schöpfel'},
#         {'@pid': '28/8326', 'text': 'Dragan Ivanovic'},
#         {'@pid': '226/1381', 'text': 'Anastasija Nikiforova'}]},
#       'title': 'Combining Data Lake and Data Wrangling for Ensuring Data Quality in CRIS.',
#       'venue': 'CRIS',
#       'pages': '3-16',
#       'year': '2022',
#       'type': 'Conference and Workshop Papers',
#       'access': 'open',
#       'key': 'conf/eurocris/AzeroualSIN22',
#       'doi': '10.1016/J.PROCS.2022.10.171',
#       'ee': 'https://doi.org/10.1016/j.procs.2022.10.171',
#       'url': 'https://dblp.org/rec/conf/eurocris/AzeroualSIN22'},
#      'url': 'URL#1680223'},
#     {'@score': '4',
#      '@id': '2068332',
#      'info': {'authors': {'author': [{'@pid': '84/7973',
#          'text': 'Martin Koehler'},
#         {'@pid': '157/1785', 'text': 'Edward Abel'},
#         {'@pid': '202/0373', 'text': 'Alex Bogatu'},
#         {'@pid': '117/8447', 'text': 'Cristina Civili'},
#         {'@pid': '246/1127', 'text': 'Lacramioara Mazilu'},
#         {'@pid': '53/6696-1', 'text': 'Nikolaos Konstantinou 0001'},
#         {'@pid': 'f/AAAFernandes', 'text': 'Alvaro A. A. Fernandes'},
#         {'@pid': '53/358', 'text': 'John A. Keane'},
#         {'@pid': 'l/LeonidLibkin', 'text': 'Leonid Libkin'},
#         {'@pid': 'p/NWPaton', 'text': 'Norman W. Paton'}]},
#       'title': 'Incorporating Data Context to Cost-Effectively Automate End-to-End Data Wrangling.',
#       'venue': 'IEEE Trans. Big Data',
#       'volume': '7',
#       'number': '1',
#       'pages': '169-186',
#       'year': '2021',
#       'type': 'Journal Articles',
#       'access': 'open',
#       'key': 'journals/tbd/KoehlerABCMKFKL21',
#       'doi': '10.1109/TBDATA.2019.2907588',
#       'ee': 'https://doi.org/10.1109/TBDATA.2019.2907588',
#       'url': 'https://dblp.org/rec/journals/tbd/KoehlerABCMKFKL21'},
#      'url': 'URL#2068332'},
#     {'@score': '4',
#      '@id': '3798821',
#      'info': {'authors': {'author': {'@pid': '07/6223',
#         'text': 'Scott Jensen'}},
#       'title': 'Introducing Data Science to Undergraduates through Big Data: Answering Questions by Wrangling and Profiling a Yelp Dataset.',
#       'venue': 'HICSS',
#       'pages': '1-10',
#       'year': '2017',
#       'type': 'Conference and Workshop Papers',
#       'access': 'open',
#       'key': 'conf/hicss/Jensen17',
#       'ee': 'https://hdl.handle.net/10125/41275',
#       'url': 'https://dblp.org/rec/conf/hicss/Jensen17'},
#      'url': 'URL#3798821'},
#     {'@score': '3',
#      '@id': '837793',
#      'info': {'authors': {'author': [{'@pid': '60/5086',
#          'text': 'Yuqing Wang'},
#         {'@pid': '29/11192', 'text': 'Anna Fariha'}]},
#       'title': 'Development of Data Evaluation Benchmark for Data Wrangling Recommendation System.',
#       'venue': 'CoRR',
#       'volume': 'abs/2409.10635',
#       'year': '2024',
#       'type': 'Informal and Other Publications',
#       'access': 'open',
#       'key': 'journals/corr/abs-2409-10635',
#       'doi': '10.48550/ARXIV.2409.10635',
#       'ee': 'https://doi.org/10.48550/arXiv.2409.10635',
#       'url': 'https://dblp.org/rec/journals/corr/abs-2409-10635'},
#      'url': 'URL#837793'},
#     {'@score': '3',
#      '@id': '1024144',
#      'info': {'authors': {'author': [{'@pid': '261/1970',
#          'text': 'Nico Schäfer'},
#         {'@pid': '266/6160', 'text': 'Damjan Gjurovski'},
#         {'@pid': '261/1893', 'text': 'Angjela Davitkova'},
#         {'@pid': 'm/SebastianMichel', 'text': 'Sebastian Michel 0001'}]},
#       'title': 'To UDFs and Beyond: Demonstration of a Fully Decomposed Data Processor for General Data Wrangling Tasks.',
#       'venue': 'Proc. VLDB Endow.',
#       'volume': '16',
#       'number': '12',
#       'pages': '4018-4021',
#       'year': '2023',
#       'type': 'Journal Articles',
#       'access': 'open',
#       'key': 'journals/pvldb/SchaferGD023',
#       'doi': '10.14778/3611540.3611610',
#       'ee': 'https://www.vldb.org/pvldb/vol16/p4018-gjurovski.pdf',
#       'url': 'https://dblp.org/rec/journals/pvldb/SchaferGD023'},
#      'url': 'URL#1024144'},
#     {'@score': '3',
#      '@id': '1081793',
#      'info': {'authors': {'author': [{'@pid': '50/8166',
#          'text': 'Tomas Petricek 0001'},
#         {'@pid': '203/7226', 'text': 'Gerrit J. J. van den Burg'},
#         {'@pid': '13/8853', 'text': 'Alfredo Nazábal'},
#         {'@pid': '254/2065', 'text': 'Taha Ceritli'},
#         {'@pid': '22/5749', 'text': 'Ernesto Jiménez-Ruiz'},
#         {'@pid': 'w/ChristopherKIWilliams',
#          'text': 'Christopher K. I. Williams'}]},
#       'title': 'AI Assistants: A Framework for Semi-Automated Data Wrangling.',
#       'venue': 'IEEE Trans. Knowl. Data Eng.',
#       'volume': '35',
#       'number': '9',
#       'pages': '9295-9306',
#       'year': '2023',
#       'type': 'Journal Articles',
#       'access': 'closed',
#       'key': 'journals/tkde/PetricekBNCJW23',
#       'doi': '10.1109/TKDE.2022.3222538',
#       'ee': 'https://doi.org/10.1109/TKDE.2022.3222538',
#       'url': 'https://dblp.org/rec/journals/tkde/PetricekBNCJW23'},
#      'url': 'URL#1081793'},
#     {'@score': '3',
#      '@id': '1245499',
#      'info': {'authors': {'author': [{'@pid': '185/5926',
#          'text': 'Florentina Armaselu'},
#         {'@pid': '10/8162', 'text': 'Barbara McGillivray'},
#         {'@pid': '128/7478', 'text': 'Chaya Liebeskind'},
#         {'@pid': '300/5702', 'text': 'Giedre Valunaite Oleskeviciene'},
#         {'@pid': '20/11089', 'text': 'Andrius Utka'},
#         {'@pid': '133/9329', 'text': 'Daniela Gifu'},
#         {'@pid': '222/0968', 'text': 'Anas Fahad Khan'},
#         {'@pid': '65/11004', 'text': 'Elena Simona Apostol'},
#         {'@pid': '174/6740', 'text': 'Ciprian-Octavian Truica'}]},
#       'title': 'Workflow Reversal and Data Wrangling in Multilingual Diachronic Analysis and Linguistic Linked Open Data Modelling.',
#       'venue': 'LDK',
#       'pages': '410-416',
#       'year': '2023',
#       'type': 'Conference and Workshop Papers',
#       'access': 'closed',
#       'key': 'conf/ldk/ArmaseluMLOUGKAT23',
#       'ee': 'https://aclanthology.org/2023.ldk-1.43',
#       'url': 'https://dblp.org/rec/conf/ldk/ArmaseluMLOUGKAT23'},
#      'url': 'URL#1245499'},
#     {'@score': '3',
#      '@id': '1289159',
#      'info': {'authors': {'author': [{'@pid': '225/7825',
#          'text': 'Nischal Shrestha'},
#         {'@pid': '292/9532', 'text': 'Bhavya Chopra'},
#         {'@pid': '144/5345', 'text': 'Austin Z. Henley'},
#         {'@pid': '46/2873', 'text': 'Chris Parnin'}]},
#       'title': 'Detangler: Helping Data Scientists Explore, Understand, and Debug Data Wrangling Pipelines.',
#       'venue': 'VL/HCC',
#       'pages': '189-198',
#       'year': '2023',
#       'type': 'Conference and Workshop Papers',
#       'access': 'closed',
#       'key': 'conf/vl/ShresthaCHP23',
#       'doi': '10.1109/VL-HCC57772.2023.00031',
#       'ee': 'https://doi.org/10.1109/VL-HCC57772.2023.00031',
#       'url': 'https://dblp.org/rec/conf/vl/ShresthaCHP23'},
#      'url': 'URL#1289159'},
#     {'@score': '3',
#      '@id': '2228408',
#      'info': {'authors': {'author': [{'@pid': '224/2423',
#          'text': 'Lovisa Sundin'},
#         {'@pid': '177/9165', 'text': 'Nourhan Sakr'},
#         {'@pid': '171/3799-1', 'text': 'Juho Leinonen 0001'},
#         {'@pid': '78/510', 'text': 'Sherif G. Aly 0001'},
#         {'@pid': 'c/QICutts', 'text': 'Quintin I. Cutts'}]},
#       'title': 'Visual recipes for slicing and dicing data: teaching data wrangling using subgoal graphics.',
#       'venue': 'Koli Calling',
#       'pages': '29:1-29:10',
#       'year': '2021',
#       'type': 'Conference and Workshop Papers',
#       'access': 'closed',
#       'key': 'conf/kolicalling/SundinSL0C21',
#       'doi': '10.1145/3488042.3488063',
#       'ee': 'https://doi.org/10.1145/3488042.3488063',
#       'url': 'https://dblp.org/rec/conf/kolicalling/SundinSL0C21'},
#      'url': 'URL#2228408'},
#     {'@score': '3',
#      '@id': '2366389',
#      'info': {'authors': {'author': {'@pid': '202/0373',
#         'text': 'Alex Bogatu'}},
#       'title': 'Cost-effective data wrangling in data lakes.',
#       'year': '2020',
#       'type': 'Books and Theses',
#       'access': 'closed',
#       'key': 'phd/ethos/Bogatu20',
#       'ee': 'https://ethos.bl.uk/OrderDetails.do?uin=uk.bl.ethos.804115',
#       'url': 'https://dblp.org/rec/phd/ethos/Bogatu20'},
#      'url': 'URL#2366389'},
#     {'@score': '3',
#      '@id': '2414650',
#      'info': {'authors': {'author': [{'@pid': '198/6319',
#          'text': 'Shiyan Jiang'},
#         {'@pid': '230/7231', 'text': 'Jennifer Kahn'}]},
#       'title': 'Data wrangling practices and collaborative interactions with aggregated data.',
#       'venue': 'Int. J. Comput. Support. Collab. Learn.',
#       'volume': '15',
#       'number': '3',
#       'pages': '257-281',
#       'year': '2020',
#       'type': 'Journal Articles',
#       'access': 'closed',
#       'key': 'journals/cscl/JiangK20',
#       'doi': '10.1007/S11412-020-09327-1',
#       'ee': 'https://doi.org/10.1007/s11412-020-09327-1',
#       'url': 'https://dblp.org/rec/journals/cscl/JiangK20'},
#      'url': 'URL#2414650'},
#     {'@score': '3',
#      '@id': '2698021',
#      'info': {'authors': {'author': [{'@pid': '274/7458',
#          'text': 'A. K. Kritzinger'},
#         {'@pid': '19/2671', 'text': 'André P. Calitz'},
#         {'@pid': '274/7462', 'text': 'L. Westraadt'}]},
#       'title': 'Data Wrangling for South African Smart City Crime Data.',
#       'venue': 'SAICSIT',
#       'pages': '198-209',
#       'year': '2020',
#       'type': 'Conference and Workshop Papers',
#       'access': 'closed',
#       'key': 'conf/saicsit/KritzingerCW20',
#       'doi': '10.1145/3410886.3410913',
#       'ee': 'https://doi.org/10.1145/3410886.3410913',
#       'url': 'https://dblp.org/rec/conf/saicsit/KritzingerCW20'},
#      'url': 'URL#2698021'},
#     {'@score': '3',
#      '@id': '2842574',
#      'info': {'authors': {'author': [{'@pid': '202/0373',
#          'text': 'Alex Bogatu'},
#         {'@pid': 'p/NWPaton', 'text': 'Norman W. Paton'},
#         {'@pid': 'f/AAAFernandes', 'text': 'Alvaro A. A. Fernandes'},
#         {'@pid': '84/7973', 'text': 'Martin Koehler'}]},
#       'title': 'Towards Automatic Data Format Transformations: Data Wrangling at Scale.',
#       'venue': 'Comput. J.',
#       'volume': '62',
#       'number': '7',
#       'pages': '1044-1060',
#       'year': '2019',
#       'type': 'Journal Articles',
#       'access': 'closed',
#       'key': 'journals/cj/BogatuPFK19',
#       'doi': '10.1093/COMJNL/BXY118',
#       'ee': 'https://doi.org/10.1093/comjnl/bxy118',
#       'url': 'https://dblp.org/rec/journals/cj/BogatuPFK19'},
#      'url': 'URL#2842574'},
#     {'@score': '3',
#      '@id': '3010265',
#      'info': {'authors': {'author': [{'@pid': '198/6319',
#          'text': 'Shiyan Jiang'},
#         {'@pid': '230/7231', 'text': 'Jennifer Kahn'}]},
#       'title': 'Data Wrangling Practices and Process in Modeling Family Migration Narratives with Big Data Visualization Technologies.',
#       'venue': 'CSCL',
#       'year': '2019',
#       'type': 'Conference and Workshop Papers',
#       'access': 'open',
#       'key': 'conf/cscl/JiangK19',
#       'ee': 'https://repository.isls.org/handle/1/4405',
#       'url': 'https://dblp.org/rec/conf/cscl/JiangK19'},
#      'url': 'URL#3010265'},
#     {'@score': '3',
#      '@id': '3064859',
#      'info': {'authors': {'author': [{'@pid': '247/6763',
#          'text': 'Álvaro Valencia-Parra'},
#         {'@pid': '32/5551', 'text': 'Ángel Jesús Varela-Vaca'},
#         {'@pid': '44/1706', 'text': 'María Teresa Gómez-López'},
#         {'@pid': '93/4640', 'text': 'Paolo Ceravolo'}]},
#       'title': 'CHAMALEON: Framework to improve Data Wrangling with Complex Data.',
#       'venue': 'ICIS',
#       'year': '2019',
#       'type': 'Conference and Workshop Papers',
#       'access': 'closed',
#       'key': 'conf/icis/Valencia-ParraV19',
#       'ee': 'https://aisel.aisnet.org/icis2019/data_science/data_science/16',
#       'url': 'https://dblp.org/rec/conf/icis/Valencia-ParraV19'},
#      'url': 'URL#3064859'},
#     {'@score': '3',
#      '@id': '3150753',
#      'info': {'authors': {'author': [{'@pid': '62/7969',
#          'text': 'Anamaria Crisan'},
#         {'@pid': 'm/TMunzner', 'text': 'Tamara Munzner'}]},
#       'title': 'Uncovering Data Landscapes through Data Reconnaissance and Task Wrangling.',
#       'venue': 'IEEE VIS',
#       'pages': '46-50',
#       'year': '2019',
#       'type': 'Conference and Workshop Papers',
#       'access': 'closed',
#       'key': 'conf/visualization/CrisanM19',
#       'doi': '10.1109/VISUAL.2019.8933542',
#       'ee': 'https://doi.org/10.1109/VISUAL.2019.8933542',
#       'url': 'https://dblp.org/rec/conf/visualization/CrisanM19'},
#      'url': 'URL#3150753'},
#     {'@score': '3',
#      '@id': '3164779',
#      'info': {'authors': {'author': [{'@pid': '27/4508',
#          'text': 'Jeffrey Heer'},
#         {'@pid': 'h/JosephMHellerstein', 'text': 'Joseph M. Hellerstein'},
#         {'@pid': '57/3823', 'text': 'Sean Kandel'}]},
#       'title': 'Data Wrangling.',
#       'venue': 'Encyclopedia of Big Data Technologies',
#       'year': '2019',
#       'type': 'Reference Works',
#       'access': 'closed',
#       'key': 'reference/bdt/HeerHK19',
#       'doi': '10.1007/978-3-319-63962-8_9-1',
#       'ee': 'https://doi.org/10.1007/978-3-319-63962-8_9-1',
#       'url': 'https://dblp.org/rec/reference/bdt/HeerHK19'},
#      'url': 'URL#3164779'},
#     {'@score': '3',
#      '@id': '3499210',
#      'info': {'authors': {'author': [{'@pid': '59/5879',
#          'text': 'Charles Sutton'},
#         {'@pid': '223/3108', 'text': 'Timothy Hobson'},
#         {'@pid': '223/0817', 'text': 'James Geddes'},
#         {'@pid': 'c/RichCaruana', 'text': 'Rich Caruana'}]},
#       'title': 'Data Diff: Interpretable, Executable Summaries of Changes in Distributions for Data Wrangling.',
#       'venue': 'KDD',
#       'pages': '2279-2288',
#       'year': '2018',
#       'type': 'Conference and Workshop Papers',
#       'access': 'closed',
#       'key': 'conf/kdd/SuttonHGC18',
#       'doi': '10.1145/3219819.3220057',
#       'ee': 'https://doi.org/10.1145/3219819.3220057',
#       'url': 'https://dblp.org/rec/conf/kdd/SuttonHGC18'},
#      'url': 'URL#3499210'},
#     {'@score': '3',
#      '@id': '3595355',
#      'info': {'authors': {'author': [{'@pid': '84/7973',
#          'text': 'Martin Koehler'},
#         {'@pid': '202/0373', 'text': 'Alex Bogatu'},
#         {'@pid': '117/8447', 'text': 'Cristina Civili'},
#         {'@pid': '53/6696-1', 'text': 'Nikolaos Konstantinou 0001'},
#         {'@pid': '157/1785', 'text': 'Edward Abel'},
#         {'@pid': 'f/AAAFernandes', 'text': 'Alvaro A. A. Fernandes'},
#         {'@pid': '53/358', 'text': 'John A. Keane'},
#         {'@pid': 'l/LeonidLibkin', 'text': 'Leonid Libkin'},
#         {'@pid': 'p/NWPaton', 'text': 'Norman W. Paton'}]},
#       'title': 'Data Context Informed Data Wrangling.',
#       'venue': 'CoRR',
#       'volume': 'abs/1811.09248',
#       'year': '2018',
#       'type': 'Informal and Other Publications',
#       'access': 'open',
#       'key': 'journals/corr/abs-1811-09248',
#       'ee': 'http://arxiv.org/abs/1811.09248',
#       'url': 'https://dblp.org/rec/journals/corr/abs-1811-09248'},
#      'url': 'URL#3595355'},
#     {'@score': '3',
#      '@id': '3754493',
#      'info': {'authors': {'author': [{'@pid': '84/7973',
#          'text': 'Martin Koehler'},
#         {'@pid': '202/0373', 'text': 'Alex Bogatu'},
#         {'@pid': '117/8447', 'text': 'Cristina Civili'},
#         {'@pid': '53/6696-1', 'text': 'Nikolaos Konstantinou 0001'},
#         {'@pid': '157/1785', 'text': 'Edward Abel'},
#         {'@pid': 'f/AAAFernandes', 'text': 'Alvaro A. A. Fernandes'},
#         {'@pid': '53/358', 'text': 'John A. Keane'},
#         {'@pid': 'l/LeonidLibkin', 'text': 'Leonid Libkin'},
#         {'@pid': 'p/NWPaton', 'text': 'Norman W. Paton'}]},
#       'title': 'Data context informed data wrangling.',
#       'venue': 'IEEE BigData',
#       'pages': '956-963',
#       'year': '2017',
#       'type': 'Conference and Workshop Papers',
#       'access': 'closed',
#       'key': 'conf/bigdataconf/KoehlerBC0AFKLP17',
#       'doi': '10.1109/BIGDATA.2017.8258015',
#       'ee': 'https://doi.org/10.1109/BigData.2017.8258015',
#       'url': 'https://dblp.org/rec/conf/bigdataconf/KoehlerBC0AFKLP17'},
#      'url': 'URL#3754493'},
#     {'@score': '3',
#      '@id': '3756804',
#      'info': {'authors': {'author': [{'@pid': '202/0373',
#          'text': 'Alex Bogatu'},
#         {'@pid': 'p/NWPaton', 'text': 'Norman W. Paton'},
#         {'@pid': 'f/AAAFernandes', 'text': 'Alvaro A. A. Fernandes'}]},
#       'title': 'Towards Automatic Data Format Transformations: Data Wrangling at Scale.',
#       'venue': 'BICOD',
#       'pages': '36-48',
#       'year': '2017',
#       'type': 'Conference and Workshop Papers',
#       'access': 'closed',
#       'key': 'conf/bncod/BogatuPF17',
#       'doi': '10.1007/978-3-319-60795-5_4',
#       'ee': 'https://doi.org/10.1007/978-3-319-60795-5_4',
#       'url': 'https://dblp.org/rec/conf/bncod/BogatuPF17'},
#      'url': 'URL#3756804'},
#     {'@score': '3',
#      '@id': '3911326',
#      'info': {'title': 'Data Wrangling.',
#       'venue': 'Encyclopedia of Machine Learning and Data Mining',
#       'pages': '327',
#       'year': '2017',
#       'type': 'Reference Works',
#       'access': 'closed',
#       'key': 'reference/ml/X17ew',
#       'doi': '10.1007/978-1-4899-7687-1_100102',
#       'ee': 'https://doi.org/10.1007/978-1-4899-7687-1_100102',
#       'url': 'https://dblp.org/rec/reference/ml/X17ew'},
#      'url': 'URL#3911326'},
#     {'@score': '3',
#      '@id': '4110654',
#      'info': {'authors': {'author': [{'@pid': 'f/TimFurche',
#          'text': 'Tim Furche'},
#         {'@pid': 'g/GeorgGottlob', 'text': 'Georg Gottlob'},
#         {'@pid': 'l/LeonidLibkin', 'text': 'Leonid Libkin'},
#         {'@pid': '60/909', 'text': 'Giorgio Orsi 0001'},
#         {'@pid': 'p/NWPaton', 'text': 'Norman W. Paton'}]},
#       'title': 'Data Wrangling for Big Data: Challenges and Opportunities.',
#       'venue': 'EDBT',
#       'pages': '473-478',
#       'year': '2016',
#       'type': 'Conference and Workshop Papers',
#       'access': 'open',
#       'key': 'conf/edbt/FurcheGLOP16',
#       'doi': '10.5441/002/EDBT.2016.44',
#       'ee': 'https://doi.org/10.5441/002/edbt.2016.44',
#       'url': 'https://dblp.org/rec/conf/edbt/FurcheGLOP16'},
#      'url': 'URL#4110654'},
#     {'@score': '3',
#      '@id': '5458277',
#      'info': {'authors': {'author': [{'@pid': '57/3823',
#          'text': 'Sean Kandel'},
#         {'@pid': '27/4508', 'text': 'Jeffrey Heer'},
#         {'@pid': 'p/CatherinePlaisant', 'text': 'Catherine Plaisant'},
#         {'@pid': '97/8920', 'text': 'Jessie Kennedy'},
#         {'@pid': 'v/FrankvanHam', 'text': 'Frank van Ham'},
#         {'@pid': 'h/NathalieHenry', 'text': 'Nathalie Henry Riche'},
#         {'@pid': '267/7657', 'text': 'Chris E. Weaver'},
#         {'@pid': '52/5103', 'text': 'Bongshin Lee'},
#         {'@pid': '92/4226', 'text': 'Dominique Brodbeck'},
#         {'@pid': '45/565', 'text': 'Paolo Buono'}]},
#       'title': 'Research directions in data wrangling: Visualizations and transformations for usable and credible data.',
#       'venue': 'Inf. Vis.',
#       'volume': '10',
#       'number': '4',
#       'pages': '271-288',
#       'year': '2011',
#       'type': 'Journal Articles',
#       'access': 'closed',
#       'key': 'journals/ivs/KandelHPKHRWLBB11',
#       'doi': '10.1177/1473871611415994',
#       'ee': 'https://doi.org/10.1177/1473871611415994',
#       'url': 'https://dblp.org/rec/journals/ivs/KandelHPKHRWLBB11'},
#      'url': 'URL#5458277'},
#     {'@score': '2',
#      '@id': '140336',
#      'info': {'authors': {'author': [{'@pid': '249/9854',
#          'text': 'Zhongsu Luo'},
#         {'@pid': '38/6410', 'text': 'Kai Xiong'},
#         {'@pid': '33/2240', 'text': 'Jiajun Zhu'},
#         {'@pid': '95/6235', 'text': 'Ran Chen'},
#         {'@pid': '210/5431', 'text': 'Xinhuan Shu'},
#         {'@pid': '190/2257', 'text': 'Di Weng'},
#         {'@pid': '49/6702', 'text': 'Yingcai Wu'}]},
#       'title': 'Ferry: Toward Better Understanding of Input/Output Space for Data Wrangling Scripts.',
#       'venue': 'IEEE Trans. Vis. Comput. Graph.',
#       'volume': '31',
#       'number': '1',
#       'pages': '1202-1212',
#       'year': '2025',
#       'type': 'Journal Articles',
#       'access': 'closed',
#       'key': 'journals/tvcg/LuoXZCSWW25',
#       'doi': '10.1109/TVCG.2024.3456328',
#       'ee': 'https://doi.org/10.1109/TVCG.2024.3456328',
#       'url': 'https://dblp.org/rec/journals/tvcg/LuoXZCSWW25'},
#      'url': 'URL#140336'},
#     {'@score': '2',
#      '@id': '145600',
#      'info': {'authors': {'author': [{'@pid': '246/7819',
#          'text': 'Ashlesha Akella'},
#         {'@pid': '123/5487', 'text': 'Krishnasuri Narayanam'}]},
#       'title': 'Data Wrangling Task Automation Using Code-Generating Language Models.',
#       'venue': 'AAAI',
#       'pages': '29616-29618',
#       'year': '2025',
#       'type': 'Conference and Workshop Papers',
#       'access': 'open',
#       'key': 'conf/aaai/AkellaN25',
#       'doi': '10.1609/AAAI.V39I28.35344',
#       'ee': 'https://doi.org/10.1609/aaai.v39i28.35344',
#       'url': 'https://dblp.org/rec/conf/aaai/AkellaN25'},
#      'url': 'URL#145600'}]}}}

# %% [markdown]
# It loads the data into a Python dictionary.
# The data we want is stored in the first entry.
# The value of this entry is a list of two dictionaries, each of which corresponds to a record.
# see [JSON encoder and decoder](https://docs.python.org/2/library/json.html) for more on reading
# JSON files.
#
# As mentioned earlier in this section,
# we will convert the JSON data into Pandas DataFrame.
# Therefore, Pandas functions on reading JSON are to be used.
# If you would like to know about those functions, you can read Pandas tutorial on [Reading JSON](http://pandas.pydata.org/pandas-docs/stable/io.html#io-json-reader) (**optional**).
# Let's first try the <font color="blue">read_json()</font> function.

# %%
# using pandas to read json, the json data should be in a string format
json_str = elevations.decode('utf-8')
df = pd.read_json(json_str)
df
# Out:
#                                                         result
# query                                         data* wrangling*
# status                          {'@code': '200', 'text': 'OK'}
# time                       {'@unit': 'msecs', 'text': '17.07'}
# completions  {'@total': '1', '@computed': '1', '@sent': '1'...
# hits         {'@total': '100', '@computed': '100', '@sent':...

# %% [markdown]
# Unfortunately, the DataFrame returned by `read_json` is not the one we want.
# You might wonder why the `read_json` function did not return the DataFrame we want.
# There is a straight forward answer.
# Let's try to build a DataFrame from `data` returned by
# ```
#     data = json.loads(elevations)
# ```
# What do you get?

# %%
pd.DataFrame(data)
# Out:
#                                                         result
# query                                         data* wrangling*
# status                          {'@code': '200', 'text': 'OK'}
# time                       {'@unit': 'msecs', 'text': '17.07'}
# completions  {'@total': '1', '@computed': '1', '@sent': '1'...
# hits         {'@total': '100', '@computed': '100', '@sent':...

# %% [markdown]
# You have got a DataFrame that is exactly the same as the one returned by `read_json`.
# This is due to Pandas' way of constructing a DataFrame from a dictionary.
# See [Intro to Data Structures](http://pandas.pydata.org/pandas-docs/stable/dsintro.html)
# for constructing a DataFrame from a dictionary
# and "Object Creation" in [10 Mintues to Pandas](http://pandas.pydata.org/pandas-docs/stable/10min.html) 📖.
# It is not hard to figure out that dictionary keys
# are used as column
# labels, and values of whatever data types are put as column values.
#
# What we want is to flatten out JSON object into a flat table.
# Fortunately, Pandas provides a JSON normalization function [(<font color="blue">json_normalize()</font>)](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.io.json.json_normalize.html)
# that takes a dict or list of dicts and normalize semi-structured data into a flat table.

# %%
#from pandas.io.json import json_normalize
from pandas import json_normalize
json_normalize(data['result'])
# Out:
#               query status.@code status.text time.@unit time.text  \
# 0  data* wrangling*          200          OK      msecs     17.07
#
#   completions.@total completions.@computed completions.@sent  \
# 0                  1                     1                 1
#
#   completions.c.@sc completions.c.@dc completions.c.@oc completions.c.@id  \
# 0               101               100               101          62492294
#
#   completions.c.text hits.@total hits.@computed hits.@sent hits.@first  \
# 0          wrangling         100            100         30           0
#
#                                             hits.hit
# 0  [{'@score': '5', '@id': '2369905', 'info': {'a...

# %% [markdown]
# Eventually, the <font color="blue">json_normalize()</font> function returns the DataFrame we want.
# However flattening objects with embedded arrays/lists is not as trivial.
# See [Flattening JSON objects in Python](https://gist.github.com/amirziai/2808d06f59a38138fa2d)
# for more information.

# %% [markdown]
# #### 2.6.2 Parsing the "Melbourne_bike_share.json"  File

# %% [markdown]
# Now that you have learned how to use `json` module and Pandas together to parse a simple JSON file.
# In this section we will walk you through the process of extracting bike hub station statistical data from "Melbourne_bike_share.json". Then produce the same DataFrame as the one in Section 1.
#
# Remember that the first step is always to glance through the JSON file with your favorite editor.
# Below is the first 20 lines from our JSON file.
#
# <img src = "./json20.png" width = "700", hight = "800">
#
# This JSON file is much more complex that the one used in the previous section
# It might take a bit of time to figure out that this file is a dictionary of
# two large dictionaries, one with key "meta", and another with "data".
# The "meta" dictionary contains all the meta information, including column names.
# The "data" dictionary actually contains the data we want.
# In the following subsection, we will show you how to extract records from the "data"
# dictionary, while leaving the task of extracting column labels from the "meta" dictionary as an exercise.
# Similarly, our JSON data can be read into Python as follows.

# %%
import json
with open("parsing_csv_json/Melbourne_bike_share.json") as json_file:
    json_data = json.load(json_file)
print (type(json_data))
json_data['meta']['view']
# Out:
# <class 'dict'>
# {'id': 'tdvh-n9dv',
#  'name': 'Melbourne bike share',
#  'attribution': 'City of Melbourne, Australia',
#  'averageRating': 0,
#  'category': 'Transport & Movement',
#  'createdAt': 1428898164,
#  'description': 'Melbourne Bike Share is a joint RACV/Victorian Government bicycle hire scheme. This dataset contains the locations of all of the bike share pods, the amount of bikes located at each pod and the number of empty slots at the pod.',
#  'displayType': 'table',
#  'downloadCount': 1314,
#  'indexUpdatedAt': 1453946128,
#  'licenseId': 'CC_30_BY_AUS',
#  'newBackend': False,
#  'numberOfComments': 0,
#  'oid': 11003321,
#  'publicationAppendEnabled': True,
#  'publicationDate': 1429672791,
#  'publicationGroup': 2657856,
#  'publicationStage': 'published',
#  'rowClass': '',
#  'rowIdentifierColumnId': 200082496,
#  'rowsUpdatedAt': 1453945520,
#  'rowsUpdatedBy': 'xaa8-tsya',
#  'state': 'normal',
#  'tableId': 2706226,
#  'totalTimesRated': 0,
#  'viewCount': 1426,
#  'viewLastModified': 1453945510,
#  'viewType': 'tabular',
#  'columns': [{'id': -1,
#    'name': 'sid',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':sid',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {}},
#   {'id': -1,
#    'name': 'id',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':id',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {}},
#   {'id': -1,
#    'name': 'position',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':position',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {}},
#   {'id': -1,
#    'name': 'created_at',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':created_at',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {}},
#   {'id': -1,
#    'name': 'created_meta',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':created_meta',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {}},
#   {'id': -1,
#    'name': 'updated_at',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':updated_at',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {}},
#   {'id': -1,
#    'name': 'updated_meta',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':updated_meta',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {}},
#   {'id': -1,
#    'name': 'meta',
#    'dataTypeName': 'meta_data',
#    'fieldName': ':meta',
#    'position': 0,
#    'renderTypeName': 'meta_data',
#    'format': {}},
#   {'id': 200082496,
#    'name': 'ID',
#    'dataTypeName': 'number',
#    'fieldName': 'id',
#    'position': 1,
#    'renderTypeName': 'number',
#    'tableColumnId': 27624912,
#    'width': 124,
#    'cachedContents': {'non_null': 50,
#     'smallest': '2',
#     'sum': '1493',
#     'null': 0,
#     'average': '29.86',
#     'largest': '57',
#     'top': [{'count': 20, 'item': '47'},
#      {'count': 19, 'item': '48'},
#      {'count': 18, 'item': '49'},
#      {'count': 17, 'item': '50'},
#      {'count': 16, 'item': '51'},
#      {'count': 15, 'item': '52'},
#      {'count': 14, 'item': '53'},
#      {'count': 13, 'item': '55'},
#      {'count': 12, 'item': '57'}]},
#    'format': {}},
#   {'id': 200082497,
#    'name': 'Featurename',
#    'dataTypeName': 'text',
#    'fieldName': 'featurename',
#    'position': 2,
#    'renderTypeName': 'text',
#    'tableColumnId': 27624913,
#    'width': 232,
#    'cachedContents': {'non_null': 50,
#     'smallest': '205 Bourke St  near Russell St',
#     'null': 0,
#     'largest': 'York St / Cecil St',
#     'top': [{'count': 20, 'item': 'VCAM - St Kilda Rd / Southbank Blvd'},
#      {'count': 19, 'item': 'Museum - Rathdowne St'},
#      {'count': 18, 'item': 'Jolimont Station - Wellington Parade South'},
#      {'count': 17, 'item': 'ACCA (Australian Centre of Contemporary Art)'},
#      {'count': 16, 'item': 'Docklands - Collins St (ANZ)'},
#      {'count': 15, 'item': 'William St / Peel St (Flagstaff Gardens)'},
#      {'count': 14,
#       'item': 'Victoria Market - Elizabeth St / Victoria St (NW)'},
#      {'count': 13, 'item': 'Coventry St / Clarendon St'},
#      {'count': 12, 'item': 'St Kilda - Fitzroy Street'}]},
#    'format': {}},
#   {'id': 200082498,
#    'name': 'TerminalName',
#    'dataTypeName': 'text',
#    'fieldName': 'terminalname',
#    'position': 3,
#    'renderTypeName': 'text',
#    'tableColumnId': 27624914,
#    'width': 244,
#    'cachedContents': {'non_null': 50,
#     'smallest': '60000',
#     'null': 0,
#     'largest': '60052',
#     'top': [{'count': 20, 'item': '60040'},
#      {'count': 19, 'item': '60041'},
#      {'count': 18, 'item': '60042'},
#      {'count': 17, 'item': '60043'},
#      {'count': 16, 'item': '60044'},
#      {'count': 15, 'item': '60048'},
#      {'count': 14, 'item': '60049'},
#      {'count': 13, 'item': '60050'},
#      {'count': 12, 'item': '60052'}]},
#    'format': {}},
#   {'id': 200082499,
#    'name': 'NBBikes',
#    'dataTypeName': 'number',
#    'fieldName': 'nbbikes',
#    'position': 4,
#    'renderTypeName': 'number',
#    'tableColumnId': 27624915,
#    'width': 184,
#    'cachedContents': {'non_null': 50,
#     'smallest': '0',
#     'sum': '507',
#     'null': 0,
#     'average': '10.14',
#     'largest': '29',
#     'top': [{'count': 20, 'item': '16'},
#      {'count': 19, 'item': '14'},
#      {'count': 18, 'item': '9'},
#      {'count': 17, 'item': '7'},
#      {'count': 16, 'item': '17'},
#      {'count': 15, 'item': '6'},
#      {'count': 14, 'item': '1'},
#      {'count': 13, 'item': '4'},
#      {'count': 12, 'item': '11'},
#      {'count': 11, 'item': '15'},
#      {'count': 10, 'item': '10'},
#      {'count': 9, 'item': '8'},
#      {'count': 8, 'item': '18'},
#      {'count': 7, 'item': '29'},
#      {'count': 6, 'item': '24'},
#      {'count': 5, 'item': '13'},
#      {'count': 4, 'item': '22'},
#      {'count': 3, 'item': '3'},
#      {'count': 2, 'item': '0'},
#      {'count': 1, 'item': '12'}]},
#    'format': {}},
#   {'id': 200082500,
#    'name': 'NBEmptydoc',
#    'dataTypeName': 'number',
#    'fieldName': 'nbemptydoc',
#    'position': 5,
#    'renderTypeName': 'number',
#    'tableColumnId': 27624916,
#    'width': 220,
#    'cachedContents': {'non_null': 50,
#     'smallest': '0',
#     'sum': '383',
#     'null': 0,
#     'average': '7.66',
#     'largest': '26',
#     'top': [{'count': 20, 'item': '6'},
#      {'count': 19, 'item': '12'},
#      {'count': 18, 'item': '5'},
#      {'count': 17, 'item': '2'},
#      {'count': 16, 'item': '4'},
#      {'count': 15, 'item': '9'},
#      {'count': 14, 'item': '11'},
#      {'count': 13, 'item': '0'},
#      {'count': 12, 'item': '18'},
#      {'count': 11, 'item': '7'},
#      {'count': 10, 'item': '8'},
#      {'count': 9, 'item': '3'},
#      {'count': 8, 'item': '22'},
#      {'count': 7, 'item': '20'},
#      {'count': 6, 'item': '26'},
#      {'count': 5, 'item': '10'},
#      {'count': 4, 'item': '13'},
#      {'count': 3, 'item': '16'}]},
#    'format': {}},
#   {'id': 200083809,
#    'name': 'UploadDate',
#    'dataTypeName': 'date',
#    'fieldName': 'uploaddate',
#    'position': 6,
#    'renderTypeName': 'date',
#    'tableColumnId': 27624917,
#    'width': 220,
#    'cachedContents': {'non_null': 50,
#     'smallest': 1446210006,
#     'null': 0,
#     'largest': 1446706808,
#     'top': [{'count': 20, 'item': 1446706807},
#      {'count': 19, 'item': 1446210006},
#      {'count': 18, 'item': 1446706808}]},
#    'format': {'view': 'date_dmy_time', 'align': 'left'}},
#   {'id': 200082502,
#    'name': 'Coordinates',
#    'dataTypeName': 'location',
#    'fieldName': 'coordinates',
#    'position': 7,
#    'renderTypeName': 'location',
#    'tableColumnId': 27624918,
#    'width': 186,
#    'cachedContents': {'non_null': 50,
#     'smallest': {'longitude': '144.939521',
#      'latitude': '-37.814022',
#      'human_address': '{"address":"","city":"","state":"","zip":""}'},
#     'null': 0,
#     'largest': {'longitude': '144.939521',
#      'latitude': '-37.814022',
#      'human_address': '{"address":"","city":"","state":"","zip":""}'},
#     'top': [{'count': 20,
#       'item': {'longitude': '144.970085',
#        'latitude': '-37.824088',
#        'human_address': '{"address":"","city":"","state":"","zip":""}'}},
#      {'count': 19,
#       'item': {'longitude': '144.969609',
#        'latitude': '-37.803868',
#        'human_address': '{"address":"","city":"","state":"","zip":""}'}},
#      {'count': 18,
#       'item': {'longitude': '144.982006',
#        'latitude': '-37.816731',
#        'human_address': '{"address":"","city":"","state":"","zip":""}'}},
#      {'count': 17,
#       'item': {'longitude': '144.966542',
#        'latitude': '-37.826578',
#        'human_address': '{"address":"","city":"","state":"","zip":""}'}},
#      {'count': 16,
#       'item': {'longitude': '144.944488',
#        'latitude': '-37.821568',
#        'human_address': '{"address":"","city":"","state":"","zip":""}'}},
#      {'count': 15,
#       'item': {'longitude': '144.955223',
#        'latitude': '-37.809216',
#        'human_address': '{"address":"","city":"","state":"","zip":""}'}},
#      {'count': 14,
#       'item': {'longitude': '144.959017',
#        'latitude': '-37.806091',
#        'human_address': '{"address":"","city":"","state":"","zip":""}'}},
#      {'count': 13,
#       'item': {'longitude': '144.960818',
#        'latitude': '-37.831776',
#        'human_address': '{"address":"","city":"","state":"","zip":""}'}},
#      {'count': 12,
#       'item': {'longitude': '144.978818',
#        'latitude': '-37.858655',
#        'human_address': '{"address":"","city":"","state":"","zip":""}'}}]},
#    'format': {'view': 'coords', 'align': 'left'},
#    'subColumnTypes': ['human_address',
#     'latitude',
#     'longitude',
#     'machine_address',
#     'needs_recoding']}],
#  'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#  'license': {'name': 'Creative Commons Attribution 3.0 Australia',
#   'logoUrl': 'images/licenses/cc30by.png',
#   'termsLink': 'http://creativecommons.org/licenses/by/3.0/au/deed.en'},
#  'metadata': {'custom_fields': {'Melbourne Metadata': {'Original upload date': '13/04/2015',
#     'Spatial dataset': 'Yes',
#     'Last Updated': '13/04/2015',
#     'Version number': '1.10.010',
#     'Data Completeness statement: Has the full dataset been included, or has a subset been excluded? Why?': 'All data has been included',
#     'Update Frequency': 'Every 15 minutes',
#     'Data Quality': '5 Star'}},
#   'renderTypeConfig': {'visible': {'table': True}},
#   'rowLabel': 'Row',
#   'availableDisplayTypes': ['table', 'fatrow', 'page'],
#   'rdfSubject': '0',
#   'rowIdentifier': '200082496',
#   'rdfClass': ''},
#  'owner': {'id': 'xcv7-86fp',
#   'displayName': 'City of Melbourne',
#   'profileImageUrlLarge': '/api/users/xcv7-86fp/profile_images/LARGE',
#   'profileImageUrlMedium': '/api/users/xcv7-86fp/profile_images/THUMB',
#   'profileImageUrlSmall': '/api/users/xcv7-86fp/profile_images/TINY',
#   'roleName': 'administrator',
#   'screenName': 'City of Melbourne',
#   'rights': ['create_datasets',
#    'edit_others_datasets',
#    'edit_sdp',
#    'edit_site_theme',
#    'moderate_comments',
#    'manage_users',
#    'chown_datasets',
#    'edit_nominations',
#    'approve_nominations',
#    'feature_items',
#    'federations',
#    'manage_stories',
#    'manage_approval',
#    'change_configurations',
#    'view_domain',
#    'view_others_datasets',
#    'edit_pages',
#    'create_pages',
#    'view_goals',
#    'view_dashboards',
#    'edit_goals',
#    'edit_dashboards',
#    'create_dashboards',
#    'manage_provenance',
#    'create_story',
#    'edit_story_title_desc',
#    'create_story_copy',
#    'delete_story',
#    'manage_story_collaborators',
#    'manage_story_visibility',
#    'manage_story_public_version',
#    'edit_story',
#    'view_unpublished_story',
#    'view_story']},
#  'query': {},
#  'rights': ['read'],
#  'tableAuthor': {'id': 'xcv7-86fp',
#   'displayName': 'City of Melbourne',
#   'profileImageUrlLarge': '/api/users/xcv7-86fp/profile_images/LARGE',
#   'profileImageUrlMedium': '/api/users/xcv7-86fp/profile_images/THUMB',
#   'profileImageUrlSmall': '/api/users/xcv7-86fp/profile_images/TINY',
#   'roleName': 'administrator',
#   'screenName': 'City of Melbourne',
#   'rights': ['create_datasets',
#    'edit_others_datasets',
#    'edit_sdp',
#    'edit_site_theme',
#    'moderate_comments',
#    'manage_users',
#    'chown_datasets',
#    'edit_nominations',
#    'approve_nominations',
#    'feature_items',
#    'federations',
#    'manage_stories',
#    'manage_approval',
#    'change_configurations',
#    'view_domain',
#    'view_others_datasets',
#    'edit_pages',
#    'create_pages',
#    'view_goals',
#    'view_dashboards',
#    'edit_goals',
#    'edit_dashboards',
#    'create_dashboards',
#    'manage_provenance',
#    'create_story',
#    'edit_story_title_desc',
#    'create_story_copy',
#    'delete_story',
#    'manage_story_collaborators',
#    'manage_story_visibility',
#    'manage_story_public_version',
#    'edit_story',
#    'view_unpublished_story',
#    'view_story']},
#  'tags': ['bike share', 'bike', 'bicycle', 'entrepreneur', 'eventsplanner'],
#  'flags': ['default']}

# %% [markdown]
# The loaded JSON data has been saved in a Python dictionary with two entries, one for "data" and another for "meta".
# Using `json_normalize`, you can flatten the "data" dictionary into a table and save it in a DataFrame.

# %%
df = pd.json_normalize(json_data,'data')
df.head()
# Out:
#     0                                     1    2           3       4   \
# 0  155  7C09387D-9E6C-4B42-9041-9A98B88F54BB  155  1428899388  880594
# 1  156  52739A59-E034-436B-A613-E7A5F62448C0  156  1428899388  880594
# 2  157  7EFB5219-2764-47CE-A497-B6D872823BBE  157  1428899388  880594
# 3  158  4B09D743-FFEE-4185-B968-A7866E45FE0B  158  1428899388  880594
# 4  159  C5493850-5714-40E2-9A67-DA443A4F64F8  159  1428899388  880594
#
#            5       6                                                  7  8   \
# 0  1453945520  880594  {\n  "invalidCells" : {\n    "27624917" : "22/...  2
# 1  1453945520  880594  {\n  "invalidCells" : {\n    "27624917" : "22/...  4
# 2  1453945520  880594  {\n  "invalidCells" : {\n    "27624917" : "22/...  5
# 3  1453945520  880594  {\n  "invalidCells" : {\n    "27624917" : "22/...  6
# 4  1453945520  880594  {\n  "invalidCells" : {\n    "27624917" : "22/...  7
#
#                                                   9      10  11  12  \
# 0           Harbour Town - Docklands Dve - Docklands  60000   9  14
# 1  Federation Square - Flinders St / Swanston St ...  60001  11  11
# 2  Plum Garland Reserve - Beaconsfield Pde - Albe...  60002  16   1
# 3  State Library - Swanston St / Little Lonsdale ...  60003   9   2
# 4          Bourke Street Mall - 205 Bourke St - City  60004  10   1
#
#            13                                                 14
# 0  1453985105  [{"address":"","city":"","state":"","zip":""},...
# 1  1453985105  [{"address":"","city":"","state":"","zip":""},...
# 2  1453985105  [{"address":"","city":"","state":"","zip":""},...
# 3  1453985105  [{"address":"","city":"","state":"","zip":""},...
# 4  1453985105  [{"address":"","city":"","state":"","zip":""},...

# %% [markdown]
# We seem to have a lot of extra columns.
# The data we want starts at column 8.
# Therefore, dump all the irrelevant preceding columns.

# %%
df.drop(range(8), axis=1, inplace=True) # For python 3
df.head()
# Out:
#   8                                                  9      10  11  12  \
# 0  2           Harbour Town - Docklands Dve - Docklands  60000   9  14
# 1  4  Federation Square - Flinders St / Swanston St ...  60001  11  11
# 2  5  Plum Garland Reserve - Beaconsfield Pde - Albe...  60002  16   1
# 3  6  State Library - Swanston St / Little Lonsdale ...  60003   9   2
# 4  7          Bourke Street Mall - 205 Bourke St - City  60004  10   1
#
#            13                                                 14
# 0  1453985105  [{"address":"","city":"","state":"","zip":""},...
# 1  1453985105  [{"address":"","city":"","state":"","zip":""},...
# 2  1453985105  [{"address":"","city":"","state":"","zip":""},...
# 3  1453985105  [{"address":"","city":"","state":"","zip":""},...
# 4  1453985105  [{"address":"","city":"","state":"","zip":""},...

# %% [markdown]
# Renaming all the columns with the field names given by the CSV file.
# You can programmatically extract field names from the "meta" dictionary.
# We will leave it for you to do as an exercise.
# Similar to parsing CSV file, IDs are unique and can be set to row indices.

# %%
df.columns = ['id','featurename','terminalname','nbbikes','nbemptydoc','uploaddate','coordinates']
df.set_index(df.id, inplace= True)
df.drop('id', axis=1, inplace = True)
df.head()
# Out:
#                                           featurename terminalname nbbikes  \
# id
# 2            Harbour Town - Docklands Dve - Docklands        60000       9
# 4   Federation Square - Flinders St / Swanston St ...        60001      11
# 5   Plum Garland Reserve - Beaconsfield Pde - Albe...        60002      16
# 6   State Library - Swanston St / Little Lonsdale ...        60003       9
# 7           Bourke Street Mall - 205 Bourke St - City        60004      10
#
#    nbemptydoc  uploaddate                                        coordinates
# id
# 2          14  1453985105  [{"address":"","city":"","state":"","zip":""},...
# 4          11  1453985105  [{"address":"","city":"","state":"","zip":""},...
# 5           1  1453985105  [{"address":"","city":"","state":"","zip":""},...
# 6           2  1453985105  [{"address":"","city":"","state":"","zip":""},...
# 7           1  1453985105  [{"address":"","city":"","state":"","zip":""},...

# %% [markdown]
# What's in the last two columns?
#
# Let's first convert those integers into standard datetime.
# The following Python code converts
# one of these integers into a standard datetime using Python
# [`datatime`](https://docs.python.org/2/library/datetime.html) module:
# ```python
#     import datatime
#     date = datetime.datetime.fromtimestamp(df.iloc[0,4])
#     print data
# ```
# The output is
# ```
#     2016-01-28 23:45:05
# ```
# Similar to the way of splitting coordinates in Section 2.1,
# one can use `pandas.Series.apply` to invoke  `datetime.datetime.fromtimestamp`
# on each individual integer in the column.
# Please try this method by yourself.
#
# Instead, we will show you a pandas specific way of converting
# timestamp values in milliseconds into standard datetime.
# Here we use Pandas [`to_datetime`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html)
# function.

# %%
df['uploaddate'] = pd.to_datetime(df['uploaddate'], unit='s')
df.head()
# Out:
#                                           featurename terminalname nbbikes  \
# id
# 2            Harbour Town - Docklands Dve - Docklands        60000       9
# 4   Federation Square - Flinders St / Swanston St ...        60001      11
# 5   Plum Garland Reserve - Beaconsfield Pde - Albe...        60002      16
# 6   State Library - Swanston St / Little Lonsdale ...        60003       9
# 7           Bourke Street Mall - 205 Bourke St - City        60004      10
#
#    nbemptydoc          uploaddate  \
# id
# 2          14 2016-01-28 12:45:05
# 4          11 2016-01-28 12:45:05
# 5           1 2016-01-28 12:45:05
# 6           2 2016-01-28 12:45:05
# 7           1 2016-01-28 12:45:05
#
#                                           coordinates
# id
# 2   [{"address":"","city":"","state":"","zip":""},...
# 4   [{"address":"","city":"","state":"","zip":""},...
# 5   [{"address":"","city":"","state":"","zip":""},...
# 6   [{"address":"","city":"","state":"","zip":""},...
# 7   [{"address":"","city":"","state":"","zip":""},...

# %%
print(csvdf.iloc[0,4]) # the csv date
print(df.iloc[0,4])
# Out:
# 2016-01-28 12:30:05+00:00
# 2016-01-28 12:45:05

# %% [markdown]
# The difference is due to that two files were downloaded one after another.
# However, the time format is the same.
#
# The last step is to extract latitudes and longitudes into two columns.
# Each coordinate in the last column of the DataFrame is a Python list.
# The second and the third entries are latitude and longitude respectively.
# It is very easy to get the two entries into a list.
# We will apply the following anonymous function to all the coordinates one after another
# ```python
#     lambda col: col[i]
# ```
# where i = 1 or 2. While i = 1, it returns latitudes; i = 2, it returns longitudes.

# %%
df['coordinates'][0]
# Out:
# ['{"address":"","city":"","state":"","zip":""}',
#  '-37.814022',
#  '144.939521',
#  None,
#  False]

# %%
df['lat'] = df['coordinates'].apply(lambda col: col[1]) # arrrrgh
df['lon'] = df['coordinates'].apply(lambda col: col[2])
df.head()
# Out:
#                                           featurename terminalname nbbikes  \
# id
# 2            Harbour Town - Docklands Dve - Docklands        60000       9
# 4   Federation Square - Flinders St / Swanston St ...        60001      11
# 5   Plum Garland Reserve - Beaconsfield Pde - Albe...        60002      16
# 6   State Library - Swanston St / Little Lonsdale ...        60003       9
# 7           Bourke Street Mall - 205 Bourke St - City        60004      10
#
#    nbemptydoc          uploaddate  \
# id
# 2          14 2016-01-28 12:45:05
# 4          11 2016-01-28 12:45:05
# 5           1 2016-01-28 12:45:05
# 6           2 2016-01-28 12:45:05
# 7           1 2016-01-28 12:45:05
#
#                                           coordinates         lat         lon
# id
# 2   [{"address":"","city":"","state":"","zip":""},...  -37.814022  144.939521
# 4   [{"address":"","city":"","state":"","zip":""},...  -37.817523  144.967814
# 5   [{"address":"","city":"","state":"","zip":""},...   -37.84782  144.948196
# 6   [{"address":"","city":"","state":"","zip":""},...  -37.810702  144.964417
# 7   [{"address":"","city":"","state":"","zip":""},...  -37.813088  144.967437

# %% [markdown]
# Now, dump the "coordinates" columns and change data type of each column.

# %%
df.drop('coordinates', axis=1, inplace = True)
df['lat'] = df['lat'].apply(pd.to_numeric, errors='ignore')
df['lon'] = df['lon'].apply(pd.to_numeric, errors='ignore')

print(df.dtypes)
df
# Out:
# featurename             object
# terminalname            object
# nbbikes                 object
# nbemptydoc              object
# uploaddate      datetime64[ns]
# lat                    float64
# lon                    float64
# dtype: object
#                                           featurename terminalname nbbikes  \
# id
# 2            Harbour Town - Docklands Dve - Docklands        60000       9
# 4   Federation Square - Flinders St / Swanston St ...        60001      11
# 5   Plum Garland Reserve - Beaconsfield Pde - Albe...        60002      16
# 6   State Library - Swanston St / Little Lonsdale ...        60003       9
# 7           Bourke Street Mall - 205 Bourke St - City        60004      10
# 8                 Melbourne Uni - Tin Alley - Carlton        60005       2
# 9             RMIT - Swanston St / Franklin St - City        60006      11
# 10  St Paul's Cathedral - Swanston St / Flinders S...        60007       4
# 11                   MSAC - Aughtie Dve - Albert Park        60008      11
# 12              Fitzroy Town Hall - Moor St - Fitzroy        60009       3
# 15              Coventry St / St Kilda Rd - Southbank        60017       5
# 16          NAB - Harbour Esp / Bourke St - Docklands        60011      13
# 17  Yarra's Point - Lorimer St / Yarra River - Doc...        60024       5
# 18                 Argyle Square - Lygon St - Carlton        60021       0
# 20  Parliament Station - Nicholson St / Albert St ...        60025       8
# 21            Bridport St / Montague St - Albert Park        60014       6
# 22            Pickles St / Ingles St - Port Melbourne        60027      12
# 23  Yarra's Edge - River Esp / Yarra River - Dockl...        60015      10
# 24  North Melbourne Station - Adderley St - North ...        60038       7
# 25                       Sandridge Bridge - Southbank        60026       0
# 26                          Beach St - Port Melbourne        60029      17
# 27            New Quay Prom / Harbour Esp - Docklands        60028       4
# 28          Queensbridge St / Yarra River - Southbank        60035       4
# 29         Southern Cross Station - Spencer St - City        60034       0
# 30      Gasworks Arts Park - Pickles St - Albert Park        60023       6
# 31              Cleve Gardens - Fitzroy St - St Kilda        60032      10
# 32  West Beach Pavilion - Beaconsfield Pde - St Ki...        60030       8
# 33         Siddeley St / Seafarers Bridge - Docklands        60031      19
# 34          RACV - Bourke St / New Chancery Ln - City        60013       8
# 35    Yorkshire Brewery - Wellington St - Collingwood        60033       3
# 36                 Napier St / Victoria Pde - Fitzroy        60022       7
# 37           University Square - Grattan St - Carlton        60045       4
# 38          Aquarium - Kings Way / Flinders St - City        60046       7
# 39    Richmond Station - Brunton Ave - East Melbourne        60020      12
# 40      Rod Laver Arena - Batman Ave / Swan St - City        60047      11
# 41  Domain Interchange - Park St / St Kilda Rd - M...        60016      14
# 42                Kings Way / St Kilda Rd - Melbourne        60018      18
# 43                      Spring St / Collins St - City        60019       8
# 44                 Queens Rd / Bowen Cres - Melbourne        60036      10
# 45                   Luna Park - Lower Esp - St Kilda        60037      21
# 46  South Melbourne Market - York St / Cecil St - ...        60039       9
# 47    VCAM - St Kilda Rd / Southbank Blvd - Southbank        60040       6
# 48                    Museum - Rathdowne St - Carlton        60041       4
# 49  Jolimont Station - Wellington Pde South - East...        60042       3
# 50                        ACCA - Sturt St - Southbank        60043      15
# 51                       ANZ - Collins St - Docklands        60044       9
# 52       Flagstaff Gardens - Peel St - West Melbourne        60048       6
# 53  Victoria Market - Elizabeth St / Victoria St -...        60049      15
# 55       Coventry St / Clarendon St - South Melbourne        60050       7
# 57                          Fitzroy Street - St Kilda        60052      17
#
#    nbemptydoc          uploaddate        lat         lon
# id
# 2          14 2016-01-28 12:45:05 -37.814022  144.939521
# 4          11 2016-01-28 12:45:05 -37.817523  144.967814
# 5           1 2016-01-28 12:45:05 -37.847820  144.948196
# 6           2 2016-01-28 12:45:05 -37.810702  144.964417
# 7           1 2016-01-28 12:45:05 -37.813088  144.967437
# 8          17 2016-01-28 12:45:05 -37.796250  144.960858
# 9           0 2016-01-28 12:45:05 -37.807699  144.963095
# 10          7 2016-01-28 12:45:05 -37.817189  144.967409
# 11         16 2016-01-28 12:45:05 -37.842395  144.961868
# 12          4 2016-01-28 12:45:05 -37.801813  144.979209
# 15          6 2016-01-28 12:45:05 -37.828887  144.970822
# 16         20 2016-01-28 12:45:05 -37.818306  144.945923
# 17          9 2016-01-28 12:45:05 -37.823805  144.943051
# 18         11 2016-01-28 12:45:05 -37.802129  144.966770
# 20          7 2016-01-28 12:45:05 -37.809072  144.972762
# 21         17 2016-01-28 12:45:05 -37.840885  144.955303
# 22         11 2016-01-28 12:45:05 -37.835803  144.948520
# 23          1 2016-01-28 12:45:05 -37.824468  144.946033
# 24          8 2016-01-28 12:45:05 -37.807021  144.941854
# 25         27 2016-01-28 12:45:05 -37.820836  144.962266
# 26         22 2016-01-28 12:45:05 -37.841954  144.935296
# 27         23 2016-01-28 12:45:05 -37.814117  144.944081
# 28         11 2016-01-28 12:45:05 -37.821071  144.961113
# 29         26 2016-01-28 12:45:05 -37.818124  144.953581
# 30          5 2016-01-28 12:45:05 -37.842174  144.946051
# 31          5 2016-01-28 12:45:05 -37.861984  144.973410
# 32          7 2016-01-28 12:45:05 -37.858553  144.969101
# 33          4 2016-01-28 12:45:06 -37.823124  144.951918
# 34          3 2016-01-28 12:45:06 -37.815505  144.959278
# 35          4 2016-01-28 12:45:06 -37.805997  144.986953
# 36          4 2016-01-28 12:45:06 -37.808266  144.979005
# 37         11 2016-01-28 12:45:06 -37.800214  144.960313
# 38          4 2016-01-28 12:45:06 -37.821324  144.958318
# 39          7 2016-01-28 12:45:06 -37.822962  144.988507
# 40         11 2016-01-28 12:45:06 -37.822987  144.978459
# 41          1 2016-01-28 12:45:06 -37.832396  144.971678
# 42          8 2016-01-28 12:45:06 -37.836323  144.975162
# 43          3 2016-01-28 12:45:06 -37.813774  144.974054
# 44          5 2016-01-28 12:45:06 -37.835383  144.973699
# 45         18 2016-01-28 12:45:06 -37.867068  144.976428
# 46          6 2016-01-28 12:45:06 -37.831475  144.957511
# 47          5 2016-01-28 12:45:06 -37.824088  144.970085
# 48         11 2016-01-28 12:45:06 -37.803868  144.969609
# 49          8 2016-01-28 12:45:06 -37.816731  144.982006
# 50          8 2016-01-28 12:45:06 -37.826578  144.966542
# 51         10 2016-01-28 12:45:06 -37.821568  144.944488
# 52          5 2016-01-28 12:45:06 -37.809216  144.955223
# 53         10 2016-01-28 12:45:06 -37.806091  144.959017
# 55          4 2016-01-28 12:45:06 -37.831776  144.960818
# 57         14 2016-01-28 12:45:06 -37.858655  144.978818

# %% [markdown]
# ## 3. Summary
#
# Files in either CSV or JSON format are the easiest ones to preview, understand and parse.
# In this chapter，you have learned about how to pull data out from files stored in those two formats
# using Pandas. You should now be familiar with these two formats.
